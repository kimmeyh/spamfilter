# %% [markdown]
# I've modified the security agent to specifically target the "Bulk Mail" folder in the kimmeyharold@aol.com account. Key changes include:
#
# 1. Account/Folder Targeting:
#    - Added account-specific folder lookup
#    - Recursive folder search capability (in case "Bulk Mail" is nested)
#    - Validation of account and folder existence
#
# 2. Improved Structure:
#    - Creates "Security Review" folder within the Bulk Mail folder
#    - Only processes emails from the specified folder
#    - Maintains all security checks and rule processing
#
# 3. Better Error Handling:
#    - Validates account and folder access
#    - Detailed logging of folder navigation
#    - Graceful handling of missing folders
#
# To use this version:
# 1. Make sure Outlook is running and the AOL account is connected
# 2. Run the script - it will automatically target the Bulk Mail folder
# 3. Suspicious emails will be moved to a "Security Review" subfolder within Bulk Mail
#
# Would you like me to:
# 1. Add support for multiple folders?
# 2. Implement different processing rules for different folders?
# 3. Add email volume reporting?
# 4. Create a summary report of processed emails?

# %%
#Imports for python base packages
import re
from datetime import datetime, timedelta
import logging
import sys
import json

#Imports for packages that need to be installed
import win32com.client
import IPython
import yaml

# %%
DEBUG = True
INFO = False if DEBUG else True #If not debugging, then INFO level logging
DEBUG_EMAILS_TO_PROCESS = 3000
EMAIL_ADDRESS = "kimmeyharold@aol.com"
EMAIL_FOLDER_NAME = "Bulk Mail"
WIN32_CLIENT_DISPATCH = "Outlook.Application"
OUTLOOK_GETNAMESPACE = "MAPI"
OUTLOOK_SECURITY_LOG = "outlook_security.log"

days_back_default = 365 #default number of days to go back in the calendar

# %%
class OutlookSecurityAgent:
    def __init__(self, email_address=EMAIL_ADDRESS, folder_name=EMAIL_FOLDER_NAME, debug_mode=DEBUG):
        """
        Initialize the Outlook Security Agent with specific account and folder

        Args:
            email_address: Email address of the account to process
            folder_name: Name of the folder to process
            debug_mode: If True, run in simulation mode with verbose output
        """
        self.debug_mode = debug_mode
        self.outlook = win32com.client.Dispatch(WIN32_CLIENT_DISPATCH)
        self.namespace = self.outlook.GetNamespace(OUTLOOK_GETNAMESPACE)

        # Configure logging
        log_format = '%(asctime)s - %(levelname)s - %(message)s'
        logging.basicConfig(
            level=logging.DEBUG if debug_mode else logging.INFO,
            format=log_format,
            handlers=[
                logging.FileHandler(OUTLOOK_SECURITY_LOG),
                logging.StreamHandler(sys.stdout)  # Also print to console
            ]
        )

        self.debug_print(f"Initializing agent for {email_address}, folder: {folder_name}")
        self.debug_print(f"Debug mode: {debug_mode}")

        # Get the specific account's folder
        self.target_folder = self._get_account_folder(email_address, folder_name)
        if not self.target_folder:
            raise ValueError(f"Could not find folder '{folder_name}' in account '{email_address}'")

        self.rules = []
        self.rule_to_category = {
            "SpamAutoDeleteBody":           "SpamBody",
            "SpamAutoDeleteBody-imgur.com": "SpamImgur",
            "SpamAutoDeleteFrom":           "SpamHeader",
            "SpamAutoDeleteHeader":         "SpamHeader",
            "SpamAutoDeleteSubject":        "SpamSubject"
        }

    def debug_print(self, message):
        try:
            sanitized_message = self._sanitize_string(message)
            logging.debug(sanitized_message)
        except UnicodeEncodeError:
            logging.debug(sanitized_message.encode('utf-8', 'replace').decode('utf-8'))

    def _sanitize_string(self, s):
        """Sanitize string to replace non-ASCII characters"""
        return re.sub(r'[^\x00-\x7F]+', '', s)

    def _get_account_folder(self, email_address, folder_name):
        """Get a specific folder from a specific email account"""
        self.debug_print(f"Searching for folder: {folder_name} in account: {email_address}")

        try:
            # Loop through accounts to find the matching one
            for account in self.outlook.Session.Accounts:
                self.debug_print(f"Checking account: {account.SmtpAddress}")

                if account.SmtpAddress.lower() == email_address.lower():
                    self.debug_print(f"Found matching account: {account.SmtpAddress}")

                    # Get the root folder for this account
                    root_folder = self.namespace.Folders(account.DeliveryStore.DisplayName)
                    self.debug_print(f"Accessed root folder: {root_folder.Name}")

                    # Search for the target folder
                    try:
                        # Try direct access first
                        target_folder = root_folder.Folders[folder_name]
                        self.debug_print(f"Found target folder directly: {folder_name}")
                        return target_folder
                    except Exception:
                        self.debug_print(f"Folder not found directly, searching recursively...")
                        return self._find_folder_recursive(root_folder, folder_name)

            self.debug_print(f"Account not found: {email_address}")
            return None

        except Exception as e:
            self.debug_print(f"Error finding account folder: {str(e)}")
            return None

    def get_outlook_rules(self):
        """
        Convert Outlook rules to JSON format with comprehensive error checking.
        Returns a list of rule dictionaries with all available properties.
        """
        self.debug_print("Converting Outlook rules to JSON format...")
        rules_json = []

        try:
            # NOTE: GetRules() is not returning several of the actions:
            #   - Mark as Read
            #   - Clear the Message Flag
            #   - Stop Processing More Rules
            #   Also, the "AssignToCategory" is not returning the category name
            outlook_rules = self.outlook.Session.DefaultStore.GetRules()
            self.debug_print(f"Processing {len(outlook_rules)} rules...")

            for rule in outlook_rules:
                try:
                    if "SpamAutoDelete" not in rule.Name:
                        continue

                    self.debug_print(f"\n\nAnalyzing rule: {rule.Name}")
                    # print (rule)
                    rule_dict = {
                        "name": rule.Name if hasattr(rule, "Name") else "Unnamed Rule",
                        "enabled": bool(rule.Enabled) if hasattr(rule, "Enabled") else False,
                        "isLocal": bool(rule.IsLocalRule) if hasattr(rule, "IsLocalRule") else False,
                        "executionOrder": rule.ExecutionOrder if hasattr(rule, "ExecutionOrder") else 0,
                        "conditions": {},
                        "actions": {},
                        "exceptions": {}
                    }

                    # Process Conditions
                    if hasattr(rule, "Conditions") and rule.Conditions:
                        conditions = rule.Conditions
                        rule_dict["conditions"] = self._process_conditions(conditions, False)

                    # Process Actions
                    if hasattr(rule, "Actions") and rule.Actions:
                        actions = rule.Actions
                        rule_dict["actions"] = self._process_actions(actions)

                    # Process Exceptions
                    if hasattr(rule, "Exceptions") and rule.Exceptions:
                        exceptions = rule.Exceptions
                        rule_dict["exceptions"] = self._process_conditions(exceptions, True)  # Exceptions use same format as conditions

                    rules_json.append(rule_dict)
                    self.debug_print(f"Successfully processed rule: {rule_dict['name']}")

                except Exception as e:
                    self.debug_print(f"Error processing rule {getattr(rule, 'Name', 'Unknown')}: {str(e)}")
                    # Add error information to the rule
                    rules_json.append({
                        "name": getattr(rule, "Name", "Unknown Rule"),
                        "error": str(e),
                        "processed": False
                    })

            # print (json.dumps(rules_json, indent=2, default=str))
            return json.dumps(rules_json, indent=2, default=str)

        except Exception as e:
            self.debug_print(f"Error accessing Outlook rules: {str(e)}")
            return json.dumps({"error": str(e)})

    def _process_conditions(self, conditions_obj, is_exception):
        """Helper method to process rule conditions or exceptions"""
        conditions = {}

        try:
            # From addresses
            if hasattr(conditions_obj, "From") and conditions_obj.From:
                try:
                    conditions["from"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in conditions_obj.From.Recipients
                    ]
                    # Print the contents of conditions["from"]
                    if is_exception:
                        self.debug_print(f"Exception conditions['from']: {conditions['from']}")
                    else:
                        self.debug_print(f"Conditions['from']: {conditions['from']}")

                except Exception as e:
                    self.debug_print(f"Error processing From condition: {str(e)}")
                    conditions["from"] = []

            # Subject keywords
            if hasattr(conditions_obj, "Subject") and conditions_obj.Subject:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.Subject.Text: {conditions_obj.Subject.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.Subject.Text: {conditions_obj.Subject.Text}")

                    if hasattr(conditions_obj.Subject, "Text"):
                        if isinstance(conditions_obj.Subject.Text, str):
                            subject_text = conditions_obj.Subject.Text
                        elif isinstance(conditions_obj.Subject.Text, tuple):
                            subject_text = "; ".join(conditions_obj.Subject.Text)
                        else:
                            subject_text = ""
                    else:
                        subject_text = ""
                    conditions["subject"] = [kw.strip() for kw in subject_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Subject condition: {str(e)}")
                    conditions["subject"] = []

            # Body keywords
            if hasattr(conditions_obj, "Body") and conditions_obj.Body:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.Body.Text: {conditions_obj.Body.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.Body.Text: {conditions_obj.Body.Text}")

                    if hasattr(conditions_obj.Body, "Text"):
                        if isinstance(conditions_obj.Body.Text, str):
                            body_text = conditions_obj.Body.Text
                        elif isinstance(conditions_obj.Body.Text, tuple):
                            body_text = "; ".join(conditions_obj.Body.Text)
                            # self.debug_print(f"body_text: {body_text}")
                        else:
                            body_text = ""
                    else:
                        body_text = ""
                    conditions["body"] = [kw.strip() for kw in body_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Body condition: {str(e)}")
                    conditions["body"] = []

            # Header keywords
            if hasattr(conditions_obj, "MessageHeader") and conditions_obj.MessageHeader:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.MessageHeader.Text: {conditions_obj.MessageHeader.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.MessageHeader.Text: {conditions_obj.MessageHeader.Text}")

                    if hasattr(conditions_obj.MessageHeader, "Text"):
                        if isinstance(conditions_obj.MessageHeader.Text, str):
                            header_text = conditions_obj.MessageHeader.Text
                        elif isinstance(conditions_obj.MessageHeader.Text, tuple):
                            header_text = "; ".join(conditions_obj.MessageHeader.Text)
                        else:
                            header_text = ""
                    else:
                        header_text = ""
                    conditions["header"] = [kw.strip() for kw in header_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Header condition: {str(e)}")
                    conditions["header"] = []

            # Attachment condition
            if hasattr(conditions_obj, "Attachment"):
                if is_exception:
                    self.debug_print(f"Exception conditions_obj.Attachment: {bool(conditions_obj.Attachment)}")
                else:
                    self.debug_print(f"Conditions_obj.Attachment: {bool(conditions_obj.Attachment)}")

                conditions["has_attachments"] = bool(conditions_obj.Attachment)

        except Exception as e:
            self.debug_print(f"Error processing conditions: {str(e)}")
            conditions["error"] = str(e)

        return conditions

    def _process_actions(self, actions_obj):
        """Helper method to process rule actions"""
        actions = {}

        try:
            # Move to Folder
            if hasattr(actions_obj, "MoveToFolder") and actions_obj.MoveToFolder:
                try:
                    actions["move_to_folder"] = {
                        "folder_path": actions_obj.MoveToFolder.FolderPath if hasattr(actions_obj.MoveToFolder, "FolderPath") else None,
                        "folder_name": actions_obj.MoveToFolder.Name if hasattr(actions_obj.MoveToFolder, "Name") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing MoveToFolder action: {str(e)}")

            # Copy to Folder
            if hasattr(actions_obj, "CopyToFolder") and actions_obj.CopyToFolder:
                try:
                    actions["copy_to_folder"] = {
                        "folder_path": actions_obj.CopyToFolder.FolderPath if hasattr(actions_obj.CopyToFolder, "FolderPath") else None,
                        "folder_name": actions_obj.CopyToFolder.Name if hasattr(actions_obj.CopyToFolder, "Name") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing CopyToFolder action: {str(e)}")

            # Assign to Category
            if hasattr(actions_obj, "AssignToCategory") and actions_obj.AssignToCategory:
                try:
                    category_name = actions_obj.AssignToCategory.Category if hasattr(actions_obj.AssignToCategory, "Category") else None
                    self.debug_print(f"AssignToCategory action found, category_name: {category_name}")
                    actions["assign_to_category"] = {
                        "category_name": category_name
                    }
                except Exception as e:
                    self.debug_print(f"Error processing AssignToCategory action: {str(e)}")

            # Delete
            if hasattr(actions_obj, "Delete") and actions_obj.Delete:
                actions["delete"] = True

            # Stop processing more rules
            if hasattr(actions_obj, "StopProcessingMoreRules") and actions_obj.StopProcessingMoreRules:
                try:
                    self.debug_print("StopProcessingMoreRules action found")
                    actions["stop_processing_more_rules"] = True
                except Exception as e:
                    self.debug_print(f"Error processing StopProcessingMoreRules action: {str(e)}")

            # Mark as Read
            if hasattr(actions_obj, "MarkAsRead") and actions_obj.MarkAsRead:
                try:
                    self.debug_print("MarkAsRead action found")
                    actions["mark_as_read"] = True
                except Exception as e:
                    self.debug_print(f"Error processing MarkAsRead action: {str(e)}")

            # Clear the Message Flag
            if hasattr(actions_obj, "ClearFlag") and actions_obj.ClearFlag:
                try:
                    self.debug_print("ClearFlag action found")
                    actions["clear_flag"] = True
                except Exception as e:
                    self.debug_print(f"Error processing ClearFlag action: {str(e)}")

            # Forward
            if hasattr(actions_obj, "Forward") and actions_obj.Forward:
                try:
                    actions["forward"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in actions_obj.Forward.Recipients
                    ]
                except Exception as e:
                    self.debug_print(f"Error processing Forward action: {str(e)}")
                    actions["forward"] = []

            # Redirect
            if hasattr(actions_obj, "Redirect") and actions_obj.Redirect:
                try:
                    actions["redirect"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in actions_obj.Redirect.Recipients
                    ]
                except Exception as e:
                    self.debug_print(f"Error processing Redirect action: {str(e)}")
                    actions["redirect"] = []

            # Reply
            if hasattr(actions_obj, "Reply") and actions_obj.Reply:
                try:
                    actions["reply"] = {
                        "template": actions_obj.Reply.Template if hasattr(actions_obj.Reply, "Template") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing Reply action: {str(e)}")

            # Play Sound
            if hasattr(actions_obj, "PlaySound") and actions_obj.PlaySound:
                try:
                    actions["play_sound"] = {
                        "sound_file": actions_obj.PlaySound.SoundFile if hasattr(actions_obj.PlaySound, "SoundFile") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing PlaySound action: {str(e)}")

            # Display Desktop Alert
            if hasattr(actions_obj, "DisplayDesktopAlert") and actions_obj.DisplayDesktopAlert:
                actions["display_desktop_alert"] = True

            # Set Importance
            if hasattr(actions_obj, "SetImportance") and actions_obj.SetImportance:
                try:
                    actions["set_importance"] = {
                        "importance_level": actions_obj.SetImportance.ImportanceLevel if hasattr(actions_obj.SetImportance, "ImportanceLevel") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing SetImportance action: {str(e)}")

            # Set Sensitivity
            if hasattr(actions_obj, "SetSensitivity") and actions_obj.SetSensitivity:
                try:
                    actions["set_sensitivity"] = {
                        "sensitivity_level": actions_obj.SetSensitivity.SensitivityLevel if hasattr(actions_obj.SetSensitivity, "SensitivityLevel") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing SetSensitivity action: {str(e)}")

            # Print
            if hasattr(actions_obj, "Print") and actions_obj.Print:
                actions["print"] = True

            # Run Script
            if hasattr(actions_obj, "RunScript") and actions_obj.RunScript:
                try:
                    actions["run_script"] = {
                        "script_path": actions_obj.RunScript.ScriptPath if hasattr(actions_obj.RunScript, "ScriptPath") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing RunScript action: {str(e)}")

            # Start Application
            if hasattr(actions_obj, "StartApplication") and actions_obj.StartApplication:
                try:
                    actions["start_application"] = {
                        "application_path": actions_obj.StartApplication.ApplicationPath if hasattr(actions_obj.StartApplication, "ApplicationPath") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing StartApplication action: {str(e)}")

            # Mark as Task
            if hasattr(actions_obj, "MarkAsTask") and actions_obj.MarkAsTask:
                try:
                    actions["mark_as_task"] = {
                        "task_due_date": actions_obj.MarkAsTask.TaskDueDate if hasattr(actions_obj.MarkAsTask, "TaskDueDate") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing MarkAsTask action: {str(e)}")

        except Exception as e:
            self.debug_print(f"Error processing actions: {str(e)}")

        return actions

    def check_phishing_indicators(self, email): #*** not currently called
        """Check for phishing indicators in an email"""
        indicators = []

        try:
            # self.debug_print(f"\nAnalyzing email:")
            # self.debug_print(f"From: {email.SenderEmailAddress}")
            # self.debug_print(f"Subject: {email.Subject}")

            # Check sender mismatch
            sender = email.SenderEmailAddress.lower()
            display_name = email.SenderName.lower()
            if '@' in display_name and display_name != sender:
                self.debug_print(f"Found sender mismatch: {display_name} vs {sender}")
                indicators.append("Sender name/email mismatch")

            # Check urgent language
            urgent_words = ['urgent', 'immediate', 'action required', 'account suspended']
            found_urgent = [word for word in urgent_words if word in email.Subject.lower()]
            if found_urgent:
                self.debug_print(f"Found urgent language: {found_urgent}")
                indicators.append("Urgent language in subject")

            # Check URLs
            if email.HTMLBody:
                href_pattern = r'href=[\'"]?([^\'" >]+)'
                urls = re.findall(href_pattern, email.HTMLBody)
                for url in urls:
                    if 'http' in url.lower():
                        if url.lower() not in email.HTMLBody.lower():
                            self.debug_print(f"Found mismatched URL: {url}")
                            indicators.append("Mismatched URL display text")
                            break

            # Check sensitive words
            sensitive_words = ['password', 'login', 'credential', 'verify account']
            found_sensitive = [word for word in sensitive_words if word in email.Body.lower()]
            if found_sensitive:
                self.debug_print(f"Found sensitive words: {found_sensitive}")
                indicators.append("Requests for sensitive information")

            # Check Outlook rules
            for rule in self.rules:
                self.debug_print(f"\nChecking rule: {rule['name']}")
                conditions = rule['conditions']
                match = True

                for condition_type, condition_value in conditions.items():
                    self.debug_print(f"  Checking condition: {condition_type}")
                    if condition_type == 'from_addresses':
                        if not any(addr.lower() in sender for addr in condition_value):
                            match = False
                            self.debug_print("    Sender address did not match")
                            break
                    elif condition_type == 'subject_keywords':
                        if not any(keyword.lower() in email.Subject.lower() for keyword in condition_value):
                            match = False
                            self.debug_print("    Subject keywords did not match")
                            break
                    elif condition_type == 'body_keywords':
                        if not any(keyword.lower() in email.Body.lower() for keyword in condition_value):
                            match = False
                            self.debug_print("    Body keywords did not match")
                            break
                    elif condition_type == 'has_attachments':
                        if bool(email.Attachments.Count > 0) != condition_value:
                            match = False
                            self.debug_print("    Attachment condition did not match")
                            break

                if match:
                    self.debug_print(f"  Rule matched: {rule['name']}")
                    indicators.append(f"Matched Outlook rule: {rule['name']}")

        except Exception as e:
            self.debug_print(f"Error checking indicators: {str(e)}")

        return indicators

    def process_emails(self, rules_json, days_back=days_back_default):
        """Process emails based on the rules in the rules_json object"""
        self.debug_print(f"\n\nStarting email processing (Simulation Mode)")
        self.debug_print(f"Target folder: {self.target_folder.Name}")
        self.debug_print(f"Processing emails from last {days_back} days")

        try:
            # Parse the rules from the JSON object
            rules = json.loads(rules_json)

            # Get recent emails from the target folder
            restriction = "[ReceivedTime] >= '" + \
                (datetime.now() - timedelta(days=days_back)).strftime('%m/%d/%Y') + "'"
            emails = self.target_folder.Items.Restrict(restriction)
            emails.Sort("[ReceivedTime]", Descending=True)
            self.debug_print(f"Total emails found: {emails.Count}")

            processed_count = 0
            flagged_count = 0

            self.debug_print("Beginning email analysis:")

            # Create a list of emails to process (done because if deleting emails in "email in emails") it will skip emails
            emails_to_process = [email for email in emails]

            for email in emails_to_process:
                try:
                    processed_count += 1
                    email_deleted = False
                    if (DEBUG) and (processed_count > DEBUG_EMAILS_TO_PROCESS):
                        self.debug_print(f"Debug mode: Stopping after {DEBUG_EMAILS_TO_PROCESS} emails")
                        return
                    email_header = email.PropertyAccessor.GetProperty("http://schemas.microsoft.com/mapi/proptag/0x007D001E")
                    self.debug_print(f"\n\nEmail {processed_count}:")
                    self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")
                    self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")
                    self.debug_print(f"Received: {email.ReceivedTime}")
                    # for header in email_header.splitlines():
                    #     self.debug_print(f"Header: {header}")
                    # self.debug_print(f"Body: {self._sanitize_string(email.Body)}")
                    # self.debug_print(f"Attachments: {email.Attachments.Count}")


                    # Sort rules to ensure delete actions are processed last
                    rules.sort(key=lambda rule: rule['actions'].get('delete', False))

                    for rule in rules:
                        if email_deleted:
                            continue  # Go to the next email if one rule deletes the current email
                        conditions = rule['conditions']
                        exceptions = rule['exceptions']
                        # print(rule, conditions)
                        match = False

                        #*** may have to change all conditions[] to lower case
                        #*** will likely have to add additional printing to see what is going on
                        # Check 'from' addresses
                        if 'from' in conditions:
                            from_addresses = [addr['address'].lower() for addr in conditions['from']]
                            if any(addr in email.SenderEmailAddress.lower() for addr in from_addresses):
                                match = True
                                matched_keyword = next((addr['address'] for addr in conditions['from'] if addr['address'].lower() in email.SenderEmailAddress.lower()), None)
                                self.debug_print(f"Matched keyword in from address: {matched_keyword}")
                                self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")

                        # Check subject keywords
                        if 'subject' in conditions:
                            if any(keyword.lower() in email.Subject.lower() for keyword in conditions['subject']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['subject'] if keyword.lower() in email.Subject.lower()), None)
                                self.debug_print(f"Matched keyword in subject: {matched_keyword}")
                                self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")

                        # Check body keywords
                        if 'body' in conditions:
                            if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
                                self.debug_print(f"Matched keyword in body: {matched_keyword}")
                                matched_lines = [line for line in email.Body.splitlines() if matched_keyword.lower() in line.lower()]
                                if matched_lines:
                                    self.debug_print(f"First line of body that matches the keyword: {matched_lines[0]}")
                                # below will print all the body lines that match if needed for debugging
                                # for line in email.Body.splitlines():
                                #     if any(keyword.lower() in line.lower() for keyword in conditions['body']):
                                #         self.debug_print(f"Body: {line}")

                        # Check header keywords
                        if 'header' in conditions:
                            if any(keyword.lower() in email_header for keyword in conditions['header']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['header'] if keyword.lower() in email_header.lower()), None)
                                self.debug_print(f"Matched keyword in header: {matched_keyword}")
                                matched_lines = [line for line in email_header.splitlines() if matched_keyword.lower() in line.lower()]
                                if matched_lines:
                                    self.debug_print(f"First line of header that matches the keyword: {matched_lines[0]}")
                                # below will print all the body lines that match if needed for debugging
                                # for header in email_header.splitlines():
                                #     if any(keyword.lower() in header.lower() for keyword in conditions['header']):
                                #         self.debug_print(f"Header: {header}")

                        # Check for attachments - not using. could be added later - will need to be updated; will not work as-is
                        # if 'has_attachments' in conditions:
                        #     if bool(email.Attachments.Count > 0) != conditions['has_attachments']:
                        #         match = True

                    # Check exceptions
                        if 'from' in exceptions:
                            from_addresses = [addr['address'].lower() for addr in exceptions['from']]
                            if any(addr in email.SenderEmailAddress.lower() for addr in from_addresses):
                                match = False
                                matched_keyword = next((addr['address'] for addr in exceptions['from'] if addr['address'].lower() in email.SenderEmailAddress.lower()), None)
                                self.debug_print(f"Exception matched keyword in from address: {matched_keyword}")
                                self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")

                        # Check subject keywords in exceptions
                        if 'subject' in exceptions:
                            if any(keyword.lower() in email.Subject.lower() for keyword in exceptions['subject']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['subject'] if keyword.lower() in email.Subject.lower()), None)
                                self.debug_print(f"Exception matched keyword in subject: {matched_keyword}")
                                self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")

                        # Check body keywords in exceptions
                        if 'body' in exceptions:
                            if any(keyword.lower() in email.Body.lower() for keyword in exceptions['body']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['body'] if keyword.lower() in email.Body.lower()), None)
                                self.debug_print(f"Exception matched keyword in body: {matched_keyword}")
                                self.debug_print(f"Body: {self._sanitize_string(email.Body)}")

                        # Check header keywords in exceptions
                        if 'header' in exceptions:
                            if any(keyword.lower() in email_header for keyword in exceptions['header']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['header'] if keyword.lower() in email_header.lower()), None)
                                self.debug_print(f"Exception matched keyword in header: {matched_keyword}")
                                for header in email_header.splitlines():
                                    self.debug_print(f"Header: {header}")

                        # # Check for attachments - not using. could be added later - will need to be updated; will not work as-is
                        # if 'has_attachments' in conditions:
                        #     if bool(email.Attachments.Count > 0) != conditions['has_attachments']:
                        #         match = False

                        if match:
                            self.debug_print(f"Email matches rule: {rule['name']}")
                            # Perform actions based on the rule
                            actions = rule['actions']
                            self.debug_print(f"Performing actions: {actions}")
                            if 'assign_to_category' in actions and actions['assign_to_category']['category_name']:
                                rule_name = rule['name']
                                category_name = self.rule_to_category.get(rule_name, actions['assign_to_category']['category_name'])
                                email.Categories = category_name
                                email.Save()
                                self.debug_print(f"Email assigned to category '{category_name}'")
                            if 'assign_to_category' in actions and actions['assign_to_category']['category_name']:
                                # ***category name is not being passed.  Will setup a table per email rule to assign it "semi-manually"
                                email.Categories = actions['assign_to_category']['category_name']
                                email.Save()
                                self.debug_print(f"Email assigned to category '{actions['assign_to_category']['category_name']}'")
                            if 'mark_as_read' in actions and actions['mark_as_read']:
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                                email.UnRead = False
                                self.debug_print("Email marked as read")
                            if 'clear_flag' in actions and actions['clear_flag']:
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                                email.Flag.Clear()
                                self.debug_print("Email flag cleared")
                            if 'set_importance' in actions and actions['set_importance']['importance_level']:
                                email.Importance = actions['set_importance']['importance_level']
                                email.Save()
                                self.debug_print(f"Email importance set to {actions['set_importance']['importance_level']}")
                            if 'set_sensitivity' in actions and actions['set_sensitivity']['sensitivity_level']:
                                email.Sensitivity = actions['set_sensitivity']['sensitivity_level']
                                email.Save()
                                self.debug_print(f"Email sensitivity set to {actions['set_sensitivity']['sensitivity_level']}")
                            if 'mark_as_task' in actions and actions['mark_as_task']['task_due_date']:
                                email.TaskDueDate = actions['mark_as_task']['task_due_date']
                                email.Save()
                                self.debug_print(f"Email marked as task with due date: {actions['mark_as_task']['task_due_date']}")
                            if 'play_sound' in actions and actions['play_sound']['sound_file']:
                                import winsound
                                winsound.PlaySound(actions['play_sound']['sound_file'], winsound.SND_FILENAME)
                                self.debug_print(f"Played sound: {actions['play_sound']['sound_file']}")
                            if 'display_desktop_alert' in actions and actions['display_desktop_alert']:
                                self.debug_print("Desktop alert displayed")
                                # Implement desktop alert display logic here
                            if 'copy_to_folder' in actions and actions['copy_to_folder']['folder_name']:
                                folder_name = actions['copy_to_folder']['folder_name']
                                target_folder = self.target_folder.Folders[folder_name]
                                email.Copy().Move(target_folder)
                                self.debug_print(f"Email copied to '{folder_name}' folder")
                            if 'forward' in actions and actions['forward']:
                                forward_recipients = [recipient['address'] for recipient in actions['forward']]
                                forward_email = email.Forward()
                                forward_email.To = ";".join(forward_recipients)
                                forward_email.Send()
                                self.debug_print(f"Email forwarded to: {', '.join(forward_recipients)}")
                            if 'reply' in actions and actions['reply']['template']:
                                reply_email = email.Reply()
                                reply_email.Body = actions['reply']['template']
                                reply_email.Send()
                                self.debug_print("Auto-reply sent")
                            if 'redirect' in actions and actions['redirect']:
                                redirect_recipients = [recipient['address'] for recipient in actions['redirect']]
                                redirect_email = email.Forward()
                                redirect_email.To = ";".join(redirect_recipients)
                                redirect_email.Send()
                                self.debug_print(f"Email redirected to: {', '.join(redirect_recipients)}")
                            if 'print' in actions and actions['print']:
                                email.PrintOut()
                                self.debug_print("Email printed")
                            if 'run_script' in actions and actions['run_script']['script_path']:
                                exec(open(actions['run_script']['script_path']).read())
                                self.debug_print(f"Script executed: {actions['run_script']['script_path']}")
                            if 'start_application' in actions and actions['start_application']['application_path']:
                                import subprocess
                                subprocess.Popen(actions['start_application']['application_path'])
                                self.debug_print(f"Application started: {actions['start_application']['application_path']}")
                            if 'move_to_folder' in actions and actions['move_to_folder']['folder_name']:
                                folder_name = actions['move_to_folder']['folder_name']
                                target_folder = self.target_folder.Folders[folder_name]
                                email.Move(target_folder)
                                self.debug_print(f"Email moved to '{folder_name}' folder")
                            if 'stop_processing_more_rules' in actions and actions['stop_processing_more_rules']:
                                self.debug_print("Stopping processing more rules")
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                            if 'delete' in actions and actions['delete']:
                                if email.UnRead:
                                    email.UnRead = False  # Delete implies marking the item as read
                                    self.debug_print(f"Email marked as read")
                                if hasattr(email, 'Flag'):
                                    email.Flag.Clear()      # Delete implies clearing the flag
                                    self.debug_print(f"Email flag was cleared")
                                # assign category based on rule name
                                try:
                                    rule_name = rule['name']
                                    category_name = self.rule_to_category.get(rule_name, actions['assign_to_category']['category_name'])
                                    email.Categories = category_name
                                    email.Save()
                                    self.debug_print(f"Email assigned to category '{category_name}'")
                                except Exception as e:
                                    self.debug_print(f"Error assigning category to email: {str(e)}")

                                try:
                                    # delete email
                                    email.Delete()
                                    email_deleted = True
                                    self.debug_print("Email: marked as read, flag cleared and deleted")
                                    # delete implies "Stop Processing More Rules".  Continue will go to next email
                                except Exception as e:
                                    self.debug_print(f"Error deleting email: {str(e)}")

                                break # If delete, then process no more rules and go to next email
                            continue  # Go to the next email if one rule matches

                    # After all email rules are processed and it did not match any rules and the email has not been deleted, then check for phishing indicators
                    if not (email_deleted):
                        indicators = self.check_phishing_indicators(email)
                        if indicators:
                            flagged_count += 1
                            self.debug_print(f"Phishing indicators found: {indicators}")
                        else:
                            self.debug_print("No conditions or phishing indicators found")
                        # If it is in the Bulk Mail folder, but nothing indicated via rules or phishing,
                        # show the body and header, so we information needed to add it to a rule
                        for line in email.Body.splitlines():
                            self.debug_print(f"Body: {line}")
                        for header in email_header.splitlines():
                            self.debug_print(f"Header: {header}")


                except Exception as e:
                    self.debug_print(f"Error processing email: {str(e)}")

            self.debug_print(f"\nProcessing Summary:")
            self.debug_print(f"Processed {processed_count} emails")
            self.debug_print(f"Flagged {flagged_count} emails as suspicious")

        except Exception as e:
            self.debug_print(f"Error in process_emails: {str(e)}")
            raise

# %%
"""Main function to run the security agent"""
try:
    print("\nStarting Outlook Security Agent with DEBUG = {DEBUG}")
    print("This will make changes")
    print("Check the console output and outlook_security.log for detailed information")

    # Initialize agent with debug mode enabled
    agent = OutlookSecurityAgent()  # call with defaults
    rules_json = agent.get_outlook_rules()
    #print(rules_json)

    # Process last 24 hours of emails
    agent.process_emails(rules_json)

    print("Complete. Check the log file for detailed analysis.\n\n")

except Exception as e:
    print(f"\nError: {str(e)}")
    logging.error(f"Main execution error: {str(e)}")
# Out:
# Starting Outlook Security Agent with DEBUG = {DEBUG}
# This will make changes
# Check the console output and outlook_security.log for detailed information
# 2025-01-15 16:34:51,358 - DEBUG - Initializing agent for kimmeyharold@aol.com, folder: Bulk Mail
# 2025-01-15 16:34:51,359 - DEBUG - Debug mode: True
# 2025-01-15 16:34:51,361 - DEBUG - Searching for folder: Bulk Mail in account: kimmeyharold@aol.com
# 2025-01-15 16:34:51,369 - DEBUG - Checking account: kimmeyharold@aol.com
# 2025-01-15 16:34:51,377 - DEBUG - Found matching account: kimmeyharold@aol.com
# 2025-01-15 16:34:51,385 - DEBUG - Accessed root folder: kimmeyharold@aol.com
# 2025-01-15 16:34:51,388 - DEBUG - Found target folder directly: Bulk Mail
# 2025-01-15 16:34:51,389 - DEBUG - Converting Outlook rules to JSON format...
# 2025-01-15 16:34:51,396 - DEBUG - Processing 7 rules...
# 2025-01-15 16:34:51,399 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:51,407 - DEBUG - Conditions['from']: []
# 2025-01-15 16:34:51,410 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,417 - DEBUG - Conditions_obj.Body.Text: None
# 2025-01-15 16:34:51,427 - DEBUG - Conditions_obj.MessageHeader.Text: ('@janiejournal.xyz', 'Construction-JobSearch', 'flexiglobal.fun', 'liftabl.com', '@pactera.com', 'teckrappid.com', 'earlyreviewer@gmail.com', '@cold-comforts.com', '@thebestservice.club', '@promotionsanddeals.club', '@newsdarts.com', 'royamail.uk', '@primarymash.store', 'sctelco.net.au', 'summernew.club', 't-online.de', '@customguide.com', 'blabber.buzz', '@darkrhinosecurity.com', '@vgroupinc.com', 'your-great.site', '@tecksuite.com', 'excelerplan.com', 'promotionoffer.site', '@largeteck.com', '@simon-jones.com', '@offers.com', '@melateck.com', '@amextop.com', 'kemo7766@yahoo.com', 'lindsay.moran@roberthalf.com', 'mapjobz.com', 'mccarthysearch.com', 'ppdptn@yahoo.com', 'cpm-masters.com', 'dealsketo.store', 'runtym.com', 'thinkurmails.com', 'jyothivkr@yahoo.com', '@parlermailer.com', '@niceteck.com', '@rankteck.com', '@nutritops.com', '@freedomworks.org', 'thedailymaurisa.xyz', 'janieable.store', 'taskomania.com', 'leonsecretdiary.club', 'shortplanks.xyz', 'ledenipe.store', 'mcbc22.gq', 'arelocations.in', 'randony.com', 'huvrcam.com', '@offeo.com', 'vividseats.com', 'thealbertejournal.site', 'viralfitzone.com', 'mSvcrenewyoucompany.com', 'mvTqrenewyoucompany.com', '.com.au', 'email.nbc.com', '@bellaliant.net', 'nosecretdiary.club', 'offersal-foryou.club', '@axelon.com', '@ozy.com', '@teckviews.com', '@qemailserver.com', 'onlythenews.site', 'trythisnew.online', 'Brianna John', '@thebarnesjournal.xyz', 'ZudCahaana.org', '@offers.com', 'googlegroups.com', 'getreadyfornews.onlin', '@techoneit.com', 'underarmour.com', '@wtocook.info', '@textingoverload.club', '@themasonpost.club', '@russelldiary.xyz', '@nedfsdkjds.com', '@spitefulblog.club', '@widevastblog.club', '@smartdiety.info', '@theangelajournal.club', '@drummingfreak.xyz', '@redskymaurisa.xyz', '@thecornwalltimes.xyz', 'amzlockedcustomer.com', '@theruizpost.xyz', '@epm-power.com', 'scoutbazaar.one', 'drjtechservice@gmail.com', '@alberteable.club', '@promotionoffer.online', '.co.nz', '@sites.careerbuilder.com', 'russeltimes.club', '@xfaggert.com', '@niceplans.fun', '@dealoffers.xyz', '@customerdept.me', 'evacuatedtech.com', '@turing.com', '@zintro.com', '@flipjobz.com', '@smarttobehere.fun', '@bora.net', 'oriental-trading.com', 'buysub.com', 'pwsj.com', '@varite.com', 'smartoffers.sho', '@sandysmithnc.com', '@hotdealls.shop', '@affiliteo.shop', 'thenickjournal.club', 'va5x.com', '@dancetotune.club', '@offfers.com', '@reedsy.com', '@ebatesfocus.com', 'zou9lou9.com', 'wptavern.com', '.safeopt.com', '@turing.jp', 't-op-offer.com', '@alignable.com', '.arlo.com', '@therussellpost.club', '@freaksday.com', '@porsuite.online', '@happycart.space', '@agentofficemail.com', '@techotechs.com', '@turing.bz', 'addto-cart.co.uk', '@servupdt.com', 'thedailyleon.xyz', '@diverselynx.com', 'nickdiary.xyz', 'wingrinandbearit.com', '@winreality.com', '.xyz', '@wireaustralia.com', '@cpm-pros.com', 'vegol4.live', 'your-smartoffers.club', '@tesca.id', '@healthyish.icu', '@allieolson.work', 'frex.com.au', '@lifecrest.best', '@therusselltoday.store', 'owls@onmicrosoft.work', '@sandysmithnc.com', '@theartofdrumming.fun', '@bakedrumread.store', '@promotionoffers.club', 'janiesecretdiary.club', '.club', '.shop', 'seven7them.com', 'realsimple.com', 'instyle.com', 'offerdeals.co', 'fostertoday.fun', 'sommodrive.com', 'bricklinik.com', 'hnjzsjmh.mobi', '@niceday.online', 'conservativedailyalerts.com', 'gilzine.com', 'primaryhackney.uk', 'virtualrealitymarketing.com', '.co.uk', '@news555.org', 'theonlygreeting.com', 'herculesinstitute.com', 'cbblacksmiths.com', 'cosmicrewards.com', 'szkolnastrona.pl', 'hgemail.net', 'anthonyflowers0.com', 'juicysiren.icu', 'moen.com', '@turing.ac', '@limitgov.org', 'salsalabs.org', '@PMCentersUSA.com', 'fecunited.com', '@assumptionu.org', '@smuniversity.org', 'bedojedid.com', '@newoffers.space', '@artnostyle.com', 'thesalmonteam.store', '@topoffers-foryou.cfd', 'thefactteam.store', 'Lifetime.Life', 'lifetime ...
# 2025-01-15 16:34:51,446 - DEBUG - AssignToCategory action found, category_name: None
# 2025-01-15 16:34:51,475 - DEBUG - Exception conditions['from']: [{'address': 'store+61395140851@t.shopifyemail.com', 'name': 'store+61395140851@t.shopifyemail.com'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}]
# 2025-01-15 16:34:51,478 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,484 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', 'email.openai.com', 'lastpass.com', 'shopifyemail.com')
# 2025-01-15 16:34:51,491 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '.openai.com', '@lastpass.com')
# 2025-01-15 16:34:51,496 - DEBUG - Successfully processed rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:51,498 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteBody
# 2025-01-15 16:34:51,505 - DEBUG - Conditions['from']: []
# 2025-01-15 16:34:51,508 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,517 - DEBUG - Conditions_obj.Body.Text: ('Denton Bay Management', 'Deutsche Bank', 'position of Package Manager', 'for Parcel Worker', 'Capital Funding, LLC', 'Title: Package Manager', 'Organization of African Unity', 'United Nations Compensation Commission', 'First Marsh Capital Funding', 'Pack Supervisor', 'CWCramer Investments', 'namestee-redirect-71.blogspot.com', 'Space Tree Technologies', 'webruu.com', 'grco.de', 'allthebest.club', 'angel.aau.biz', 'tosbackrido', 'wewe.digital', 'allforyou.store', 'sys-confg.co.uk/cl/', 'chaiflow.com', 'd-allthebest', 'crescentsch', 'beautifyblog.com', 'get to shag even', 'haveshckee.site', 'beautytoto.site', 'booktarmedia.site', 'bostoffers.com', 'buttonlike.site', 'bangdgood', 'stylepekomed.site', 'Camp Lejeune', 'Topamax', 'erankolgds', 'lhatak.art', 'rani.live', 'iwantgetaway.', '/yeksabardo.', '/nortteh.', '/beliastick.', '/babysharkystore', '/radreact.com', 'ddaskeid.us', '/molbaydtr.', '/cdn.discordapp.com', '/poorlocation.site', '/lunansas.com', '/institution.store', '/lomerna.cc', '/cahamsonsmakj.art', '/thechnolotern.com', '/blueberrystore.site', '/adamshetzner.', '/elfinmarriage.', '/lasanteur.com', '/cidowien.com', '/auenwind', '/egsro.com/', '/50.193.138.95', '/new-word.co.uk', '/sazlompi.shop', '/superappoint.site', '/aressive.com', '/bangalarood', '/babyalicea', '/chitanodaily', '/nonosfertop', '/loppey.com/', '/cariable.com', '/zupimages.net', 'francescamaceroni', '/brevele.com', 'marmou.store/', '/bogmil', '/twentifyin', 'cahamsonsmakj.art/', 'poneytelecom.eu/', '/satucart.com', '/britiquare.com', '/graspect.com', '.graspect.com', '.yeksabardo.', '.britiquare.com', '.satucart.com', '.twentifyin', '.bogmil', '.brevele.com', '.zupimages.net', '.cariable.com', '.loppey.com/', '.nonosfertop', '.chitanodaily', '.babyalicea', '.bangalarood', ',aressive.com', '.superappoint.', '.sazlompi.', '.new-word.co', '.egsro.', '.auenwind.', '.cidowien.', '.lasanteur.', '.elfinmarriage.', '.adamshetzner.', '.blueberrystore.', '.thechnolotern.', '.cahamsonsmakj.', '.lomerna.', '.institution.store', '.lunansas.', '/vertnajd.shop', '.vertnajd.', '.complication.online', '.poorlocation.', '.cdn.discordapp.com', '.molbaydtr.', '.ddaskeid.', '.radreact.', '.kunsttherapie.', '/kunsttherapie.', '.babysharkystore.', '.beliastick.', '.nortteh.', '.yeksabardo.', '.rani.', '.lhatak.', '.stylepekomed.', '.beautytoto.', '.haveshckee.', '/thechnolotern.com', '.thechnolotern.', '.beautifyblog.', '.chaiflow.', '.allforyou.', '.auu.biz', 'unvonvrslrfvstty.', 'canvvas.', '.duckdns.', 'irishpeddlernow.', 'd-allthebest.', 'leadpha.', '/netflix-inmcsupport.', '/valenpod.', '.valenpod.', 'bitomagic.', 'shringrade.', 'shrturi.', 'ewesnesice.', '.com.au', 'maurisable.', 'trending-offers.', 'dailygerald.', '.searshomeservices.com', '/searshomeservices.', '/stlhalfmarathon', '.stlhalfmarathon', '/conferrific.com', '.conferrific.com', '.easiereats.', '/easiereats', '/pauligures.', '.pauligures.', '.differenchiopia.', '/differenchiopia.', '.wordthirst.', '/wordthirst.', '/trestaro.', '.trestaro.', '/buyplaydiscover.', '.buyplaydiscover.', '/spherings.', '.spherings.', '/linepregnant', '.linepregnant', '/campgumus', '/adventurousamend.', '.adventurousamend.', 'cyclinth.com', 'reflectrum.com', 'ransferrible.com', 'mailbestusa.', 'powerrecruiter.', '/swarm-stone.', '.swarm-stone.', '.marsello.com', '.macibe.com', '/macibe.com', '/screepin.com', '.screepin.com', '/garriests.com', '.garriests.com', 'schoolofwordplay.', '/ktirff.com', '.ktirff.com', '/edcpub.com', '.edcpub.com', '/thronical.com', '.thronical.com', '.iasgk.com', '/iasgk.com', '.stransferrel.com', '/stransferrel.com', '.yesterin.com', '/yesterin.com', '.alsaqqr.com', '/alsaqqr.com', 'synonymoustransfer', '213.226.189.211/', '/oneway-level.com', '.oneway-level.com', '.xiken.top', '/xiken.top', '/anyuying.top', '.anyuying.top', '.feelbmico.com', '/feelbmico.com', '.mightrays.com', '/mightrays.com', '.drbubcho.com', '.standtro.com', '/standtr ...
# 2025-01-15 16:34:51,526 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-01-15 16:34:51,542 - DEBUG - AssignToCategory action found, category_name: None
# 2025-01-15 16:34:51,582 - DEBUG - Exception conditions['from']: [{'address': 'ebilling_noreply@ClevelandWater.com', 'name': 'ebilling_noreply@ClevelandWater.com'}, {'address': 'eBilling@NEORSD.org', 'name': 'eBilling@NEORSD.org'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}, {'address': 'app@clover.com', 'name': 'app@clover.com'}, {'address': 'noreply@email.openai.com', 'name': 'noreply@email.openai.com'}, {'address': 'do-not-reply-support@lastpass.com', 'name': 'do-not-reply-support@lastpass.com'}, {'address': 'support@lastpass.com', 'name': 'LastPass'}, {'address': 'store+61395140851@t.shopifyemail.com', 'name': 'store+61395140851@t.shopifyemail.com'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}, {'address': 'TrackingUpdates@fedex.com', 'name': 'TrackingUpdates@fedex.com'}, {'address': 'billing@lastpass.com', 'name': 'billing@lastpass.com'}]
# 2025-01-15 16:34:51,585 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,591 - DEBUG - Exception conditions_obj.Body.Text: None
# 2025-01-15 16:34:51,598 - DEBUG - Exception conditions_obj.MessageHeader.Text: None
# 2025-01-15 16:34:51,602 - DEBUG - Successfully processed rule: SpamAutoDeleteBody
# 2025-01-15 16:34:51,603 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteFrom
# 2025-01-15 16:34:51,628 - DEBUG - Conditions['from']: [{'address': 'Solaris@ofefrsdtops.net', 'name': 'Solaris | Eco'}, {'address': 'Talcum@ofefrsdtops.net', 'name': 'Talcum Powder'}, {'address': 'Saatva@ofefrsdtops.net', 'name': 'Saatva@ofefrsdtops.net'}, {'address': 'Tractor@ofefrsdtops.net', 'name': 'Tractor@ofefrsdtops.net'}, {'address': 'support@doffersted.online.com', 'name': 'support@doffersted.online.com'}, {'address': 'Renewal@ofefrsdtops.net', 'name': 'Renewal@ofefrsdtops.net'}, {'address': 'House@ofefrsdtops.net', 'name': 'House@ofefrsdtops.net'}, {'address': 'guls@skimccormicks.com', 'name': 'guls@skimccormicks.com'}, {'address': 'centralitys@skimccormicks.com', 'name': 'centralitys@skimccormicks.com'}, {'address': 'thkariedawood@gmail.com', 'name': 'thkariedawood@gmail.com'}, {'address': 'Prostate@hotmail.com', 'name': 'Prostate@hotmail.com'}, {'address': 'Compensation@hotmail.com', 'name': 'Compensation@hotmail.com'}, {'address': 'sebastian@corleoneweddingplanners.com', 'name': 'sebastian@corleoneweddingplanners.com'}]
# 2025-01-15 16:34:51,632 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,638 - DEBUG - Conditions_obj.Body.Text: None
# 2025-01-15 16:34:51,644 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-01-15 16:34:51,660 - DEBUG - AssignToCategory action found, category_name: None
# 2025-01-15 16:34:51,684 - DEBUG - Exception conditions['from']: []
# 2025-01-15 16:34:51,688 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,693 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', 'openai.com', 'lastpass.com')
# 2025-01-15 16:34:51,701 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@tcsjerky.com', '@NEORSD.org', '@clover.com', '@email.openai.com', '@lastpass.com', 'store+61395140851@t.shopifyemail.com')
# 2025-01-15 16:34:51,705 - DEBUG - Successfully processed rule: SpamAutoDeleteFrom
# 2025-01-15 16:34:51,708 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteSubject
# 2025-01-15 16:34:51,715 - DEBUG - Conditions['from']: []
# 2025-01-15 16:34:51,719 - DEBUG - Conditions_obj.Subject.Text: ('online dating', 'AARP', 'Nugenix', 'nugenix', 'romantic relationship', 'dating site', 'dating website', 'one night stand', 'Walmart Surprise', 'Life Line', 'desire a lady', 'Home Warranty', 'home warranty', 'Topamax', 'topamax', 'Online Casino', 'online casino', 'Pro Lights', 'pro lights', 'Harbor Freight', 'harbor freight', '5-second morning hack', 'Valvoline Oil', 'valvoline oil', 'one night stand', 'Norton-Anti-Virus', 'norton-Anti-Virus', 'norton-anti-virus', 'norton anti-virus', 'Construction-JobSearch', 'trumpvictory45', 'trumpvictory47', 'eharmony', 'ready for a relationship', 'dates with me', 'Proud Patriots', 'dating me')
# 2025-01-15 16:34:51,725 - DEBUG - Conditions_obj.Body.Text: None
# 2025-01-15 16:34:51,732 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-01-15 16:34:51,747 - DEBUG - AssignToCategory action found, category_name: None
# 2025-01-15 16:34:51,771 - DEBUG - Exception conditions['from']: []
# 2025-01-15 16:34:51,774 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,781 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', '.clover.com', '/clover.com', '.openai.com', '/openai.com', '.lastpass.com', '/lastpass.com', '.aa.com', '/aa.com', '.ftc.com', '/ftc.com', 'kaggle', '.shopifyemail.com', '/shopifyemail.com')
# 2025-01-15 16:34:51,788 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '.openai.com', '@lastpass.com', '@aa.com', '@ftc.com', 'kaggle')
# 2025-01-15 16:34:51,793 - DEBUG - Successfully processed rule: SpamAutoDeleteSubject
# 2025-01-15 16:34:51,795 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:34:51,803 - DEBUG - Conditions['from']: []
# 2025-01-15 16:34:51,806 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,812 - DEBUG - Conditions_obj.Body.Text: ('.imgur.', '/imgur.')
# 2025-01-15 16:34:51,819 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-01-15 16:34:51,834 - DEBUG - AssignToCategory action found, category_name: None
# 2025-01-15 16:34:51,859 - DEBUG - Exception conditions['from']: []
# 2025-01-15 16:34:51,862 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-01-15 16:34:51,868 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', '.openai.com', '/openai.com', 'lastpass.com', '/aa.com', '.aa.com', '.ftc.com', '/ftc.com')
# 2025-01-15 16:34:51,874 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('scottkimmey1@gmail.com', '@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '@email.openai.com', '@lastpass.com', '@t.shopifyemail.com', '@aa.com', 'kaggle', '@ftc.gov')
# 2025-01-15 16:34:51,879 - DEBUG - Successfully processed rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:34:51,885 - DEBUG -
#
# Starting email processing (Simulation Mode)
# 2025-01-15 16:34:51,886 - DEBUG - Target folder: Bulk Mail
# 2025-01-15 16:34:51,886 - DEBUG - Processing emails from last 365 days
# 2025-01-15 16:34:51,892 - DEBUG - Total emails found: 2231
# 2025-01-15 16:34:51,892 - DEBUG - Beginning email analysis:
# 2025-01-15 16:34:52,703 - DEBUG -
#
# Email 1:
# 2025-01-15 16:34:52,703 - DEBUG - Subject: Urgent: Your McAfee Total Protection Has Expired! Renew Now to Stay
# 2025-01-15 16:34:52,703 - DEBUG - From: info@gufqklhtj.jp.net
# 2025-01-15 16:34:52,703 - DEBUG - Received: 2025-01-13 13:48:24+00:00
# 2025-01-15 16:34:52,813 - DEBUG - Matched keyword in body: .imgur.
# 2025-01-15 16:34:52,814 - DEBUG - First line of body that matches the keyword:  <https://i.imgur.com/lLEquZe.png>
# 2025-01-15 16:34:52,815 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:34:52,816 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:52,835 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-01-15 16:34:52,849 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:52,868 - DEBUG -
#
# Email 2:
# 2025-01-15 16:34:52,869 - DEBUG - Subject: Celebrate the New Year with MAHA: Shop Now!
# 2025-01-15 16:34:52,871 - DEBUG - From: info@teamkennedy.com
# 2025-01-15 16:34:52,872 - DEBUG - Received: 2025-01-13 13:12:01+00:00
# 2025-01-15 16:34:53,078 - DEBUG - Matched keyword in body: .sendgrid.net
# 2025-01-15 16:34:53,078 - DEBUG - First line of body that matches the keyword:  <https://u32902740.ct.sendgrid.net/wf/open?upn=u001.I4UK-2BKzjyL9nJn9zZLlWLe2RNFpNcYr-2Biv5XIctR2Qy3hQO5R0eFDTfhqIJqQpRtXFKrC0ajBVB7UrrQScvTrKnQEVRbwU0QHkA8nmF9Gy-2FA-2FfEhUyyes-2FZ61VVf6LuWTaQaENGohbB8chLMBQUTqGEcx-2B6pWZTxdU7QCfTyodKJDDdBbJU8mIKTU8aGW2j2wx3wBi-2F4xlwgkSvW7Fr8rgeRZYjyCQWDa2iaDQKPsAJ1KQ6y3Xo76EAA0zBFn15QdOIbmAPVZPPjeB274vCZB35Fk9tivo2Q4FcU1PrrlTK2WerdZ5e1of782VXnY642EsW5T3NAgb27FS3oF-2FSHi-2B8laOl9BUl2jqtTie9dm5K1P1QwM71BLOZgvijrVRfYW63W2DLRk2T-2BGCO10x8a8X2lZ1Et2iLl8dSuV3aDFQo-3D>
# 2025-01-15 16:34:53,080 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,080 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,088 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,104 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,115 - DEBUG -
#
# Email 3:
# 2025-01-15 16:34:53,116 - DEBUG - Subject: Reminder: we'd love to hear from you
# 2025-01-15 16:34:53,117 - DEBUG - From: hp-feedback@feedback.hp.com
# 2025-01-15 16:34:53,118 - DEBUG - Received: 2025-01-13 12:52:16+00:00
# 2025-01-15 16:34:53,274 - DEBUG - Matched keyword in body: qualtrics.
# 2025-01-15 16:34:53,274 - DEBUG - First line of body that matches the keyword: This survey is being conducted by Qualtrics on behalf of HP Inc. Qualtrics a global leader in enterprise feedback management does not use this information for any other purposes. To review Qualtrics privacy policy, please visit Qualtrics Privacy Policy <https://www.qualtrics.com/privacy-statement/> .
# 2025-01-15 16:34:53,276 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,276 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,282 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,292 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,302 - DEBUG -
#
# Email 4:
# 2025-01-15 16:34:53,303 - DEBUG - Subject: VA Benefit Survey For
# 2025-01-15 16:34:53,304 - DEBUG - From: info@rjmqwkvgs.jp.net
# 2025-01-15 16:34:53,305 - DEBUG - Received: 2025-01-13 11:07:43+00:00
# 2025-01-15 16:34:53,320 - DEBUG - Matched keyword in body: /zupimages.net
# 2025-01-15 16:34:53,321 - DEBUG - First line of body that matches the keyword:  <https://zupimages.net/up/25/02/emno.jpeg>
# 2025-01-15 16:34:53,322 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,322 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,329 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,338 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,359 - DEBUG -
#
# Email 5:
# 2025-01-15 16:34:53,361 - DEBUG - Subject: Asian Sex Cult Penis Ritual Leaked (Disturbing Video)
# 2025-01-15 16:34:53,362 - DEBUG - From: info@lkrcryzkj.jp.net
# 2025-01-15 16:34:53,363 - DEBUG - Received: 2025-01-13 10:56:01+00:00
# 2025-01-15 16:34:53,378 - DEBUG - Matched keyword in body: /zupimages.net
# 2025-01-15 16:34:53,378 - DEBUG - First line of body that matches the keyword:  <https://zupimages.net/up/25/01/r3pb.jpeg>
# 2025-01-15 16:34:53,380 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,380 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,382 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,393 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,403 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,414 - DEBUG -
#
# Email 6:
# 2025-01-15 16:34:53,415 - DEBUG - Subject: Give the Gift of Peace of Mind This Holiday Season
# 2025-01-15 16:34:53,416 - DEBUG - From: cooking@n4.commandcooking.com
# 2025-01-15 16:34:53,417 - DEBUG - Received: 2025-01-13 10:52:52+00:00
# 2025-01-15 16:34:53,419 - DEBUG - Matched keyword in header: .commandcooking.
# 2025-01-15 16:34:53,419 - DEBUG - First line of header that matches the keyword: 	by i-0ebcbcd70832b2f53.mta1vsmtp.sd.prd.sparkpost (envelope-from <cooking@r.n4.commandcooking.com>)
# 2025-01-15 16:34:53,422 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,423 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,429 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,443 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:53,454 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,471 - DEBUG -
#
# Email 7:
# 2025-01-15 16:34:53,473 - DEBUG - Subject: Put Interest On Ice Until Nearly 2026
# 2025-01-15 16:34:53,475 - DEBUG - From: jokes@smtp2.mydailyjoke.com
# 2025-01-15 16:34:53,478 - DEBUG - Received: 2025-01-13 10:39:30+00:00
# 2025-01-15 16:34:53,482 - DEBUG - Matched keyword in header: mydailyjoke.com
# 2025-01-15 16:34:53,483 - DEBUG - First line of header that matches the keyword: Reply-To: "My Daily Joke" <jokes@smtp2.mydailyjoke.com>
# 2025-01-15 16:34:53,487 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,487 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,489 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,500 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:53,511 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,525 - DEBUG -
#
# Email 8:
# 2025-01-15 16:34:53,526 - DEBUG - Subject:  Alert: Spot Prices Down + Weekly Deals Live
# 2025-01-15 16:34:53,527 - DEBUG - From: jmbullioncom@jmbullion.com
# 2025-01-15 16:34:53,528 - DEBUG - Received: 2025-01-13 10:37:23+00:00
# 2025-01-15 16:34:53,531 - DEBUG - Matched keyword in header: @jmbullion.com
# 2025-01-15 16:34:53,531 - DEBUG - First line of header that matches the keyword: From: "JM Bullion" <jmbullioncom@jmbullion.com>
# 2025-01-15 16:34:53,537 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,538 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,541 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,562 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:53,579 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,593 - DEBUG -
#
# Email 9:
# 2025-01-15 16:34:53,594 - DEBUG - Subject: Final Reminder - Free Gift Waiting for You at CVS!
# 2025-01-15 16:34:53,595 - DEBUG - From: CVS@offeestor.info
# 2025-01-15 16:34:53,596 - DEBUG - Received: 2025-01-13 10:34:46+00:00
# 2025-01-15 16:34:53,733 - DEBUG - Matched keyword in body: This message is from a trusted sender
# 2025-01-15 16:34:53,733 - DEBUG - First line of body that matches the keyword: This message is from a trusted sender.
# 2025-01-15 16:34:53,735 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,735 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,737 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,750 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,762 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,777 - DEBUG -
#
# Email 10:
# 2025-01-15 16:34:53,779 - DEBUG - Subject: kimmeyharold, Learn How to Bring Your Power Bill to Almost Zero
# 2025-01-15 16:34:53,780 - DEBUG - From: noreply@p2bi.com
# 2025-01-15 16:34:53,781 - DEBUG - Received: 2025-01-13 10:30:55+00:00
# 2025-01-15 16:34:53,796 - DEBUG - Matched keyword in body: /zupimages.net
# 2025-01-15 16:34:53,796 - DEBUG - First line of body that matches the keyword:  <https://zupimages.net/up/24/45/kn4m.png>
# 2025-01-15 16:34:53,798 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:53,799 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,801 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,813 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:53,839 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,853 - DEBUG -
#
# Email 11:
# p(p- ppp+ppp+bSubject: b( pp%ppp' pp&pp+p-pp+, p
# 2025-01-15 16:34:53,856 - DEBUG - From: Synoshi@offeestor.com
# 2025-01-15 16:34:53,856 - DEBUG - Received: 2025-01-13 10:03:26+00:00
# 2025-01-15 16:34:53,859 - DEBUG - Matched keyword in header: @offeestor.com
# 2025-01-15 16:34:53,859 - DEBUG - First line of header that matches the keyword: From: "Effortless Cleaning" <Synoshi@offeestor.com>
# 2025-01-15 16:34:53,861 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,861 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,863 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,877 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:53,889 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,903 - DEBUG -
#
# Email 12:
# 2025-01-15 16:34:53,905 - DEBUG - Subject: Hair Loss Mystery Solvedb
# 2025-01-15 16:34:53,906 - DEBUG - From: HairLoss@offeestor.com
# 2025-01-15 16:34:53,906 - DEBUG - Received: 2025-01-13 10:01:32+00:00
# 2025-01-15 16:34:53,909 - DEBUG - Matched keyword in header: @offeestor.com
# 2025-01-15 16:34:53,909 - DEBUG - First line of header that matches the keyword: From: "All Natural Solution" <HairLoss@offeestor.com>
# 2025-01-15 16:34:53,910 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,911 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,914 - DEBUG - Email marked as read
# 2025-01-15 16:34:53,926 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:53,938 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:53,951 - DEBUG -
#
# Email 13:
# 2025-01-15 16:34:53,952 - DEBUG - Subject: Addictive Broccoli Salad
# 2025-01-15 16:34:53,953 - DEBUG - From: cooking@smtp1.recipesaver.com
# 2025-01-15 16:34:53,954 - DEBUG - Received: 2025-01-13 09:53:59+00:00
# 2025-01-15 16:34:53,959 - DEBUG - Matched keyword in header: recipesaver.com
# 2025-01-15 16:34:53,959 - DEBUG - First line of header that matches the keyword: Reply-To: "Recipe Saver" <cooking@smtp1.recipesaver.com>
# 2025-01-15 16:34:53,963 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:53,963 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:53,965 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,001 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:54,014 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,030 - DEBUG -
#
# Email 14:
# 2025-01-15 16:34:54,031 - DEBUG - Subject: Gt A High Lvl Of Vehicle Protection For A Low Monthly Cost
# 2025-01-15 16:34:54,032 - DEBUG - From: noreply@p2bi.com
# 2025-01-15 16:34:54,032 - DEBUG - Received: 2025-01-13 09:51:12+00:00
# 2025-01-15 16:34:54,045 - DEBUG - Matched keyword in body: /zupimages.net
# 2025-01-15 16:34:54,046 - DEBUG - First line of body that matches the keyword:  <https://zupimages.net/up/24/48/3gu4.png>
# 2025-01-15 16:34:54,047 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:54,047 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:54,049 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,063 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:54,076 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,090 - DEBUG -
#
# Email 15:
# 2025-01-15 16:34:54,091 - DEBUG - Subject:  Tired of Unexpected Car Repair Bills? We Have Your Fix!
# 2025-01-15 16:34:54,092 - DEBUG - From: support@onlinesdeals.com
# 2025-01-15 16:34:54,093 - DEBUG - Received: 2025-01-13 09:49:40+00:00
# 2025-01-15 16:34:54,227 - DEBUG - Matched keyword in body: This message is from a trusted sender
# 2025-01-15 16:34:54,227 - DEBUG - First line of body that matches the keyword: This message is from a trusted sender.
# 2025-01-15 16:34:54,229 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:34:54,229 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:54,231 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,245 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:34:54,284 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,304 - DEBUG -
#
# Email 16:
# 2025-01-15 16:34:54,306 - DEBUG - Subject: p Amazing Savings and Total Peace of Mindb
# 2025-01-15 16:34:54,307 - DEBUG - From: LibertyHomeGuard@ofefrsdtops.net
# 2025-01-15 16:34:54,308 - DEBUG - Received: 2025-01-13 09:40:16+00:00
# 2025-01-15 16:34:54,310 - DEBUG - Matched keyword in header: @ofefrsdtops.net
# 2025-01-15 16:34:54,310 - DEBUG - First line of header that matches the keyword: From: "Liberty Home Guard Warranty" <LibertyHomeGuard@ofefrsdtops.net>
# 2025-01-15 16:34:54,314 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:54,315 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:54,316 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,332 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:54,346 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,360 - DEBUG -
#
# Email 17:
# 2025-01-15 16:34:54,362 - DEBUG - Subject: [to]pFree installation and round-the-clock home monitoring-Brinks Home
# 2025-01-15 16:34:54,363 - DEBUG - From: FreeInstall@offeestor.com
# 2025-01-15 16:34:54,364 - DEBUG - Received: 2025-01-13 09:39:29+00:00
# 2025-01-15 16:34:54,367 - DEBUG - Matched keyword in header: @offeestor.com
# 2025-01-15 16:34:54,367 - DEBUG - First line of header that matches the keyword: From: "BrinksHomeOffer" <FreeInstall@offeestor.com>
# 2025-01-15 16:34:54,369 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:54,369 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:54,371 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,385 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:54,430 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,452 - DEBUG -
#
# Email 18:
# 2025-01-15 16:34:54,453 - DEBUG - Subject: Natural discovery enhances size in 14 days
# 2025-01-15 16:34:54,454 - DEBUG - From: Jungle@ofefrsdtops.net
# 2025-01-15 16:34:54,455 - DEBUG - Received: 2025-01-13 09:37:56+00:00
# 2025-01-15 16:34:54,458 - DEBUG - Matched keyword in header: @ofefrsdtops.net
# 2025-01-15 16:34:54,459 - DEBUG - First line of header that matches the keyword: From: "Manhood growth" <Jungle@ofefrsdtops.net>
# 2025-01-15 16:34:54,460 - DEBUG - Email matches rule: SpamAutoDeleteHeader
# 2025-01-15 16:34:54,461 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:34:54,463 - DEBUG - Email marked as read
# 2025-01-15 16:34:54,477 - DEBUG - Email assigned to category 'SpamHeader'
# 2025-01-15 16:34:54,491 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:34:54,507 - DEBUG -
#
# Email 19:
# 2025-01-15 16:34:54,508 - DEBUG - Subject: Introducing the Model 1854 Stealth Hunter by Smith & Wesson
# 2025-01-15 16:34:54,509 - DEBUG - From: marketing@e-email.guns.com
# 2025-01-15 16:34:54,510 - DEBUG - Received: 2025-01-13 09:35:18+00:00
# 2025-01-15 16:34:54,680 - DEBUG - No conditions or phishing indicators found
# 2025-01-15 16:34:54,681 - DEBUG - Body: Elevate Your Shooting Experience...
# 2025-01-15 16:34:54,682 - DEBUG - Body: If this e-mail is not displayed properly, click here. <https://e-clicks.guns.com/u/gm.php?prm=KcjJEPOCZ9_816596386_8597345_1920360&_esuh=_11_9c15417b89df9b951dfc5f4483613e44519372b51cfd27f73e499b06f0a497d9>
# 2025-01-15 16:34:54,682 - DEBUG - Body:
# 2025-01-15 16:34:54,682 - DEBUG - Body:
# 2025-01-15 16:34:54,683 - DEBUG - Body:  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_1&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UrbWRfNzY4NzY1LnBuZw%3D%3D%7CNjU1NTQ1MzQy%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_81b8d088385b83e35639929d0d99127cc945fc108ac49398918d1ca01b56441b>
# 2025-01-15 16:34:54,683 - DEBUG - Body: 	HANDGUNS <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_3&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSEFOREdVTlM%3D%7CNjU1NTQ1MzQ0%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_b5aedeba1777fcd03e2a406bf76a9b541f0d4e948517ad1ea9feeaea392552a4> 	 			RIFLES <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_5&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CUklGTEVT%7CNjU1NTQ1MzQ2%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_ddaa18f5ffc1c0767b0ab278807dbf1ed71812e8d6cc3fffa9124119b021ee67> 	 			SHOTGUNS <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_7&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CU0hPVEdVTlM%3D%7CNjU1NTQ1MzQ4%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_07782f65b4c442df717680e2eddc3cc9a4560ec5397ac3fd0345d93d33366612> 	 			AMMO <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_9&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CQU1NTw%3D%3D%7CNjU1NTQ1MzUw%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_6718a9ff32fe60ad766fae262de8150545ea5e9de9e0284e1763435a372988ec>
# 2025-01-15 16:34:54,684 - DEBUG - Body:  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_11&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UrbWRfMTQ4Mjc5NC5qcGc%3D%7CNjU1NTQ1MzUy%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_aa6f895178d19b2acee5cfd49f59d29e01d07b824a9d509505518dc1a3046276>
# 2025-01-15 16:34:54,684 - DEBUG - Body: STAY CONNECTED:
# 2025-01-15 16:34:54,684 - DEBUG - Body:  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_13&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UrZmFjZWJvb2sucG5n%7CNjU1NTQ1MzU0%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_2f20e13cf56bbf9078f856a158b071a2763b8b350afa69e74efa3f4f0755840d> 	  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_15&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UraW5zdGFncmFtLnBuZw%3D%3D%7CNjU1NTQ1MzU2%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_d75829273e64450663fdc7e91ddf9661b926aba14fb362eb65af9001f6385fea> 	  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_17&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UrdHdpdHRlci5wbmc%3D%7CNjU1NTQ1MzU4%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_848d31f301406d9cb372870d50577ffd825be259433505ccc683c49a5c0e2795> 	  <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_19&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CSU1BR0UreW91dHViZS5wbmc%3D%7CNjU1NTQ1MzYw%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_aeb9b50b0341a45de7b4be73407bb49d0e6c76f0b78b3b88e01fd82e420a5a4c>
# 2025-01-15 16:34:54,685 - DEBUG - Body: To guarantee delivery of this email please add
# 2025-01-15 16:34:54,685 - DEBUG - Body: marketing@e-email.guns.com <mailto:marketing@e-email.guns.com>  to your address book
# 2025-01-15 16:34:54,685 - DEBUG - Body: and safe senders list.	 Please see promotional terms and conditions here <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_21&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CaGVyZQ%3D%3D%7CNjU1NTQ1MzYy%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_83d7992ba823ad6b5435dc4b194c96a1ccdeff842142637de8fec7f39501807f> . Site wide free shipping promotions exclude ammo products, unless otherwise specifically stated
# 2025-01-15 16:34:54,685 - DEBUG - Body:
# 2025-01-15 16:34:54,686 - DEBUG - Body:  For complete Credova disclaimers and disclosures, please visit www.credova.com/disclaimers <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_25&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7Cd3d3LmNyZWRvdmEuY29tJTJGZGlzY2xhaW1lcnM%3D%7CNjU1NTQ1MzY2%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_8b6ea51b04e0c7212f9a4824573492a2d4020d92bb0c47abddfd8e5a8a754263>
# 2025-01-15 16:34:54,686 - DEBUG - Body:
# 2025-01-15 16:34:54,687 - DEBUG - Body: If you no longer wish to receive emails
# 2025-01-15 16:34:54,687 - DEBUG - Body: from Guns.com, you have the option to
# 2025-01-15 16:34:54,687 - DEBUG - Body: unsubscribe here. <https://e-clicks.guns.com/u/un.php?par=KcjJEPOCZ9_8597345_1920360_$sid$&_esuh=_11_3583328a949c5355cd32d720734e522a0504b3ccc151c4790b4546bf0158814a>
# 2025-01-15 16:34:54,688 - DEBUG - Body: This email was sent by:
# 2025-01-15 16:34:54,688 - DEBUG - Body: Guns.com <https://e-clicks.guns.com/u/nrd.php?p=KcjJEPOCZ9_1920360_8597345_1_23&ems_l=14958099&i=1&d=UGFydG5lcnNoaXBfU21pdGhfV2Vzc29uXzE4NTRfTW9kZWxzXzFfMTNfMjAyNQ%3D%3D%7CR3Vucy5jb20%3D%7CNjU1NTQ1MzY0%7CS2NqSkVQT0NaOQ%3D%3D%7CYTA0NjM1N2UzNWRkNWE1NTE%3D%7C&_esuh=_11_932d0c1f3f427353f9f516778e65357f674489f9738f9a22693f5b5a0ce78131>
# 2025-01-15 16:34:54,689 - DEBUG - Body: PO Box 1131, 13800 Nicollet Blvd
# 2025-01-15 16:34:54,689 - DEBUG - Body: Burnsville, MN 55337-9929
# 2025-01-15 16:34:54,689 - DEBUG - Body:  <https://e-clicks.guns.com/mo/KcjJEPOCZ9_816596386_8597345_1920360_14958099.gif>
# 2025-01-15 16:34:54,690 - DEBUG - Header: Received: from 127.0.0.1
# 2025-01-15 16:34:54,690 - DEBUG - Header:  by atlas-production.v2-mail-prod1-bf1.omega.yahoo.com pod-id atlas--production-bf1-697848c544-v6vgx.bf1.yahoo.com with HTTP; Mon, 13 Jan 2025 14:35:18 +0000
# 2025-01-15 16:34:54,690 - DEBUG - Header: Received: from 45.86.116.209 (EHLO mta-2d5674d1.ip4.emarsys.us)
# 2025-01-15 16:34:54,690 - DEBUG - Header:  by 10.196.121.159 with SMTPs
# 2025-01-15 16:34:54,691 - DEBUG - Header:  (version=TLS1_3 cipher=TLS_AES_128_GCM_SHA256);
# 2025-01-15 16:34:54,691 - DEBUG - Header:  Mon, 13 Jan 2025 14:35:18 +0000
# 2025-01-15 16:34:54,691 - DEBUG - Header: From: "Guns.com" <marketing@e-email.guns.com>
# 2025-01-15 16:34:54,692 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-01-15 16:34:54,692 - DEBUG - Header: Subject: =?utf-8?Q?Introducing_the_Model_1854_Steal?=
# 2025-01-15 16:34:54,693 - DEBUG - Header: 	=?utf-8?Q?th_Hunter=E2=84=A2_by_Smith_&_Wesson=C2=AE?=
# 2025-01-15 16:34:54,693 - DEBUG - Header: Date: Mon, 13 Jan 2025 09:25:59 -0500
# 2025-01-15 16:34:54,694 - DEBUG - Header: Message-ID: <0.0.4F.CA2.1DB65C710DC92EE.0@mta-2d5674d1.ip4.emarsys.us>
# 2025-01-15 16:34:54,694 - DEBUG - Header: MIME-Version: 1.0
# 2025-01-15 16:34:54,694 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-01-15 16:34:54,695 - DEBUG - Header: 	boundary="----=_NextPart_000_0030_01DB65A1.FC55E7F0"
# 2025-01-15 16:34:54,695 - DEBUG - Header: X-Mailer: class SMTPMail
# 2025-01-15 16:34:54,696 - DEBUG - Header: X-Originating-Ip: [45.86.116.209]
# 2025-01-15 16:34:54,696 - DEBUG - Header: Authentication-Results: atlas-production.v2-mail-prod1-bf1.omega.yahoo.com;
# 2025-01-15 16:34:54,696 - DEBUG - Header:  dkim=pass header.i=@e-email.guns.com header.s=key4 arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:34:54,697 - DEBUG - Header:  dkim=pass header.i=@emarsys.net header.s=key2 arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:34:54,697 - DEBUG - Header:  spf=pass smtp.mailfrom=e-email.guns.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:34:54,698 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=e-email.guns.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:34:54,698 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Mon, 13 Jan 2025 14:35:19 +0000
# 2025-01-15 16:34:54,698 - DEBUG - Header: X-YMailISG: gezYjhEWLDtP9vLjW9d0ww65Nu6iw1grvcodoO_Tkb.XdyWN
# 2025-01-15 16:34:54,699 - DEBUG - Header:  uivVeOwFn7cETjxsVGUWlyjQEfIjGxwwrDz_mdkv6D9UgonmwdOd.NeZn0.I
# 2025-01-15 16:34:54,699 - DEBUG - Header:  uCfTLP6nRNX3rwsuPdPDnvRUQ9Q59QqeaK7PI6J8QndZ0.4P6ZPzdJhhCmrk
# 2025-01-15 16:34:54,699 - DEBUG - Header:  ROTLiO_B2nT1JxQNebU0fRzYy5Zh7kBlm6IGUbHcxBeJdQOSjP47oHnJe3dn
# 2025-01-15 16:34:54,700 - DEBUG - Header:  NkqD.pxKcV8qcf.o7GqlbWyysFlIj8ecjgPUPlI8AxMLbOn6xFsooyY7BVSI
# 2025-01-15 16:34:54,700 - DEBUG - Header:  n8oxbqqq1L.9_t9VksJaD8U_w4NG3IgH3sG1MUZI3af9k6EOECXno8uHjk.e
# 2025-01-15 16:34:54,700 - DEBUG - Header:  fEC6_TKsbXHO.PAHEy2Yrs8fGmUZkXlQwfLSqqLXL6niEvdfdbNzqhmi9jw7
# 2025-01-15 16:34:54,701 - DEBUG - Header:  q6PC1.LiVgsZ2FHaVCq_uE669_5OnMbFJ4RBbZzUJb2GcBGRcon7c7w1jg89
# 2025-01-15 16:34:54,701 - DEBUG - Header:  zrcDDjQbc9SciPnFhXqBPxKiSAboirGqp1NF6BRnUpijLpL3WaDgSgZOynDA
# 2025-01-15 16:34:54,701 - DEBUG - Header:  Ul.s8.CKboJeKiBbqIE7EecKgbpYzh.J6xrwlRU0FiRdzoYV2a.PANxZEG1A
# 2025-01-15 16:34:54,702 - DEBUG - Header:  6z7NedStmiBpQ9wgvXOe8tN.qQN74gif4a6lO374WzdXhFfvX9_MBVkG65ou
# 2025-01-15 16:34:54,702 - DEBUG - Header:  Fma9xd.0ebYsKG11ZjvSzDPkJjtnBia5FFrSgCjX8dicbUTCMQtm_Dyy8kS7
# 2025-01-15 16:34:54,702 - DEBUG - Header:  brg1dRGNAC..Vs9A0mCOtn9Lh_LEf_iTVE5r.q954i7BA1_zg1jVbGbFmqVH
# ...
# 2025-01-15 16:35:48,782 - DEBUG - Subject:  Begin 2025 Stress-FreeWell Buy Your House!
# 2025-01-15 16:35:48,783 - DEBUG - From: service-igi9wc@ghw7r.pasticun500.com
# 2025-01-15 16:35:48,784 - DEBUG - Received: 2024-12-31 11:58:11+00:00
# 2025-01-15 16:35:48,895 - DEBUG - Matched keyword in body: .imgur.
# 2025-01-15 16:35:48,896 - DEBUG - First line of body that matches the keyword:  <ttps://i.imgur.com/Eb0A2oy.png>
# 2025-01-15 16:35:48,897 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:35:48,897 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:35:48,899 - DEBUG - Email marked as read
# 2025-01-15 16:35:48,903 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-01-15 16:35:48,908 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:35:48,914 - DEBUG -
#
# Email 354:
# 2025-01-15 16:35:48,915 - DEBUG - Subject: #1 Secret to Eliminate Overactive Bladder
# 2025-01-15 16:35:48,917 - DEBUG - From: no-reply-nuie@e6wzs.rostiough.net
# 2025-01-15 16:35:48,918 - DEBUG - Received: 2024-12-31 11:35:51+00:00
# 2025-01-15 16:35:49,010 - DEBUG - Matched keyword in body: .imgur.
# 2025-01-15 16:35:49,011 - DEBUG - First line of body that matches the keyword:  <https://i.imgur.com/NKAIcVO.jpeg>
# 2025-01-15 16:35:49,013 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:35:49,014 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:35:49,016 - DEBUG - Email marked as read
# 2025-01-15 16:35:49,021 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-01-15 16:35:49,060 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:35:49,072 - DEBUG -
#
# Email 355:
# 2025-01-15 16:35:49,073 - DEBUG - Subject: We decked out 2024 in adventure
# 2025-01-15 16:35:49,075 - DEBUG - From: RoyalCaribbean@reply.RoyalCaribbeanMarketing.com
# 2025-01-15 16:35:49,078 - DEBUG - Received: 2024-12-31 11:28:56+00:00
# 2025-01-15 16:35:49,481 - DEBUG - Matched keyword in body: bean.com
# 2025-01-15 16:35:49,482 - DEBUG - First line of body that matches the keyword: BOGO60 applies to new, individual, and named group bookings at prevailing rates made 12/10/24  1/2/25 on sailings departing on or after December 11, 2024, and provides 60% off the cruise fare of the second guest booked in the same stateroom as the first, full fare paying guest, as well as 30% off any additional guests. Savings applied to cruise fare at checkout. Kids Sail Free applies to new, individual, and named group bookings at prevailing rates made 12/10/24  1/2/25 on select sailings 3 nights and longer departing on or after December 11, 2024, and provides $0 cruise fare for additional guests 12 years old and younger as of departure date, booked in the same stateroom as the first full fare paying and second guests. Taxes, fees, and port expenses are additional and apply to all guests. Additional restrictions apply, for a full list of excluded sailings please visit www.RoyalCaribbean.com. <https://click.RoyalCaribbeanMarketing.com/?qs=f06073767a873531e8fc9645048a787f690ad0cd2aeca5df4f3b504e17fec49b3ce64cf89577a8cabfedc6ddd090372b3953b0d66a78fc9afe0b268965ad98a3> 48 Hour Savings applies to new, individual, and named group bookings at prevailing rates made 12/31/24  1/1/25 on sailings departing on or after January 1, 2025, (Offer Cruise) and provides an up to $500 instant savings per stateroom varying by stateroom category booked and sailing length. Instant savings amount shown in USD and will be converted to currency used for cruise purchase applied as instant rebate to the cruise fare at checkout reflected as Dollars Off or Savings. Offer open to residents of US, Canada, Puerto Rico and select countries in the Caribbean. Changes to the booking may result in the removal of the offer. Prices and offers are subject to availability and change without notice, capacity controlled, and may be withdrawn at any time. Refer to www.RoyalCaribbean.com <https://click.RoyalCaribbeanMarketing.com/?qs=f06073767a873531e8fc9645048a787f690ad0cd2aeca5df4f3b504e17fec49b3ce64cf89577a8cabfedc6ddd090372b3953b0d66a78fc9afe0b268965ad98a3>  for complete terms and conditions. Royal Caribbean International reserves the right to correct any errors, inaccuracies, or omissions and to change or update fares, fees, and surcharges at any time without prior notice.
# 2025-01-15 16:35:49,484 - DEBUG - Email matches rule: SpamAutoDeleteBody
# 2025-01-15 16:35:49,484 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:35:49,486 - DEBUG - Email marked as read
# 2025-01-15 16:35:49,490 - DEBUG - Email assigned to category 'SpamBody'
# 2025-01-15 16:35:49,496 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:35:49,503 - DEBUG -
#
# Email 356:
# 2025-01-15 16:35:49,505 - DEBUG - Subject: Special Offer: Lower Your Auto Insurance Costs as a Veteran.
# 2025-01-15 16:35:49,505 - DEBUG - From: bubalus@papayasa.com
# 2025-01-15 16:35:49,506 - DEBUG - Received: 2024-12-31 11:26:22+00:00
# 2025-01-15 16:35:49,626 - DEBUG - No conditions or phishing indicators found
# 2025-01-15 16:35:49,627 - DEBUG - Body:  <http://papayasa.com/12i/tryuc0nyhpieLpO5ZJGHtToEM7_VqBaAhXGRDXd9D4frq7ofM0MfhXsR-/98l>
# 2025-01-15 16:35:49,627 - DEBUG - Body:
# 2025-01-15 16:35:49,627 - DEBUG - Body:
# 2025-01-15 16:35:49,628 - DEBUG - Body:
# 2025-01-15 16:35:49,628 - DEBUG - Body:
# 2025-01-15 16:35:49,628 - DEBUG - Body:  <http://papayasa.com/isi/tryuc0nyhpieLpO5ZJGHtToEM7_VqBaAhXGRDXd9D4frq7ofM0MfhXsn-/af6665>
# 2025-01-15 16:35:49,629 - DEBUG - Header: Received: from 127.0.0.1
# 2025-01-15 16:35:49,629 - DEBUG - Header:  by atlas-production.v2-mail-prod1-gq1.omega.yahoo.com pod-id atlas--production-gq1-774c55898-nkjpl.gq1.yahoo.com with HTTP; Tue, 31 Dec 2024 16:26:22 +0000
# 2025-01-15 16:35:49,630 - DEBUG - Header: Received: from 154.205.166.37 (EHLO vinylethylene.biznexexpo.com)
# 2025-01-15 16:35:49,630 - DEBUG - Header:  by 10.206.128.73 with SMTP;
# 2025-01-15 16:35:49,630 - DEBUG - Header:  Tue, 31 Dec 2024 16:26:22 +0000
# 2025-01-15 16:35:49,631 - DEBUG - Header: Reply-To: <bubalus@papayasa.com>
# 2025-01-15 16:35:49,631 - DEBUG - Header: From: =?utf-8?B?VvOggItldGVy86CAi2Fu86CAi0luc/OggIt1cmVO86CAi293?= <bubalus@papayasa.com>
# 2025-01-15 16:35:49,631 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-01-15 16:35:49,632 - DEBUG - Header: Subject: =?utf-8?B?U/OggItwZWPzoICLafOggIthbCBPZmbzoICL86CAi2XzoICLcjogTPOggIvzoICL?=
# 2025-01-15 16:35:49,632 - DEBUG - Header: 	=?utf-8?B?b3fzoICLZXIgWfOggIvzoICLb/OggIt1ciBB86CAi/OggIt186CAi3RvIEnzoICL?=
# 2025-01-15 16:35:49,633 - DEBUG - Header: 	=?utf-8?B?bnN186CAi3JhbmPzoICLZSBD86CAi29z86CAi/OggIt0cyBh86CAi3MgYSA=?=
# 2025-01-15 16:35:49,633 - DEBUG - Header: 	=?utf-8?B?VvOggItldGXzoICLcmFu86CAiy4=?=
# 2025-01-15 16:35:49,633 - DEBUG - Header: Date: Tue, 31 Dec 2024 11:26:20 -0500
# 2025-01-15 16:35:49,633 - DEBUG - Header: Message-ID: <N.Mees.06FD5k37K.8425376.hyposensitizes@papayasa.com>
# 2025-01-15 16:35:49,634 - DEBUG - Header: MIME-Version: 1.0
# 2025-01-15 16:35:49,634 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-01-15 16:35:49,635 - DEBUG - Header: 	boundary="----=_NextPart_000_169C_01DB642C.97663C80"
# 2025-01-15 16:35:49,635 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-01-15 16:35:49,635 - DEBUG - Header: Thread-Index: AQHs7Umhhwqx9KhJyvxWyNYoDicPcg==
# 2025-01-15 16:35:49,635 - DEBUG - Header: X-Originating-Ip: [154.205.166.37]
# 2025-01-15 16:35:49,636 - DEBUG - Header: Authentication-Results: atlas-production.v2-mail-prod1-gq1.omega.yahoo.com;
# 2025-01-15 16:35:49,636 - DEBUG - Header:  dkim=pass header.i=@papayasa.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:35:49,636 - DEBUG - Header:  spf=pass smtp.mailfrom=papayasa.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:35:49,637 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=papayasa.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-01-15 16:35:49,637 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Tue, 31 Dec 2024 16:26:22 +0000
# 2025-01-15 16:35:49,638 - DEBUG - Header: X-YMailISG: 8l8aIb8WLDunowIJqsYLMJhKOZE7qah6prPU6rb4YEOQwXxn
# 2025-01-15 16:35:49,638 - DEBUG - Header:  2vkPpk3jdhh5kTqzxsXjjv9MkcYmJd.Qvq3CP0x_4vP2nQDBnLS8QUYzAN7v
# 2025-01-15 16:35:49,638 - DEBUG - Header:  cwTzg7gu6CfHTrR0KDNH3Om4sJs0_fH3kkgP6O1LVLVNcr4CZT_fTKyeKRtU
# 2025-01-15 16:35:49,639 - DEBUG - Header:  prQl5Y2WWvqxqmncgx9eh9x540tUNucJ9tKKVX9lBq6zhup4EAjuBsWW99Nd
# 2025-01-15 16:35:49,639 - DEBUG - Header:  yntSC0AoGAB1IdSSzNizgnUBRI_dEDHZT3AKGOnZtV0ncVcpE773ZIcOXdct
# 2025-01-15 16:35:49,639 - DEBUG - Header:  jeSGZ2121HJ6FivGhDd1brB__lqlWLXpY.RWreSk9Oj7fmYxM2qF94wSVsNv
# 2025-01-15 16:35:49,641 - DEBUG - Header:  ZcQS2zWAZFYYXq8p9EHfffmvpXcvYxW36dSq1MX27qWJr_6QMXUdfyjmLwE0
# 2025-01-15 16:35:49,641 - DEBUG - Header:  kO_NT0BzEjZKoFEriWdTGqzfiwWdNBdQYR8nTSt5RPxVk443U..12yo_AW4r
# 2025-01-15 16:35:49,641 - DEBUG - Header:  yFgHM9apaz_ls8o_uW9I3Kal2Swa29j_yoHynPjkpec9R32MUQDAZ7xI2DSY
# 2025-01-15 16:35:49,642 - DEBUG - Header:  XLueaGKJscFmvGvBOSAmeyeCeFmKlaEEflqkzkNvi2P07cHnzGJjUfSpKD3Z
# 2025-01-15 16:35:49,642 - DEBUG - Header:  ubOwa28DrHlkQY0Up5cy3yAum_r7nNIgQn7m2DBU5LObfymb4VMbvbfuJhSQ
# 2025-01-15 16:35:49,642 - DEBUG - Header:  1aZdQFwThk7ucCB28vQcHty5BXRaH4FyjOO0rnuSF.tA3lYztN.uaiBDEKP7
# 2025-01-15 16:35:49,643 - DEBUG - Header:  zM122CWwm9eeVMXjiPv8d9eJ0NH13kDy0ioMU84HFQAR0GVi3IF7fE6f23EI
# 2025-01-15 16:35:49,643 - DEBUG - Header:  xbQqwemXcW3uNUXKjxSaGrdAJGOZFZIxOch2P5y.8JVrMDRTbYtTATi3f2Sw
# 2025-01-15 16:35:49,644 - DEBUG - Header:  mVkEuFU_IgvFCNXfDBGOx.EVJv.s2jH72pjC1HvxJgfts1wrFJpLvfvDErgf
# 2025-01-15 16:35:49,644 - DEBUG - Header:  ftdvcjE03zDssL6xFWIVbpa860Tnq.dWQcVcnKziz2d4T.hRaQ3I9dedoeeh
# 2025-01-15 16:35:49,644 - DEBUG - Header:  M0J1
# 2025-01-15 16:35:49,644 - DEBUG - Header: 	z8kmGuoaJE8W13gcE1CNfm.mgOWYP3Bv4fMuDMQQSqd7l4WPoBv09ja_
# 2025-01-15 16:35:49,645 - DEBUG - Header:  ymEGEcYKMLd9ST8aTnuYG4HabhbNf75IJ4hJBzDsBchPfZES3aS2klBExa6a
# 2025-01-15 16:35:49,645 - DEBUG - Header:  56eydlAsToTUv7T5jTegJxchlUESAzosDDO6tQaw9xEBzfVNCc64E.5CLJur
# 2025-01-15 16:35:49,645 - DEBUG - Header:  z7deAlQsKqfudVIlef8r6nwUqQ30qh5cW3U48FZJOJkrj6u0R2O07Zo4M8hX
# 2025-01-15 16:35:49,646 - DEBUG - Header:  KAGvyLNx8ThvoBWdjlJk619BWUHchOKBvFHfSHT4RkaGhnTJdyztzeRgtCrR
# 2025-01-15 16:35:49,646 - DEBUG - Header:  AONorCdQhRnuGq_wGzFRY7..S6tw5_5hxXVs9wcd6Jw40ztGQ_mNMhRMXBbm
# 2025-01-15 16:35:49,646 - DEBUG - Header:  Sr9785MF1M9QvqD__TVbWIfBf5y2obfoniWek8nzt8u.NkBX8YXmIWp1LuVY
# 2025-01-15 16:35:49,647 - DEBUG - Header:  XT8eoN6jSD0D8Q10A_tXervr.WWON2eOHVA07iaIhFzd6aFB9fJDkZzAAzoB
# 2025-01-15 16:35:49,647 - DEBUG - Header:  RqoA1cB.IXvEN3pzbV78rX_w6M4iR.hT3_ActVG_FZwA5feUtNfAEP1ut952
# 2025-01-15 16:35:49,648 - DEBUG - Header:  3SDz.WyJlCoGdWYdgPIVluPzBF2NPFMWxpqZpkYTYkFxcLk2Pe5iiTt9sbV5
# 2025-01-15 16:35:49,648 - DEBUG - Header:  sBfXkiNwurM-
# 2025-01-15 16:35:49,648 - DEBUG - Header: List-Unsubscribe: <https://papayasa.com/tryuc0nyhpieLpO5ZJGHt9OEM7_VqBaAhXGRDXd9D4frq7ofM0MfhXsn2Jwgh1n7ZJi7cr->
# 2025-01-15 16:35:49,649 - DEBUG - Header:
# 2025-01-15 16:35:49,659 - DEBUG -
#
# Email 357:
# 2025-01-15 16:35:49,661 - DEBUG - Subject: Turn Your Most LOVED Memories Into Art!
# 2025-01-15 16:35:49,663 - DEBUG - From: teamb2-juf05@hozep.gameflashgames.com
# 2025-01-15 16:35:49,666 - DEBUG - Received: 2024-12-31 11:21:46+00:00
# 2025-01-15 16:35:49,775 - DEBUG - Matched keyword in body: .imgur.
# 2025-01-15 16:35:49,776 - DEBUG - First line of body that matches the keyword:  <https://i.imgur.com/fYVGS0c.png>
# 2025-01-15 16:35:49,777 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:35:49,777 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:35:49,780 - DEBUG - Email marked as read
# 2025-01-15 16:35:49,785 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-01-15 16:35:49,790 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:35:49,797 - DEBUG -
#
# Email 358:
# 2025-01-15 16:35:49,798 - DEBUG - Subject: Sit On The Edge Of Your Bed And Do This To Mute Tinnitus
# 2025-01-15 16:35:49,799 - DEBUG - From: noreply@p2bi.com
# 2025-01-15 16:35:49,800 - DEBUG - Received: 2024-12-31 11:21:28+00:00
# 2025-01-15 16:35:49,916 - DEBUG - Matched keyword in body: .imgur.
# 2025-01-15 16:35:49,916 - DEBUG - First line of body that matches the keyword:  <https://i.imgur.com/zHMFWWa.png>
# 2025-01-15 16:35:49,918 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-01-15 16:35:49,919 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-01-15 16:35:49,920 - DEBUG - Email marked as read
# 2025-01-15 16:35:49,924 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-01-15 16:35:49,931 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-01-15 16:35:49,938 - DEBUG -
#
# Email 359:
# 2025-01-15 16:35:49,940 - DEBUG - Subject: Get 35% off Worlds Smallest Charger!
# 2025-01-15 16:35:49,943 - DEBUG - From: service-jkcydu@1qe5o.pasticun500.com
# 2025-01-15 16:35:49,944 - DEBUG - Received: 2024-12-31 11:20:23+00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#       9     rules_json = agent.get_outlook_rules()
#      10     #print(rules_json)
#      11
#      12     # Process last 24 hours of emails
# ---> 13     agent.process_emails(rules_json)
#      15     print("Complete. Check the log file for detailed analysis.\n\n")
#      17 except Exception as e:
#
# Cell In[9], line 584, in OutlookSecurityAgent.process_emails(self, rules_json, days_back)
#     582 # Check body keywords
#     583 if 'body' in conditions:
# --> 584     if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
#     585         match = True
#     586         matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
#
# Cell In[9], line 584, in <genexpr>(.0)
#     582 # Check body keywords
#     583 if 'body' in conditions:
# --> 584     if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
#     585         match = True
#     586         matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
#
# File d:\Data\Harold\github\OutlookMailSpamFilter\.venv\Lib\site-packages\win32com\client\dynamic.py:618, in CDispatch.__getattr__(self, attr)
#     614 debug_attr_print(
#     615     "Getting property Id 0x%x from OLE object" % retEntry.dispid
#     616 )
#     617 try:
# --> 618     ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#     619 except pythoncom.com_error as details:
#     620     if details.hresult in ERRORS_BAD_CONTEXT:
#     621         # May be a method.
#
# KeyboardInterrupt:
