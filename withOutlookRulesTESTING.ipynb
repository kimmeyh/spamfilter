# %% [markdown]
# I've modified the security agent to specifically target the "Bulk Mail" folder in the kimmeyharold@aol.com account. Key changes include:
#
# 1. Account/Folder Targeting:
#    - Added account-specific folder lookup
#    - Recursive folder search capability (in case "Bulk Mail" is nested)
#    - Validation of account and folder existence
#
# 2. Improved Structure:
#    - Creates "Security Review" folder within the Bulk Mail folder
#    - Only processes emails from the specified folder
#    - Maintains all security checks and rule processing
#
# 3. Better Error Handling:
#    - Validates account and folder access
#    - Detailed logging of folder navigation
#    - Graceful handling of missing folders
#
# To use this version:
# 1. Make sure Outlook is running and the AOL account is connected
# 2. Run the script - it will automatically target the Bulk Mail folder
# 3. Suspicious emails will be moved to a "Security Review" subfolder within Bulk Mail
#
# Would you like me to:
# 1. Add support for multiple folders?
# 2. Implement different processing rules for different folders?
# 3. Add email volume reporting?
# 4. Create a summary report of processed emails?

# %%
#**** DO NOT RUN *** would need to be modified before it would work correctly

# %%
#Imports for python base packages
import re
from datetime import datetime, timedelta
import logging
import sys
import json

#Imports for packages that need to be installed
import win32com.client
import IPython
import yaml

# %%
DEBUG = True
INFO = False if DEBUG else True #If not debugging, then INFO level logging
DEBUG_EMAILS_TO_PROCESS = 3000
EMAIL_ADDRESS = "kimmeyharold@aol.com"
EMAIL_FOLDER_NAME = "Bulk Mail"
WIN32_CLIENT_DISPATCH = "Outlook.Application"
OUTLOOK_GETNAMESPACE = "MAPI"
OUTLOOK_SECURITY_LOG = "outlook_security.log"

days_back_default = 365 #default number of days to go back in the calendar

# %%
class OutlookSecurityAgent:
    def __init__(self, email_address=EMAIL_ADDRESS, folder_name=EMAIL_FOLDER_NAME, debug_mode=DEBUG):
        """
        Initialize the Outlook Security Agent with specific account and folder

        Args:
            email_address: Email address of the account to process
            folder_name: Name of the folder to process
            debug_mode: If True, run in simulation mode with verbose output
        """
        self.debug_mode = debug_mode
        self.outlook = win32com.client.Dispatch(WIN32_CLIENT_DISPATCH)
        self.namespace = self.outlook.GetNamespace(OUTLOOK_GETNAMESPACE)

        # Configure logging
        log_format = '%(asctime)s - %(levelname)s - %(message)s'
        logging.basicConfig(
            level=logging.DEBUG if debug_mode else logging.INFO,
            format=log_format,
            handlers=[
                logging.FileHandler(OUTLOOK_SECURITY_LOG),
                logging.StreamHandler(sys.stdout)  # Also print to console
            ]
        )

        self.debug_print(f"Initializing agent for {email_address}, folder: {folder_name}")
        self.debug_print(f"Debug mode: {debug_mode}")

        # Get the specific account's folder
        self.target_folder = self._get_account_folder(email_address, folder_name)
        if not self.target_folder:
            raise ValueError(f"Could not find folder '{folder_name}' in account '{email_address}'")

        self.rules = []
        self.rule_to_category = {
            "SpamAutoDeleteBody":           "SpamBody",
            "SpamAutoDeleteBody-imgur.com": "SpamImgur",
            "SpamAutoDeleteFrom":           "SpamHeader",
            "SpamAutoDeleteHeader":         "SpamHeader",
            "SpamAutoDeleteSubject":        "SpamSubject"
        }

    def debug_print(self, message):
        try:
            sanitized_message = self._sanitize_string(message)
            logging.debug(sanitized_message)
        except UnicodeEncodeError:
            logging.debug(sanitized_message.encode('utf-8', 'replace').decode('utf-8'))

    def _sanitize_string(self, s):
        """Sanitize string to replace non-ASCII characters"""
        return re.sub(r'[^\x00-\x7F]+', '', s)

    def _get_account_folder(self, email_address, folder_name):
        """Get a specific folder from a specific email account"""
        self.debug_print(f"Searching for folder: {folder_name} in account: {email_address}")

        try:
            # Loop through accounts to find the matching one
            for account in self.outlook.Session.Accounts:
                self.debug_print(f"Checking account: {account.SmtpAddress}")

                if account.SmtpAddress.lower() == email_address.lower():
                    self.debug_print(f"Found matching account: {account.SmtpAddress}")

                    # Get the root folder for this account
                    root_folder = self.namespace.Folders(account.DeliveryStore.DisplayName)
                    self.debug_print(f"Accessed root folder: {root_folder.Name}")

                    # Search for the target folder
                    try:
                        # Try direct access first
                        target_folder = root_folder.Folders[folder_name]
                        self.debug_print(f"Found target folder directly: {folder_name}")
                        return target_folder
                    except Exception:
                        self.debug_print(f"Folder not found directly, searching recursively...")
                        return self._find_folder_recursive(root_folder, folder_name)

            self.debug_print(f"Account not found: {email_address}")
            return None

        except Exception as e:
            self.debug_print(f"Error finding account folder: {str(e)}")
            return None

    def get_outlook_rules(self):
        """
        Convert Outlook rules to JSON format with comprehensive error checking.
        Returns a list of rule dictionaries with all available properties.
        """
        self.debug_print("Converting Outlook rules to JSON format...")
        rules_json = []

        try:
            # NOTE: GetRules() is not returning several of the actions:
            #   - Mark as Read
            #   - Clear the Message Flag
            #   - Stop Processing More Rules
            #   Also, the "AssignToCategory" is not returning the category name
            outlook_rules = self.outlook.Session.DefaultStore.GetRules()
            self.debug_print(f"Processing {len(outlook_rules)} rules...")

            for rule in outlook_rules:
                try:
                    if "SpamAutoDelete" not in rule.Name:
                        continue

                    self.debug_print(f"\n\nAnalyzing rule: {rule.Name}")
                    # print (rule)
                    rule_dict = {
                        "name": rule.Name if hasattr(rule, "Name") else "Unnamed Rule",
                        "enabled": bool(rule.Enabled) if hasattr(rule, "Enabled") else False,
                        "isLocal": bool(rule.IsLocalRule) if hasattr(rule, "IsLocalRule") else False,
                        "executionOrder": rule.ExecutionOrder if hasattr(rule, "ExecutionOrder") else 0,
                        "conditions": {},
                        "actions": {},
                        "exceptions": {}
                    }

                    # Process Conditions
                    if hasattr(rule, "Conditions") and rule.Conditions:
                        conditions = rule.Conditions
                        rule_dict["conditions"] = self._process_conditions(conditions, False)

                    # Process Actions
                    if hasattr(rule, "Actions") and rule.Actions:
                        actions = rule.Actions
                        rule_dict["actions"] = self._process_actions(actions)

                    # Process Exceptions
                    if hasattr(rule, "Exceptions") and rule.Exceptions:
                        exceptions = rule.Exceptions
                        rule_dict["exceptions"] = self._process_conditions(exceptions, True)  # Exceptions use same format as conditions

                    rules_json.append(rule_dict)
                    self.debug_print(f"Successfully processed rule: {rule_dict['name']}")

                except Exception as e:
                    self.debug_print(f"Error processing rule {getattr(rule, 'Name', 'Unknown')}: {str(e)}")
                    # Add error information to the rule
                    rules_json.append({
                        "name": getattr(rule, "Name", "Unknown Rule"),
                        "error": str(e),
                        "processed": False
                    })

            # print (json.dumps(rules_json, indent=2, default=str))
            return json.dumps(rules_json, indent=2, default=str)

        except Exception as e:
            self.debug_print(f"Error accessing Outlook rules: {str(e)}")
            return json.dumps({"error": str(e)})

    def _process_conditions(self, conditions_obj, is_exception):
        """Helper method to process rule conditions or exceptions"""
        conditions = {}

        try:
            # From addresses
            if hasattr(conditions_obj, "From") and conditions_obj.From:
                try:
                    conditions["from"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in conditions_obj.From.Recipients
                    ]
                    # Print the contents of conditions["from"]
                    if is_exception:
                        self.debug_print(f"Exception conditions['from']: {conditions['from']}")
                    else:
                        self.debug_print(f"Conditions['from']: {conditions['from']}")

                except Exception as e:
                    self.debug_print(f"Error processing From condition: {str(e)}")
                    conditions["from"] = []

            # Subject keywords
            if hasattr(conditions_obj, "Subject") and conditions_obj.Subject:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.Subject.Text: {conditions_obj.Subject.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.Subject.Text: {conditions_obj.Subject.Text}")

                    if hasattr(conditions_obj.Subject, "Text"):
                        if isinstance(conditions_obj.Subject.Text, str):
                            subject_text = conditions_obj.Subject.Text
                        elif isinstance(conditions_obj.Subject.Text, tuple):
                            subject_text = "; ".join(conditions_obj.Subject.Text)
                        else:
                            subject_text = ""
                    else:
                        subject_text = ""
                    conditions["subject"] = [kw.strip() for kw in subject_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Subject condition: {str(e)}")
                    conditions["subject"] = []

            # Body keywords
            if hasattr(conditions_obj, "Body") and conditions_obj.Body:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.Body.Text: {conditions_obj.Body.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.Body.Text: {conditions_obj.Body.Text}")

                    if hasattr(conditions_obj.Body, "Text"):
                        if isinstance(conditions_obj.Body.Text, str):
                            body_text = conditions_obj.Body.Text
                        elif isinstance(conditions_obj.Body.Text, tuple):
                            body_text = "; ".join(conditions_obj.Body.Text)
                            # self.debug_print(f"body_text: {body_text}")
                        else:
                            body_text = ""
                    else:
                        body_text = ""
                    conditions["body"] = [kw.strip() for kw in body_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Body condition: {str(e)}")
                    conditions["body"] = []

            # Header keywords
            if hasattr(conditions_obj, "MessageHeader") and conditions_obj.MessageHeader:
                try:
                    if is_exception:
                        self.debug_print(f"Exception conditions_obj.MessageHeader.Text: {conditions_obj.MessageHeader.Text}")
                    else:
                        self.debug_print(f"Conditions_obj.MessageHeader.Text: {conditions_obj.MessageHeader.Text}")

                    if hasattr(conditions_obj.MessageHeader, "Text"):
                        if isinstance(conditions_obj.MessageHeader.Text, str):
                            header_text = conditions_obj.MessageHeader.Text
                        elif isinstance(conditions_obj.MessageHeader.Text, tuple):
                            header_text = "; ".join(conditions_obj.MessageHeader.Text)
                        else:
                            header_text = ""
                    else:
                        header_text = ""
                    conditions["header"] = [kw.strip() for kw in header_text.split(";") if kw.strip()]
                except Exception as e:
                    self.debug_print(f"Error processing Header condition: {str(e)}")
                    conditions["header"] = []

            # Attachment condition
            if hasattr(conditions_obj, "Attachment"):
                if is_exception:
                    self.debug_print(f"Exception conditions_obj.Attachment: {bool(conditions_obj.Attachment)}")
                else:
                    self.debug_print(f"Conditions_obj.Attachment: {bool(conditions_obj.Attachment)}")

                conditions["has_attachments"] = bool(conditions_obj.Attachment)

        except Exception as e:
            self.debug_print(f"Error processing conditions: {str(e)}")
            conditions["error"] = str(e)

        return conditions

    def _process_actions(self, actions_obj):
        """Helper method to process rule actions"""
        actions = {}

        try:
            # Move to Folder
            if hasattr(actions_obj, "MoveToFolder") and actions_obj.MoveToFolder:
                try:
                    actions["move_to_folder"] = {
                        "folder_path": actions_obj.MoveToFolder.FolderPath if hasattr(actions_obj.MoveToFolder, "FolderPath") else None,
                        "folder_name": actions_obj.MoveToFolder.Name if hasattr(actions_obj.MoveToFolder, "Name") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing MoveToFolder action: {str(e)}")

            # Copy to Folder
            if hasattr(actions_obj, "CopyToFolder") and actions_obj.CopyToFolder:
                try:
                    actions["copy_to_folder"] = {
                        "folder_path": actions_obj.CopyToFolder.FolderPath if hasattr(actions_obj.CopyToFolder, "FolderPath") else None,
                        "folder_name": actions_obj.CopyToFolder.Name if hasattr(actions_obj.CopyToFolder, "Name") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing CopyToFolder action: {str(e)}")

            # Assign to Category
            if hasattr(actions_obj, "AssignToCategory") and actions_obj.AssignToCategory:
                try:
                    category_name = actions_obj.AssignToCategory.Category if hasattr(actions_obj.AssignToCategory, "Category") else None
                    self.debug_print(f"AssignToCategory action found, category_name: {category_name}")
                    actions["assign_to_category"] = {
                        "category_name": category_name
                    }
                except Exception as e:
                    self.debug_print(f"Error processing AssignToCategory action: {str(e)}")

            # Delete
            if hasattr(actions_obj, "Delete") and actions_obj.Delete:
                actions["delete"] = True

            # Stop processing more rules
            if hasattr(actions_obj, "StopProcessingMoreRules") and actions_obj.StopProcessingMoreRules:
                try:
                    self.debug_print("StopProcessingMoreRules action found")
                    actions["stop_processing_more_rules"] = True
                except Exception as e:
                    self.debug_print(f"Error processing StopProcessingMoreRules action: {str(e)}")

            # Mark as Read
            if hasattr(actions_obj, "MarkAsRead") and actions_obj.MarkAsRead:
                try:
                    self.debug_print("MarkAsRead action found")
                    actions["mark_as_read"] = True
                except Exception as e:
                    self.debug_print(f"Error processing MarkAsRead action: {str(e)}")

            # Clear the Message Flag
            if hasattr(actions_obj, "ClearFlag") and actions_obj.ClearFlag:
                try:
                    self.debug_print("ClearFlag action found")
                    actions["clear_flag"] = True
                except Exception as e:
                    self.debug_print(f"Error processing ClearFlag action: {str(e)}")

            # Forward
            if hasattr(actions_obj, "Forward") and actions_obj.Forward:
                try:
                    actions["forward"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in actions_obj.Forward.Recipients
                    ]
                except Exception as e:
                    self.debug_print(f"Error processing Forward action: {str(e)}")
                    actions["forward"] = []

            # Redirect
            if hasattr(actions_obj, "Redirect") and actions_obj.Redirect:
                try:
                    actions["redirect"] = [
                        {
                            "address": recipient.Address if hasattr(recipient, "Address") else None,
                            "name": recipient.Name if hasattr(recipient, "Name") else None
                        }
                        for recipient in actions_obj.Redirect.Recipients
                    ]
                except Exception as e:
                    self.debug_print(f"Error processing Redirect action: {str(e)}")
                    actions["redirect"] = []

            # Reply
            if hasattr(actions_obj, "Reply") and actions_obj.Reply:
                try:
                    actions["reply"] = {
                        "template": actions_obj.Reply.Template if hasattr(actions_obj.Reply, "Template") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing Reply action: {str(e)}")

            # Play Sound
            if hasattr(actions_obj, "PlaySound") and actions_obj.PlaySound:
                try:
                    actions["play_sound"] = {
                        "sound_file": actions_obj.PlaySound.SoundFile if hasattr(actions_obj.PlaySound, "SoundFile") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing PlaySound action: {str(e)}")

            # Display Desktop Alert
            if hasattr(actions_obj, "DisplayDesktopAlert") and actions_obj.DisplayDesktopAlert:
                actions["display_desktop_alert"] = True

            # Set Importance
            if hasattr(actions_obj, "SetImportance") and actions_obj.SetImportance:
                try:
                    actions["set_importance"] = {
                        "importance_level": actions_obj.SetImportance.ImportanceLevel if hasattr(actions_obj.SetImportance, "ImportanceLevel") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing SetImportance action: {str(e)}")

            # Set Sensitivity
            if hasattr(actions_obj, "SetSensitivity") and actions_obj.SetSensitivity:
                try:
                    actions["set_sensitivity"] = {
                        "sensitivity_level": actions_obj.SetSensitivity.SensitivityLevel if hasattr(actions_obj.SetSensitivity, "SensitivityLevel") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing SetSensitivity action: {str(e)}")

            # Print
            if hasattr(actions_obj, "Print") and actions_obj.Print:
                actions["print"] = True

            # Run Script
            if hasattr(actions_obj, "RunScript") and actions_obj.RunScript:
                try:
                    actions["run_script"] = {
                        "script_path": actions_obj.RunScript.ScriptPath if hasattr(actions_obj.RunScript, "ScriptPath") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing RunScript action: {str(e)}")

            # Start Application
            if hasattr(actions_obj, "StartApplication") and actions_obj.StartApplication:
                try:
                    actions["start_application"] = {
                        "application_path": actions_obj.StartApplication.ApplicationPath if hasattr(actions_obj.StartApplication, "ApplicationPath") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing StartApplication action: {str(e)}")

            # Mark as Task
            if hasattr(actions_obj, "MarkAsTask") and actions_obj.MarkAsTask:
                try:
                    actions["mark_as_task"] = {
                        "task_due_date": actions_obj.MarkAsTask.TaskDueDate if hasattr(actions_obj.MarkAsTask, "TaskDueDate") else None
                    }
                except Exception as e:
                    self.debug_print(f"Error processing MarkAsTask action: {str(e)}")

        except Exception as e:
            self.debug_print(f"Error processing actions: {str(e)}")

        return actions

    def check_phishing_indicators(self, email): #*** not currently called
        """Check for phishing indicators in an email"""
        indicators = []

        try:
            # self.debug_print(f"\nAnalyzing email:")
            # self.debug_print(f"From: {email.SenderEmailAddress}")
            # self.debug_print(f"Subject: {email.Subject}")

            # Check sender mismatch
            sender = email.SenderEmailAddress.lower()
            display_name = email.SenderName.lower()
            if '@' in display_name and display_name != sender:
                self.debug_print(f"Found sender mismatch: {display_name} vs {sender}")
                indicators.append("Sender name/email mismatch")

            # Check urgent language
            urgent_words = ['urgent', 'immediate', 'action required', 'account suspended']
            found_urgent = [word for word in urgent_words if word in email.Subject.lower()]
            if found_urgent:
                self.debug_print(f"Found urgent language: {found_urgent}")
                indicators.append("Urgent language in subject")

            # Check URLs
            if email.HTMLBody:
                href_pattern = r'href=[\'"]?([^\'" >]+)'
                urls = re.findall(href_pattern, email.HTMLBody)
                for url in urls:
                    if 'http' in url.lower():
                        if url.lower() not in email.HTMLBody.lower():
                            self.debug_print(f"Found mismatched URL: {url}")
                            indicators.append("Mismatched URL display text")
                            break

            # Check sensitive words
            sensitive_words = ['password', 'login', 'credential', 'verify account']
            found_sensitive = [word for word in sensitive_words if word in email.Body.lower()]
            if found_sensitive:
                self.debug_print(f"Found sensitive words: {found_sensitive}")
                indicators.append("Requests for sensitive information")

            # Check Outlook rules
            for rule in self.rules:
                self.debug_print(f"\nChecking rule: {rule['name']}")
                conditions = rule['conditions']
                match = True

                for condition_type, condition_value in conditions.items():
                    self.debug_print(f"  Checking condition: {condition_type}")
                    if condition_type == 'from_addresses':
                        if not any(addr.lower() in sender for addr in condition_value):
                            match = False
                            self.debug_print("    Sender address did not match")
                            break
                    elif condition_type == 'subject_keywords':
                        if not any(keyword.lower() in email.Subject.lower() for keyword in condition_value):
                            match = False
                            self.debug_print("    Subject keywords did not match")
                            break
                    elif condition_type == 'body_keywords':
                        if not any(keyword.lower() in email.Body.lower() for keyword in condition_value):
                            match = False
                            self.debug_print("    Body keywords did not match")
                            break
                    elif condition_type == 'has_attachments':
                        if bool(email.Attachments.Count > 0) != condition_value:
                            match = False
                            self.debug_print("    Attachment condition did not match")
                            break

                if match:
                    self.debug_print(f"  Rule matched: {rule['name']}")
                    indicators.append(f"Matched Outlook rule: {rule['name']}")

        except Exception as e:
            self.debug_print(f"Error checking indicators: {str(e)}")

        return indicators

    def process_emails(self, rules_json, days_back=days_back_default):
        """Process emails based on the rules in the rules_json object"""
        self.debug_print(f"\n\nStarting email processing (Simulation Mode)")
        self.debug_print(f"Target folder: {self.target_folder.Name}")
        self.debug_print(f"Processing emails from last {days_back} days")

        try:
            # Parse the rules from the JSON object
            rules = json.loads(rules_json)

            # Get recent emails from the target folder
            restriction = "[ReceivedTime] >= '" + \
                (datetime.now() - timedelta(days=days_back)).strftime('%m/%d/%Y') + "'"
            emails = self.target_folder.Items.Restrict(restriction)
            emails.Sort("[ReceivedTime]", Descending=True)
            self.debug_print(f"Total emails found: {emails.Count}")

            processed_count = 0
            flagged_count = 0

            self.debug_print("Beginning email analysis:")

            # Create a list of emails to process (done because if deleting emails in "email in emails") it will skip emails
            emails_to_process = [email for email in emails]

            for email in emails_to_process:
                try:
                    processed_count += 1
                    email_deleted = False
                    if (DEBUG) and (processed_count > DEBUG_EMAILS_TO_PROCESS):
                        self.debug_print(f"Debug mode: Stopping after {DEBUG_EMAILS_TO_PROCESS} emails")
                        return
                    email_header = email.PropertyAccessor.GetProperty("http://schemas.microsoft.com/mapi/proptag/0x007D001E")
                    self.debug_print(f"\n\nEmail {processed_count}:")
                    self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")
                    self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")
                    self.debug_print(f"Received: {email.ReceivedTime}")
                    # for header in email_header.splitlines():
                    #     self.debug_print(f"Header: {header}")
                    # self.debug_print(f"Body: {self._sanitize_string(email.Body)}")
                    # self.debug_print(f"Attachments: {email.Attachments.Count}")


                    # Sort rules to ensure delete actions are processed last
                    rules.sort(key=lambda rule: rule['actions'].get('delete', False))

                    for rule in rules:
                        if email_deleted:
                            continue  # Go to the next email if one rule deletes the current email
                        conditions = rule['conditions']
                        exceptions = rule['exceptions']
                        # print(rule, conditions)
                        match = False

                        #*** may have to change all conditions[] to lower case
                        #*** will likely have to add additional printing to see what is going on
                        # Check 'from' addresses
                        if 'from' in conditions:
                            from_addresses = [addr['address'].lower() for addr in conditions['from']]
                            if any(addr in email.SenderEmailAddress.lower() for addr in from_addresses):
                                match = True
                                matched_keyword = next((addr['address'] for addr in conditions['from'] if addr['address'].lower() in email.SenderEmailAddress.lower()), None)
                                self.debug_print(f"Matched keyword in from address: {matched_keyword}")
                                self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")

                        # Check subject keywords
                        if 'subject' in conditions:
                            if any(keyword.lower() in email.Subject.lower() for keyword in conditions['subject']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['subject'] if keyword.lower() in email.Subject.lower()), None)
                                self.debug_print(f"Matched keyword in subject: {matched_keyword}")
                                self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")

                        # Check body keywords
                        if 'body' in conditions:
                            if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
                                self.debug_print(f"Matched keyword in body: {matched_keyword}")
                                matched_lines = [line for line in email.Body.splitlines() if matched_keyword.lower() in line.lower()]
                                if matched_lines:
                                    self.debug_print(f"First line of body that matches the keyword: {matched_lines[0]}")
                                # below will print all the body lines that match if needed for debugging
                                # for line in email.Body.splitlines():
                                #     if any(keyword.lower() in line.lower() for keyword in conditions['body']):
                                #         self.debug_print(f"Body: {line}")

                        # Check header keywords
                        if 'header' in conditions:
                            if any(keyword.lower() in email_header for keyword in conditions['header']):
                                match = True
                                matched_keyword = next((keyword for keyword in conditions['header'] if keyword.lower() in email_header.lower()), None)
                                self.debug_print(f"Matched keyword in header: {matched_keyword}")
                                matched_lines = [line for line in email_header.splitlines() if matched_keyword.lower() in line.lower()]
                                if matched_lines:
                                    self.debug_print(f"First line of header that matches the keyword: {matched_lines[0]}")
                                # below will print all the body lines that match if needed for debugging
                                # for header in email_header.splitlines():
                                #     if any(keyword.lower() in header.lower() for keyword in conditions['header']):
                                #         self.debug_print(f"Header: {header}")

                        # Check for attachments - not using. could be added later - will need to be updated; will not work as-is
                        # if 'has_attachments' in conditions:
                        #     if bool(email.Attachments.Count > 0) != conditions['has_attachments']:
                        #         match = True

                    # Check exceptions
                        if 'from' in exceptions:
                            from_addresses = [addr['address'].lower() for addr in exceptions['from']]
                            if any(addr in email.SenderEmailAddress.lower() for addr in from_addresses):
                                match = False
                                matched_keyword = next((addr['address'] for addr in exceptions['from'] if addr['address'].lower() in email.SenderEmailAddress.lower()), None)
                                self.debug_print(f"Exception matched keyword in from address: {matched_keyword}")
                                self.debug_print(f"From: {self._sanitize_string(email.SenderEmailAddress)}")

                        # Check subject keywords in exceptions
                        if 'subject' in exceptions:
                            if any(keyword.lower() in email.Subject.lower() for keyword in exceptions['subject']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['subject'] if keyword.lower() in email.Subject.lower()), None)
                                self.debug_print(f"Exception matched keyword in subject: {matched_keyword}")
                                self.debug_print(f"Subject: {self._sanitize_string(email.Subject)}")

                        # Check body keywords in exceptions
                        if 'body' in exceptions:
                            if any(keyword.lower() in email.Body.lower() for keyword in exceptions['body']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['body'] if keyword.lower() in email.Body.lower()), None)
                                self.debug_print(f"Exception matched keyword in body: {matched_keyword}")
                                self.debug_print(f"Body: {self._sanitize_string(email.Body)}")

                        # Check header keywords in exceptions
                        if 'header' in exceptions:
                            if any(keyword.lower() in email_header for keyword in exceptions['header']):
                                match = False
                                matched_keyword = next((keyword for keyword in exceptions['header'] if keyword.lower() in email_header.lower()), None)
                                self.debug_print(f"Exception matched keyword in header: {matched_keyword}")
                                for header in email_header.splitlines():
                                    self.debug_print(f"Header: {header}")

                        # # Check for attachments - not using. could be added later - will need to be updated; will not work as-is
                        # if 'has_attachments' in conditions:
                        #     if bool(email.Attachments.Count > 0) != conditions['has_attachments']:
                        #         match = False

                        if match:
                            self.debug_print(f"Email matches rule: {rule['name']}")
                            # Perform actions based on the rule
                            actions = rule['actions']
                            self.debug_print(f"Performing actions: {actions}")
                            if 'assign_to_category' in actions and actions['assign_to_category']['category_name']:
                                rule_name = rule['name']
                                category_name = self.rule_to_category.get(rule_name, actions['assign_to_category']['category_name'])
                                email.Categories = category_name
                                email.Save()
                                self.debug_print(f"Email assigned to category '{category_name}'")
                            if 'assign_to_category' in actions and actions['assign_to_category']['category_name']:
                                # ***category name is not being passed.  Will setup a table per email rule to assign it "semi-manually"
                                email.Categories = actions['assign_to_category']['category_name']
                                email.Save()
                                self.debug_print(f"Email assigned to category '{actions['assign_to_category']['category_name']}'")
                            if 'mark_as_read' in actions and actions['mark_as_read']:
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                                email.UnRead = False
                                self.debug_print("Email marked as read")
                            if 'clear_flag' in actions and actions['clear_flag']:
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                                email.Flag.Clear()
                                self.debug_print("Email flag cleared")
                            if 'set_importance' in actions and actions['set_importance']['importance_level']:
                                email.Importance = actions['set_importance']['importance_level']
                                email.Save()
                                self.debug_print(f"Email importance set to {actions['set_importance']['importance_level']}")
                            if 'set_sensitivity' in actions and actions['set_sensitivity']['sensitivity_level']:
                                email.Sensitivity = actions['set_sensitivity']['sensitivity_level']
                                email.Save()
                                self.debug_print(f"Email sensitivity set to {actions['set_sensitivity']['sensitivity_level']}")
                            if 'mark_as_task' in actions and actions['mark_as_task']['task_due_date']:
                                email.TaskDueDate = actions['mark_as_task']['task_due_date']
                                email.Save()
                                self.debug_print(f"Email marked as task with due date: {actions['mark_as_task']['task_due_date']}")
                            if 'play_sound' in actions and actions['play_sound']['sound_file']:
                                import winsound
                                winsound.PlaySound(actions['play_sound']['sound_file'], winsound.SND_FILENAME)
                                self.debug_print(f"Played sound: {actions['play_sound']['sound_file']}")
                            if 'display_desktop_alert' in actions and actions['display_desktop_alert']:
                                self.debug_print("Desktop alert displayed")
                                # Implement desktop alert display logic here
                            if 'copy_to_folder' in actions and actions['copy_to_folder']['folder_name']:
                                folder_name = actions['copy_to_folder']['folder_name']
                                target_folder = self.target_folder.Folders[folder_name]
                                email.Copy().Move(target_folder)
                                self.debug_print(f"Email copied to '{folder_name}' folder")
                            if 'forward' in actions and actions['forward']:
                                forward_recipients = [recipient['address'] for recipient in actions['forward']]
                                forward_email = email.Forward()
                                forward_email.To = ";".join(forward_recipients)
                                forward_email.Send()
                                self.debug_print(f"Email forwarded to: {', '.join(forward_recipients)}")
                            if 'reply' in actions and actions['reply']['template']:
                                reply_email = email.Reply()
                                reply_email.Body = actions['reply']['template']
                                reply_email.Send()
                                self.debug_print("Auto-reply sent")
                            if 'redirect' in actions and actions['redirect']:
                                redirect_recipients = [recipient['address'] for recipient in actions['redirect']]
                                redirect_email = email.Forward()
                                redirect_email.To = ";".join(redirect_recipients)
                                redirect_email.Send()
                                self.debug_print(f"Email redirected to: {', '.join(redirect_recipients)}")
                            if 'print' in actions and actions['print']:
                                email.PrintOut()
                                self.debug_print("Email printed")
                            if 'run_script' in actions and actions['run_script']['script_path']:
                                exec(open(actions['run_script']['script_path']).read())
                                self.debug_print(f"Script executed: {actions['run_script']['script_path']}")
                            if 'start_application' in actions and actions['start_application']['application_path']:
                                import subprocess
                                subprocess.Popen(actions['start_application']['application_path'])
                                self.debug_print(f"Application started: {actions['start_application']['application_path']}")
                            if 'move_to_folder' in actions and actions['move_to_folder']['folder_name']:
                                folder_name = actions['move_to_folder']['folder_name']
                                target_folder = self.target_folder.Folders[folder_name]
                                email.Move(target_folder)
                                self.debug_print(f"Email moved to '{folder_name}' folder")
                            if 'stop_processing_more_rules' in actions and actions['stop_processing_more_rules']:
                                self.debug_print("Stopping processing more rules")
                                # this flag is not being passed by outlook, so will never be set.  Keeping in case fixed in the future
                            if 'delete' in actions and actions['delete']:
                                if email.UnRead:
                                    email.UnRead = False  # Delete implies marking the item as read
                                    self.debug_print(f"Email marked as read")
                                if hasattr(email, 'Flag'):
                                    email.Flag.Clear()      # Delete implies clearing the flag
                                    self.debug_print(f"Email flag was cleared")
                                # assign category based on rule name
                                try:
                                    rule_name = rule['name']
                                    category_name = self.rule_to_category.get(rule_name, actions['assign_to_category']['category_name'])
                                    email.Categories = category_name
                                    email.Save()
                                    self.debug_print(f"Email assigned to category '{category_name}'")
                                except Exception as e:
                                    self.debug_print(f"Error assigning category to email: {str(e)}")

                                try:
                                    # delete email
                                    email.Delete()
                                    email_deleted = True
                                    self.debug_print("Email: marked as read, flag cleared and deleted")
                                    # delete implies "Stop Processing More Rules".  Continue will go to next email
                                except Exception as e:
                                    self.debug_print(f"Error deleting email: {str(e)}")

                                break # If delete, then process no more rules and go to next email
                            continue  # Go to the next email if one rule matches

                    # After all email rules are processed and it did not match any rules and the email has not been deleted, then check for phishing indicators
                    if not (email_deleted):
                        indicators = self.check_phishing_indicators(email)
                        if indicators:
                            flagged_count += 1
                            self.debug_print(f"Phishing indicators found: {indicators}")
                        else:
                            self.debug_print("No conditions or phishing indicators found")
                        # If it is in the Bulk Mail folder, but nothing indicated via rules or phishing,
                        # show the body and header, so we information needed to add it to a rule
                        for line in email.Body.splitlines():
                            self.debug_print(f"Body: {line}")
                        for header in email_header.splitlines():
                            self.debug_print(f"Header: {header}")


                except Exception as e:
                    self.debug_print(f"Error processing email: {str(e)}")

            self.debug_print(f"\nProcessing Summary:")
            self.debug_print(f"Processed {processed_count} emails")
            self.debug_print(f"Flagged {flagged_count} emails as suspicious")

        except Exception as e:
            self.debug_print(f"Error in process_emails: {str(e)}")
            raise

# %%
"""Main function to run the security agent"""
try:
    print("\nStarting Outlook Security Agent with DEBUG = {DEBUG}")
    print("This will make changes")
    print("Check the console output and outlook_security.log for detailed information")

    # Initialize agent with debug mode enabled
    agent = OutlookSecurityAgent()  # call with defaults
    rules_json = agent.get_outlook_rules()
    #print(rules_json)

    # Process last 24 hours of emails
    agent.process_emails(rules_json)

    print("Complete. Check the log file for detailed analysis.\n\n")

except Exception as e:
    print(f"\nError: {str(e)}")
    logging.error(f"Main execution error: {str(e)}")
# Out:
# Starting Outlook Security Agent with DEBUG = {DEBUG}
# This will make changes
# Check the console output and outlook_security.log for detailed information
# 2025-04-30 10:41:02,236 - DEBUG - Initializing agent for kimmeyharold@aol.com, folder: Bulk Mail
# 2025-04-30 10:41:02,237 - DEBUG - Debug mode: True
# 2025-04-30 10:41:02,238 - DEBUG - Searching for folder: Bulk Mail in account: kimmeyharold@aol.com
# 2025-04-30 10:41:02,267 - DEBUG - Checking account: kimmeyharold@aol.com
# 2025-04-30 10:41:02,270 - DEBUG - Found matching account: kimmeyharold@aol.com
# 2025-04-30 10:41:02,288 - DEBUG - Accessed root folder: kimmeyharold@aol.com
# 2025-04-30 10:41:02,300 - DEBUG - Found target folder directly: Bulk Mail
# 2025-04-30 10:41:02,303 - DEBUG - Converting Outlook rules to JSON format...
# 2025-04-30 10:41:02,329 - DEBUG - Processing 7 rules...
# 2025-04-30 10:41:02,339 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteHeader
# 2025-04-30 10:41:02,361 - DEBUG - Conditions['from']: []
# 2025-04-30 10:41:02,361 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-04-30 10:41:02,385 - DEBUG - Conditions_obj.Body.Text: None
# 2025-04-30 10:41:02,404 - DEBUG - Conditions_obj.MessageHeader.Text: ('@janiejournal.xyz', 'Construction-JobSearch', 'flexiglobal.fun', 'liftabl.com', '@pactera.com', 'teckrappid.com', 'earlyreviewer@gmail.com', '@cold-comforts.com', '@thebestservice.club', '@promotionsanddeals.club', '@newsdarts.com', 'royamail.uk', '@primarymash.store', 'sctelco.net.au', 'summernew.club', 't-online.de', '@customguide.com', 'blabber.buzz', '@darkrhinosecurity.com', '@vgroupinc.com', 'your-great.site', '@tecksuite.com', 'excelerplan.com', 'promotionoffer.site', '@largeteck.com', '@simon-jones.com', '@offers.com', '@melateck.com', '@amextop.com', 'kemo7766@yahoo.com', 'lindsay.moran@roberthalf.com', 'mapjobz.com', 'mccarthysearch.com', 'ppdptn@yahoo.com', 'cpm-masters.com', 'dealsketo.store', 'runtym.com', 'thinkurmails.com', 'jyothivkr@yahoo.com', '@parlermailer.com', '@niceteck.com', '@rankteck.com', '@nutritops.com', '@freedomworks.org', 'thedailymaurisa.xyz', 'janieable.store', 'taskomania.com', 'leonsecretdiary.club', 'shortplanks.xyz', 'ledenipe.store', 'mcbc22.gq', 'arelocations.in', 'randony.com', 'huvrcam.com', '@offeo.com', 'vividseats.com', 'thealbertejournal.site', 'viralfitzone.com', 'mSvcrenewyoucompany.com', 'mvTqrenewyoucompany.com', '.com.au', 'email.nbc.com', '@bellaliant.net', 'nosecretdiary.club', 'offersal-foryou.club', '@axelon.com', '@ozy.com', '@teckviews.com', '@qemailserver.com', 'onlythenews.site', 'trythisnew.online', 'Brianna John', '@thebarnesjournal.xyz', 'ZudCahaana.org', '@offers.com', 'googlegroups.com', 'getreadyfornews.onlin', '@techoneit.com', 'underarmour.com', '@wtocook.info', '@textingoverload.club', '@themasonpost.club', '@russelldiary.xyz', '@nedfsdkjds.com', '@spitefulblog.club', '@widevastblog.club', '@smartdiety.info', '@theangelajournal.club', '@drummingfreak.xyz', '@redskymaurisa.xyz', '@thecornwalltimes.xyz', 'amzlockedcustomer.com', '@theruizpost.xyz', '@epm-power.com', 'scoutbazaar.one', 'drjtechservice@gmail.com', '@alberteable.club', '@promotionoffer.online', '.co.nz', '@sites.careerbuilder.com', 'russeltimes.club', '@xfaggert.com', '@niceplans.fun', '@dealoffers.xyz', '@customerdept.me', 'evacuatedtech.com', '@turing.com', '@zintro.com', '@flipjobz.com', '@smarttobehere.fun', '@bora.net', 'oriental-trading.com', 'buysub.com', 'pwsj.com', '@varite.com', 'smartoffers.sho', '@sandysmithnc.com', '@hotdealls.shop', '@affiliteo.shop', 'thenickjournal.club', 'va5x.com', '@dancetotune.club', '@offfers.com', '@reedsy.com', '@ebatesfocus.com', 'zou9lou9.com', 'wptavern.com', '.safeopt.com', '@turing.jp', 't-op-offer.com', '@alignable.com', '.arlo.com', '@therussellpost.club', '@freaksday.com', '@porsuite.online', '@happycart.space', '@agentofficemail.com', '@techotechs.com', '@turing.bz', 'addto-cart.co.uk', '@servupdt.com', 'thedailyleon.xyz', '@diverselynx.com', 'nickdiary.xyz', 'wingrinandbearit.com', '@winreality.com', '.xyz', '@wireaustralia.com', '@cpm-pros.com', 'vegol4.live', 'your-smartoffers.club', '@tesca.id', '@healthyish.icu', '@allieolson.work', 'frex.com.au', '@lifecrest.best', '@therusselltoday.store', 'owls@onmicrosoft.work', '@sandysmithnc.com', '@theartofdrumming.fun', '@bakedrumread.store', '@promotionoffers.club', 'janiesecretdiary.club', '.club', '.shop', 'seven7them.com', 'realsimple.com', 'instyle.com', 'offerdeals.co', 'fostertoday.fun', 'sommodrive.com', 'bricklinik.com', 'hnjzsjmh.mobi', '@niceday.online', 'conservativedailyalerts.com', 'gilzine.com', 'primaryhackney.uk', 'virtualrealitymarketing.com', '.co.uk', '@news555.org', 'theonlygreeting.com', 'herculesinstitute.com', 'cbblacksmiths.com', 'cosmicrewards.com', 'szkolnastrona.pl', 'hgemail.net', 'anthonyflowers0.com', 'juicysiren.icu', 'moen.com', '@turing.ac', '@limitgov.org', 'salsalabs.org', '@PMCentersUSA.com', 'fecunited.com', '@assumptionu.org', '@smuniversity.org', 'bedojedid.com', '@newoffers.space', '@artnostyle.com', 'thesalmonteam.store', '@topoffers-foryou.cfd', 'thefactteam.store', 'Lifetime.Life', 'lifetime ...
# 2025-04-30 10:41:02,488 - DEBUG - AssignToCategory action found, category_name: None
# 2025-04-30 10:41:02,547 - DEBUG - Exception conditions['from']: [{'address': 'store+61395140851@t.shopifyemail.com', 'name': 'store+61395140851@t.shopifyemail.com'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}]
# 2025-04-30 10:41:02,547 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-04-30 10:41:02,574 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', 'email.openai.com', 'lastpass.com', 'shopifyemail.com')
# 2025-04-30 10:41:02,575 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '.openai.com', '@lastpass.com')
# 2025-04-30 10:41:02,591 - DEBUG - Successfully processed rule: SpamAutoDeleteHeader
# 2025-04-30 10:41:02,600 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteBody
# 2025-04-30 10:41:02,619 - DEBUG - Conditions['from']: []
# 2025-04-30 10:41:02,630 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-04-30 10:41:02,630 - DEBUG - Conditions_obj.Body.Text: ('Denton Bay Management', 'Deutsche Bank', 'position of Package Manager', 'for Parcel Worker', 'Capital Funding, LLC', 'Title: Package Manager', 'Organization of African Unity', 'United Nations Compensation Commission', 'First Marsh Capital Funding', 'Pack Supervisor', 'CWCramer Investments', 'namestee-redirect-71.blogspot.com', 'Space Tree Technologies', 'webruu.com', 'grco.de', 'allthebest.club', 'angel.aau.biz', 'tosbackrido', 'wewe.digital', 'allforyou.store', 'sys-confg.co.uk/cl/', 'chaiflow.com', 'd-allthebest', 'crescentsch', 'beautifyblog.com', 'get to shag even', 'haveshckee.site', 'beautytoto.site', 'booktarmedia.site', 'bostoffers.com', 'buttonlike.site', 'bangdgood', 'stylepekomed.site', 'Camp Lejeune', 'Topamax', 'erankolgds', 'lhatak.art', 'rani.live', 'iwantgetaway.', '/yeksabardo.', '/nortteh.', '/beliastick.', '/babysharkystore', '/radreact.com', 'ddaskeid.us', '/molbaydtr.', '/cdn.discordapp.com', '/poorlocation.site', '/lunansas.com', '/institution.store', '/lomerna.cc', '/cahamsonsmakj.art', '/thechnolotern.com', '/blueberrystore.site', '/adamshetzner.', '/elfinmarriage.', '/lasanteur.com', '/cidowien.com', '/auenwind', '/egsro.com/', '/50.193.138.95', '/new-word.co.uk', '/sazlompi.shop', '/superappoint.site', '/aressive.com', '/bangalarood', '/babyalicea', '/chitanodaily', '/nonosfertop', '/loppey.com/', '/cariable.com', '/zupimages.net', 'francescamaceroni', '/brevele.com', 'marmou.store/', '/bogmil', '/twentifyin', 'cahamsonsmakj.art/', 'poneytelecom.eu/', '/satucart.com', '/britiquare.com', '/graspect.com', '.graspect.com', '.yeksabardo.', '.britiquare.com', '.satucart.com', '.twentifyin', '.bogmil', '.brevele.com', '.zupimages.net', '.cariable.com', '.loppey.com/', '.nonosfertop', '.chitanodaily', '.babyalicea', '.bangalarood', ',aressive.com', '.superappoint.', '.sazlompi.', '.new-word.co', '.egsro.', '.auenwind.', '.cidowien.', '.lasanteur.', '.elfinmarriage.', '.adamshetzner.', '.blueberrystore.', '.thechnolotern.', '.cahamsonsmakj.', '.lomerna.', '.institution.store', '.lunansas.', '/vertnajd.shop', '.vertnajd.', '.complication.online', '.poorlocation.', '.cdn.discordapp.com', '.molbaydtr.', '.ddaskeid.', '.radreact.', '.kunsttherapie.', '/kunsttherapie.', '.babysharkystore.', '.beliastick.', '.nortteh.', '.yeksabardo.', '.rani.', '.lhatak.', '.stylepekomed.', '.beautytoto.', '.haveshckee.', '/thechnolotern.com', '.thechnolotern.', '.beautifyblog.', '.chaiflow.', '.allforyou.', '.auu.biz', 'unvonvrslrfvstty.', 'canvvas.', '.duckdns.', 'irishpeddlernow.', 'd-allthebest.', 'leadpha.', '/netflix-inmcsupport.', '/valenpod.', '.valenpod.', 'bitomagic.', 'shringrade.', 'shrturi.', 'ewesnesice.', '.com.au', 'maurisable.', 'trending-offers.', 'dailygerald.', '.searshomeservices.com', '/searshomeservices.', '/stlhalfmarathon', '.stlhalfmarathon', '/conferrific.com', '.conferrific.com', '.easiereats.', '/easiereats', '/pauligures.', '.pauligures.', '.differenchiopia.', '/differenchiopia.', '.wordthirst.', '/wordthirst.', '/trestaro.', '.trestaro.', '/buyplaydiscover.', '.buyplaydiscover.', '/spherings.', '.spherings.', '/linepregnant', '.linepregnant', '/campgumus', '/adventurousamend.', '.adventurousamend.', 'cyclinth.com', 'reflectrum.com', 'ransferrible.com', 'mailbestusa.', 'powerrecruiter.', '/swarm-stone.', '.swarm-stone.', '.marsello.com', '.macibe.com', '/macibe.com', '/screepin.com', '.screepin.com', '/garriests.com', '.garriests.com', 'schoolofwordplay.', '/ktirff.com', '.ktirff.com', '/edcpub.com', '.edcpub.com', '/thronical.com', '.thronical.com', '.iasgk.com', '/iasgk.com', '.stransferrel.com', '/stransferrel.com', '.yesterin.com', '/yesterin.com', '.alsaqqr.com', '/alsaqqr.com', 'synonymoustransfer', '213.226.189.211/', '/oneway-level.com', '.oneway-level.com', '.xiken.top', '/xiken.top', '/anyuying.top', '.anyuying.top', '.feelbmico.com', '/feelbmico.com', '.mightrays.com', '/mightrays.com', '.drbubcho.com', '.standtro.com', '/standtr ...
# 2025-04-30 10:41:02,652 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-04-30 10:41:02,688 - DEBUG - AssignToCategory action found, category_name: None
# 2025-04-30 10:41:02,755 - DEBUG - Exception conditions['from']: [{'address': 'ebilling_noreply@ClevelandWater.com', 'name': 'ebilling_noreply@ClevelandWater.com'}, {'address': 'eBilling@NEORSD.org', 'name': 'eBilling@NEORSD.org'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}, {'address': 'app@clover.com', 'name': 'app@clover.com'}, {'address': 'noreply@email.openai.com', 'name': 'noreply@email.openai.com'}, {'address': 'do-not-reply-support@lastpass.com', 'name': 'do-not-reply-support@lastpass.com'}, {'address': 'support@lastpass.com', 'name': 'LastPass'}, {'address': 'store+61395140851@t.shopifyemail.com', 'name': 'store+61395140851@t.shopifyemail.com'}, {'address': 'orders@tcsjerky.com', 'name': 'orders@tcsjerky.com'}, {'address': 'TrackingUpdates@fedex.com', 'name': 'TrackingUpdates@fedex.com'}, {'address': 'billing@lastpass.com', 'name': 'billing@lastpass.com'}]
# 2025-04-30 10:41:02,755 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-04-30 10:41:02,773 - DEBUG - Exception conditions_obj.Body.Text: None
# 2025-04-30 10:41:02,791 - DEBUG - Exception conditions_obj.MessageHeader.Text: None
# 2025-04-30 10:41:02,791 - DEBUG - Successfully processed rule: SpamAutoDeleteBody
# 2025-04-30 10:41:02,791 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteFrom
# 2025-04-30 10:41:02,846 - DEBUG - Conditions['from']: [{'address': 'Solaris@ofefrsdtops.net', 'name': 'Solaris | Eco'}, {'address': 'Talcum@ofefrsdtops.net', 'name': 'Talcum Powder'}, {'address': 'Saatva@ofefrsdtops.net', 'name': 'Saatva@ofefrsdtops.net'}, {'address': 'Tractor@ofefrsdtops.net', 'name': 'Tractor@ofefrsdtops.net'}, {'address': 'support@doffersted.online.com', 'name': 'support@doffersted.online.com'}, {'address': 'Renewal@ofefrsdtops.net', 'name': 'Renewal@ofefrsdtops.net'}, {'address': 'House@ofefrsdtops.net', 'name': 'House@ofefrsdtops.net'}, {'address': 'guls@skimccormicks.com', 'name': 'guls@skimccormicks.com'}, {'address': 'centralitys@skimccormicks.com', 'name': 'centralitys@skimccormicks.com'}, {'address': 'thkariedawood@gmail.com', 'name': 'thkariedawood@gmail.com'}, {'address': 'Prostate@hotmail.com', 'name': 'Prostate@hotmail.com'}, {'address': 'Compensation@hotmail.com', 'name': 'Compensation@hotmail.com'}, {'address': 'sebastian@corleoneweddingplanners.com', 'name': 'sebastian@corleoneweddingplanners.com'}]
# 2025-04-30 10:41:02,846 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-04-30 10:41:02,889 - DEBUG - Conditions_obj.Body.Text: None
# 2025-04-30 10:41:02,945 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-04-30 10:41:02,974 - DEBUG - AssignToCategory action found, category_name: None
# 2025-04-30 10:41:03,041 - DEBUG - Exception conditions['from']: []
# 2025-04-30 10:41:03,047 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-04-30 10:41:03,064 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', 'openai.com', 'lastpass.com')
# 2025-04-30 10:41:03,082 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@tcsjerky.com', '@NEORSD.org', '@clover.com', '@email.openai.com', '@lastpass.com', 'store+61395140851@t.shopifyemail.com')
# 2025-04-30 10:41:03,094 - DEBUG - Successfully processed rule: SpamAutoDeleteFrom
# 2025-04-30 10:41:03,094 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteSubject
# 2025-04-30 10:41:03,108 - DEBUG - Conditions['from']: []
# 2025-04-30 10:41:03,125 - DEBUG - Conditions_obj.Subject.Text: ('online dating', 'AARP', 'Nugenix', 'nugenix', 'romantic relationship', 'dating site', 'dating website', 'one night stand', 'Walmart Surprise', 'Life Line', 'desire a lady', 'Home Warranty', 'home warranty', 'Topamax', 'topamax', 'Online Casino', 'online casino', 'Pro Lights', 'pro lights', 'Harbor Freight', 'harbor freight', '5-second morning hack', 'Valvoline Oil', 'valvoline oil', 'one night stand', 'Norton-Anti-Virus', 'norton-Anti-Virus', 'norton-anti-virus', 'norton anti-virus', 'Construction-JobSearch', 'trumpvictory45', 'trumpvictory47', 'eharmony', 'ready for a relationship', 'dates with me', 'Proud Patriots', 'dating me')
# 2025-04-30 10:41:03,136 - DEBUG - Conditions_obj.Body.Text: None
# 2025-04-30 10:41:03,152 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-04-30 10:41:03,168 - DEBUG - AssignToCategory action found, category_name: None
# 2025-04-30 10:41:03,252 - DEBUG - Exception conditions['from']: []
# 2025-04-30 10:41:03,258 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-04-30 10:41:03,274 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', '.clover.com', '/clover.com', '.openai.com', '/openai.com', '.lastpass.com', '/lastpass.com', '.aa.com', '/aa.com', '.ftc.com', '/ftc.com', 'kaggle', '.shopifyemail.com', '/shopifyemail.com')
# 2025-04-30 10:41:03,289 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '.openai.com', '@lastpass.com', '@aa.com', '@ftc.com', 'kaggle')
# 2025-04-30 10:41:03,306 - DEBUG - Successfully processed rule: SpamAutoDeleteSubject
# 2025-04-30 10:41:03,306 - DEBUG -
#
# Analyzing rule: SpamAutoDeleteBody-imgur.com
# 2025-04-30 10:41:03,322 - DEBUG - Conditions['from']: []
# 2025-04-30 10:41:03,324 - DEBUG - Conditions_obj.Subject.Text: None
# 2025-04-30 10:41:03,324 - DEBUG - Conditions_obj.Body.Text: ('.imgur.', '/imgur.')
# 2025-04-30 10:41:03,347 - DEBUG - Conditions_obj.MessageHeader.Text: None
# 2025-04-30 10:41:03,367 - DEBUG - AssignToCategory action found, category_name: None
# 2025-04-30 10:41:03,403 - DEBUG - Exception conditions['from']: []
# 2025-04-30 10:41:03,421 - DEBUG - Exception conditions_obj.Subject.Text: None
# 2025-04-30 10:41:03,437 - DEBUG - Exception conditions_obj.Body.Text: ('ClevelandWater.com', 'NEORSD.org', 'tcsjerky.com', 'clover.com', '.openai.com', '/openai.com', 'lastpass.com', '/aa.com', '.aa.com', '.ftc.com', '/ftc.com')
# 2025-04-30 10:41:03,453 - DEBUG - Exception conditions_obj.MessageHeader.Text: ('scottkimmey1@gmail.com', '@ClevelandWater.com', '@NEORSD.org', '@tcsjerky.com', '@clover.com', '@email.openai.com', '@lastpass.com', '@t.shopifyemail.com', '@aa.com', 'kaggle', '@ftc.gov')
# 2025-04-30 10:41:03,488 - DEBUG - Successfully processed rule: SpamAutoDeleteBody-imgur.com
# 2025-04-30 10:41:03,506 - DEBUG -
#
# Starting email processing (Simulation Mode)
# 2025-04-30 10:41:03,512 - DEBUG - Target folder: Bulk Mail
# 2025-04-30 10:41:03,512 - DEBUG - Processing emails from last 365 days
# 2025-04-30 10:41:03,530 - DEBUG - Total emails found: 270
# 2025-04-30 10:41:03,530 - DEBUG - Beginning email analysis:
# 2025-04-30 10:41:03,807 - DEBUG -
#
# Email 1:
# 2025-04-30 10:41:03,809 - DEBUG - Subject: You might be paying too much for auto insurance - check now
# 2025-04-30 10:41:03,809 - DEBUG - From: piecen@smudmarketplace.com
# 2025-04-30 10:41:03,894 - DEBUG - Received: 2025-04-30 10:34:22+00:00
# 2025-04-30 10:41:04,073 - DEBUG - No conditions or phishing indicators found
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,073 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,086 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:
# 2025-04-30 10:41:04,102 - DEBUG - Body:  <https://smudmarketplace.com/i5oc74o/tryuc0nyhpieLpO5ZJGHtToEM7zTq7OxM7zRDXd9D4ioqRGnh4sBLRKf-/6x0h>
# 2025-04-30 10:41:04,117 - DEBUG - Body:
# 2025-04-30 10:41:04,119 - DEBUG - Body:
# 2025-04-30 10:41:04,120 - DEBUG - Body:  <https://smudmarketplace.com/jkc/tryuc0nyhpieLpO5ZJGHtToEM7zTq7OxM7fRDXd9D4ioqRGnh4sBLRYr-/mc17hlyb>
# 2025-04-30 10:41:04,121 - DEBUG - Body:
# 2025-04-30 10:41:04,122 - DEBUG - Body:
# 2025-04-30 10:41:04,124 - DEBUG - Body:
# 2025-04-30 10:41:04,125 - DEBUG - Body:
# 2025-04-30 10:41:04,125 - DEBUG - Body:
# 2025-04-30 10:41:04,125 - DEBUG - Body:
# 2025-04-30 10:41:04,125 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,130 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,142 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,158 - DEBUG - Body:
# 2025-04-30 10:41:04,174 - DEBUG - Body:
# 2025-04-30 10:41:04,174 - DEBUG - Body:
# 2025-04-30 10:41:04,174 - DEBUG - Body:
# 2025-04-30 10:41:04,174 - DEBUG - Header: Received: from 127.0.0.1
# 2025-04-30 10:41:04,174 - DEBUG - Header:  by atlas-production.v2-mail-prod1-bf1.omega.yahoo.com pod-id atlas--production-bf1-58d647f446-h8lc9.bf1.yahoo.com with HTTP; Wed, 30 Apr 2025 14:34:22 +0000
# 2025-04-30 10:41:04,174 - DEBUG - Header: Received: from 104.252.175.19 (EHLO pents.slammerd.com)
# 2025-04-30 10:41:04,174 - DEBUG - Header:  by 10.195.11.111 with SMTP;
# 2025-04-30 10:41:04,174 - DEBUG - Header:  Wed, 30 Apr 2025 14:34:22 +0000
# 2025-04-30 10:41:04,174 - DEBUG - Header: Reply-To: <piecen@smudmarketplace.com>
# 2025-04-30 10:41:04,174 - DEBUG - Header: From: =?UTF-8?B?QfOggId1dG9J86CAh25z86CAh3VyZUPzoICHb25u86CAh2Vj86CAh3QuY++/vQ==?=
# 2025-04-30 10:41:04,191 - DEBUG - Header: 	=?UTF-8?B?77+9b20=?= <piecen@smudmarketplace.com>
# 2025-04-30 10:41:04,191 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:41:04,191 - DEBUG - Header: Subject: =?UTF-8?B?WfOggIdvdSBt86CAh2nzoICHZ/OggIdodCBi86CAh2UgcPOggIfzoICHYfOggId5?=
# 2025-04-30 10:41:04,197 - DEBUG - Header: 	=?UTF-8?B?aW5nIHRv86CAh28g86CAh21186CAh/OggIdjaCBm86CAh29yIPOggIdhde+/vQ==?=
# 2025-04-30 10:41:04,197 - DEBUG - Header: 	=?UTF-8?B?77+986CAh3RvIGlu86CAh3N1cvOggIdhbmPzoICHZSAtIGNo86CAh/OggIdl77+9?=
# 2025-04-30 10:41:04,197 - DEBUG - Header: 	=?UTF-8?B?77+9Y2sgbm/zoICHdw==?=
# 2025-04-30 10:41:04,197 - DEBUG - Header: Date: Wed, 30 Apr 2025 10:32:10 -0400
# 2025-04-30 10:41:04,197 - DEBUG - Header: Message-ID: <7t2698w.U1isCg5457154.pGnRZ8es.D20tUcVZQI9xuF@smudmarketplace.com>
# 2025-04-30 10:41:04,197 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:41:04,197 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:41:04,210 - DEBUG - Header: 	boundary="----=_NextPart_000_106E_01DBB9BB.7F26E540"
# 2025-04-30 10:41:04,211 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:41:04,211 - DEBUG - Header: X-Originating-Ip: [104.252.175.19]
# 2025-04-30 10:41:04,211 - DEBUG - Header: Authentication-Results: atlas-production.v2-mail-prod1-bf1.omega.yahoo.com;
# 2025-04-30 10:41:04,211 - DEBUG - Header:  dkim=pass header.i=@smudmarketplace.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,211 - DEBUG - Header:  spf=pass smtp.mailfrom=smudmarketplace.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,211 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=smudmarketplace.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,211 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Wed, 30 Apr 2025 14:34:22 +0000
# 2025-04-30 10:41:04,211 - DEBUG - Header: X-YMailISG: qCInTScWLDt__Vh9CjYaPEPmorpJgkj3dPhkI.zOnuWuDVC2
# 2025-04-30 10:41:04,221 - DEBUG - Header:  CzO1qYACt6I2ORM4k3dFPHKZfL1_AIgbCRM6.QRD88GWOpbgyoCsnc9isFt9
# 2025-04-30 10:41:04,221 - DEBUG - Header:  tjFtwhyQIpCioCftho2I.7aQB50Tt3jcWbKl671rU_yFImD0jxrJ.u2oMjyn
# 2025-04-30 10:41:04,221 - DEBUG - Header:  nXm_WXmep6Qs8YJzgu2vtDcin6SEBMUJTisBhC8yQrKi4xq76YD62jaYTZgt
# 2025-04-30 10:41:04,221 - DEBUG - Header:  7U4rEGlEPBhTy.OwV19V07Wl4MNyVF4ONeB3NzgdRlV6CgVZTnRP6H94TQwz
# 2025-04-30 10:41:04,221 - DEBUG - Header:  1.LgT8ivsyFMq3_ESq8PntyqmM1QEc4IKb8fE_7C2YBW14C6gDx7Q7VdX2cb
# 2025-04-30 10:41:04,221 - DEBUG - Header:  uQYjZsqsAjCeX071B.l75uvHwsJ8Tg9wuJdX6MulYtb_zx5RsHg8YeBsulXH
# 2025-04-30 10:41:04,227 - DEBUG - Header:  e3xn1NXRB95vb3ajaBGMy5rbdTgHmM8Edi4FFSaczMGyteXHUSYFyHyNj0yR
# 2025-04-30 10:41:04,227 - DEBUG - Header:  M5hoYP90tdLG2a1vBs.SFCx7MknrxJf5NMUEKe3OaqKiDnHP0isXE.8eUfGL
# 2025-04-30 10:41:04,227 - DEBUG - Header:  B0JR0.MwGO0X6KvzX4VXAE2.Ha1vv.UQaK9pd5T.N7B4xShQXJtgAHfLI1uM
# 2025-04-30 10:41:04,227 - DEBUG - Header:  6rdTrJ0y70D7vxKUSsRFjN3zvvUh3JyHkiKvawoyiEJgbphSZ74vxH7Y0o98
# 2025-04-30 10:41:04,227 - DEBUG - Header:  WA47XE4kqnftIV3tt9FK836ZGxVQOCGHt7MnvWqiWqsKxPDgY7fHUId.bGx0
# 2025-04-30 10:41:04,233 - DEBUG - Header:  I7QljcG4_rw0jcb_fXrwOhQt38wZKhahJwYUaFSiK_L9OJWu083ei_S5ypNf
# 2025-04-30 10:41:04,233 - DEBUG - Header:  aeS85zDXYaFj6T.j1iOQtdK2ySgXc.J5Xa.rP86jB_nSvVuw0GAeqr2gm6LR
# 2025-04-30 10:41:04,233 - DEBUG - Header:  uKO8ge8rqixDMTurhXYWFhyVA8dvB8G6hE6BrB4f5l.Fmqv7K1GfIi5NXXr.
# 2025-04-30 10:41:04,233 - DEBUG - Header:  hfAul13hYfMZdErRZhYPnih9jkimrAVALKl1_YtZ6rMyK.ym8MinhPdYX7KV
# 2025-04-30 10:41:04,233 - DEBUG - Header:  ZuXY
# 2025-04-30 10:41:04,233 - DEBUG - Header: 	VDMZzOnt84kKCaIPEbpi3.4_zQ02.fdQ0_TekpLNBnLoUhd0a4y9VpgC
# 2025-04-30 10:41:04,239 - DEBUG - Header:  igQViQxwnj0T8U0jgGlbdT6V96XLq3AgPru_jzxf0t1Vg_OgW_aZIQpwtemn
# 2025-04-30 10:41:04,239 - DEBUG - Header:  tyHqBILitEEpdA5uVjHrTiIomkJH.f.DUH3sgZefswKe4KzlNo6Xgna51ZDQ
# 2025-04-30 10:41:04,239 - DEBUG - Header:  cIdZ_SmPiOdZufFTFm1MhjAW13WxiV.DYOkR11OniWZsg9TuA98atIqkerJj
# 2025-04-30 10:41:04,239 - DEBUG - Header:  SMdW78oU4MXTxCS6iOOeKLOrtghuNCfCGsO9y8tYnCXcLkrNYk_zdz5xnqjX
# 2025-04-30 10:41:04,239 - DEBUG - Header:  Bm1BjHAw8gCkX96iGcJf5Kw8a.WMEbuEiwoFgMGu0yLlOVji633b.foIDEqw
# 2025-04-30 10:41:04,239 - DEBUG - Header:  vDz._5nt7laLeRjBYq6lunzwFVZV4M5ErAUG2o.rMPfaPZB_cThT4GbDy1QJ
# 2025-04-30 10:41:04,239 - DEBUG - Header:  Yw_r5_0rR74avlA8fMapD2fgRanPKz9WO5QB
# 2025-04-30 10:41:04,239 - DEBUG - Header: List-Unsubscribe: <https://smudmarketplace.com/tryuc0nyhpieLpO5ZJGHt9OEM7zTq7OxM7fRDXd9D4ioqRGnh4sBLRYr2Jwgh1n7ZJi7cr->
# 2025-04-30 10:41:04,239 - DEBUG - Header: Thread-Index: AQJJc/NZ+3ULu48nRrI8OFToOyD4Hg==
# 2025-04-30 10:41:04,239 - DEBUG - Header:
# 2025-04-30 10:41:04,260 - DEBUG -
#
# Email 2:
# 2025-04-30 10:41:04,264 - DEBUG - Subject: Re: kimmeyharold, Urgent: Your Netflix Membership has Expired!ID: 9656989601.
# 2025-04-30 10:41:04,270 - DEBUG - From: noreply@accuweather.jp.net
# 2025-04-30 10:41:04,270 - DEBUG - Received: 2025-04-30 10:26:39+00:00
# 2025-04-30 10:41:04,524 - DEBUG - Matched keyword in body: .imgur.
# 2025-04-30 10:41:04,524 - DEBUG - First line of body that matches the keyword:  <https://i.imgur.com/r5fWXdP.png>
# 2025-04-30 10:41:04,524 - DEBUG - Email matches rule: SpamAutoDeleteBody-imgur.com
# 2025-04-30 10:41:04,524 - DEBUG - Performing actions: {'move_to_folder': {'folder_path': None, 'folder_name': None}, 'copy_to_folder': {'folder_path': None, 'folder_name': None}, 'assign_to_category': {'category_name': None}, 'delete': True, 'forward': [], 'redirect': [], 'play_sound': {'sound_file': None}, 'mark_as_task': {'task_due_date': None}}
# 2025-04-30 10:41:04,524 - DEBUG - Email marked as read
# 2025-04-30 10:41:04,540 - DEBUG - Email assigned to category 'SpamImgur'
# 2025-04-30 10:41:04,540 - DEBUG - Email: marked as read, flag cleared and deleted
# 2025-04-30 10:41:04,556 - DEBUG -
#
# Email 3:
# 2025-04-30 10:41:04,556 - DEBUG - Subject: Request $100 to $40,000 in Just Two Minutes
# 2025-04-30 10:41:04,556 - DEBUG - From: yplcnaxoi@nowthreading.com
# 2025-04-30 10:41:04,556 - DEBUG - Received: 2025-04-30 01:37:05+00:00
# 2025-04-30 10:41:04,768 - DEBUG - No conditions or phishing indicators found
# 2025-04-30 10:41:04,768 - DEBUG - Body:  <https://nowthreading.com/FH3CojQqNbx6EVC8TJEbP6rnZXTqRcZ2F1i54j1o5U6eYyK541IJpus17EltSTKSaYSDGoLpMFFBHF/wVaveEHpLA9Jio5>
# 2025-04-30 10:41:04,768 - DEBUG - Body:  <https://nowthreading.com/UAIegIyJ7pT0HNb4XUmC7oT85xaqTXIU3sTCIx0Rg8hDkONLW2Vhi6AE4StrZNUxw6nDclgO2RL7QIG/w3Ev7pt83FR6Jpb>
# 2025-04-30 10:41:04,768 - DEBUG - Body:
# 2025-04-30 10:41:04,783 - DEBUG - Body: Request $100 to $40,000 in Just Two Minutes
# 2025-04-30 10:41:04,783 - DEBUG - Header: Received: from 10.226.14.48
# 2025-04-30 10:41:04,783 - DEBUG - Header:  by atlas109.aol.mail.ne1.yahoo.com pod-id NONE with HTTPS; Wed, 30 Apr 2025 05:37:05 +0000
# 2025-04-30 10:41:04,783 - DEBUG - Header: Received: from 151.240.7.22 (EHLO wirelesssecurity-151240.dosassesranch.com)
# 2025-04-30 10:41:04,783 - DEBUG - Header:  by 10.226.14.48 with SMTPs
# 2025-04-30 10:41:04,788 - DEBUG - Header:  (version=TLS1_2 cipher=TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256);
# 2025-04-30 10:41:04,789 - DEBUG - Header:  Wed, 30 Apr 2025 05:37:05 +0000
# 2025-04-30 10:41:04,790 - DEBUG - Header: From: =?UTF-8?B?TvOggIFl86CAgXjzoICBdPOggIFE86CAgWHzoICBefOggIFQZfOggIFy86CAgQ==?=
# 2025-04-30 10:41:04,792 - DEBUG - Header: 	=?UTF-8?B?c/OggIFv86CAgW7zoICBYfOggIFs86CAgUzzoICBb/OggIFh86CAgW7zoICBIA==?=
# 2025-04-30 10:41:04,793 - DEBUG - Header: 	=?UTF-8?B?86CAgUzzoICBZfOggIFu86CAgWRp86CAgW7zoICBZ/OggIEg86CAgUHzoICBZA==?=
# 2025-04-30 10:41:04,795 - DEBUG - Header: 	=?UTF-8?B?86CAgXbzoICBafOggIFz86CAgW9y86CAgQ==?= <yplcnaxoi@nowthreading.com>
# 2025-04-30 10:41:04,796 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:41:04,797 - DEBUG - Header: Subject: =?UTF-8?B?UvOggIFl86CAgXHzoICBdfOggIFl86CAgXPzoICBdPOggIEg86CAgSQx86CAgQ==?=
# 2025-04-30 10:41:04,797 - DEBUG - Header: 	=?UTF-8?B?MPOggIEw86CAgSDzoICBdPOggIFv86CAgSDzoICBJPOggIE086CAgTDzoICBLA==?=
# 2025-04-30 10:41:04,799 - DEBUG - Header: 	=?UTF-8?B?86CAgTDzoICBMPOggIEw86CAgSDzoICBafOggIFu86CAgSDzoICBSvOggIF1cw==?=
# 2025-04-30 10:41:04,799 - DEBUG - Header: 	=?UTF-8?B?86CAgXTzoICBIPOggIFU86CAgXfzoICBb/OggIEg86CAgU3zoICBafOggIFu77+9?=
# 2025-04-30 10:41:04,803 - DEBUG - Header: 	=?UTF-8?B?77+9dfOggIF086CAgWVz86CAgQ==?=
# 2025-04-30 10:41:04,803 - DEBUG - Header: Date: Wed, 30 Apr 2025 01:37:03 -0400
# 2025-04-30 10:41:04,803 - DEBUG - Header: Message-ID: <f79c98861f08a9a47308dba6ce@nowthreading.com>
# 2025-04-30 10:41:04,803 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:41:04,803 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:41:04,803 - DEBUG - Header: 	boundary="----=_NextPart_000_0E89_01DBB973.C60C15E0"
# 2025-04-30 10:41:04,815 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:41:04,815 - DEBUG - Header: X-Originating-Ip: [151.240.7.22]
# 2025-04-30 10:41:04,815 - DEBUG - Header: Authentication-Results: atlas109.aol.mail.ne1.yahoo.com;
# 2025-04-30 10:41:04,815 - DEBUG - Header:  dkim=pass header.i=@nowthreading.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,815 - DEBUG - Header:  spf=pass smtp.mailfrom=nowthreading.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,815 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=nowthreading.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:04,822 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Wed, 30 Apr 2025 05:37:05 +0000
# 2025-04-30 10:41:04,823 - DEBUG - Header: X-YMailISG: pTGGdGMWLDsms4i51FZb39Dt.ZgspgTtsRTiC25Wo20fE.AK
# 2025-04-30 10:41:04,825 - DEBUG - Header:  qX9YPrOpe2s9ih6v3MBbiysbBkrkjVe6b4CdAOAHDhH.1Cr4b48i..Xjzxpz
# 2025-04-30 10:41:04,825 - DEBUG - Header:  oqgC1gJQoyZbUAaGk2BYCmYwldZ6rD8Z.s_cIm6gWRhhpouSf2JOm7mFjWhS
# 2025-04-30 10:41:04,826 - DEBUG - Header:  wmW8VdSY2iZfFPTPr_pfsjR5Y6sLtM5Lsw7Xkn_y_2S5oc51NjN60V1SZB8P
# 2025-04-30 10:41:04,828 - DEBUG - Header:  opxAEZXeVAKMHoXNY9FuaxKNl1icvUD9Nfe1XL3Zs1Hqztpmch7xS15_.0ae
# 2025-04-30 10:41:04,829 - DEBUG - Header:  y4vzbNNq2LjHQLPf2xuxoyjRfGDNtdJ.cMZgf_PxIekQbA6pGJ7bB6frdgWD
# 2025-04-30 10:41:04,830 - DEBUG - Header:  uhq22VQn_ywo.Er_oDBjuplfVC98fFnGW.oBSQ1AwCYACGTbdiMpxJljuslO
# 2025-04-30 10:41:04,831 - DEBUG - Header:  XfVHVrczymhmkXXs43FhKgHm3NguWyuxU2Yyg971PHoJEiGqOIksxJmlFPa3
# 2025-04-30 10:41:04,831 - DEBUG - Header:  fB5b9g3teO_Q_uCmiWXRPpAUV736YuI8mPctDXr2aLKEP9VGk0HzinBJ7a8v
# 2025-04-30 10:41:04,831 - DEBUG - Header:  a1LQvf2JqK4dIOls95iTrDQmEKvkLBaeR.fha72hHzDEIFabk4AQPnThq5jF
# 2025-04-30 10:41:04,831 - DEBUG - Header:  zEZQE.f7dxHxq7j.gEGndUchMahAIgkQ41Lyrk_Ejc8njs50mGIeeaxZvx7O
# 2025-04-30 10:41:04,831 - DEBUG - Header:  5bVSNJ37WyoOYWRrg8Ij3NJUBYvDurGTtr.krvNgYdPj57AjksUqBpncKPnt
# 2025-04-30 10:41:04,831 - DEBUG - Header:  KTNv6SuDL0g5e9df0zBpn11ntuLbL1Orx2dx9j3L4sdDIB8M5hpew_TvKNDq
# 2025-04-30 10:41:04,831 - DEBUG - Header:  mHvuvl.dA2jFaS_7uLWgvKNXRPCNNWi0Bg0nlduWSeGC7Czh8WRI9Jm5_fhr
# 2025-04-30 10:41:04,831 - DEBUG - Header:  q3unSZJ1H88mwkL4MiJeO0QXtr1IUL.S.CGePPBsQYehd1V2itZOGYl6.0Oa
# 2025-04-30 10:41:04,831 - DEBUG - Header:  hM53g31b8mznhEfYtf9BB8NIfKZipLSvF2dzgBJC0_EQm8mr8hyu3wZxGrgm
# 2025-04-30 10:41:04,831 - DEBUG - Header:  f3OG
# 2025-04-30 10:41:04,831 - DEBUG - Header: 	hkULkvKebtwnD7asdoyRT0dt7mHyIIIeL_yxmifEIwT7BQ..wov1x9en
# 2025-04-30 10:41:04,831 - DEBUG - Header:  bDq2Da1CBOqSd05W.vjFUIC4IZ4F_qp23hDY94_7c4cMOr6ceUORmVrATO6D
# 2025-04-30 10:41:04,831 - DEBUG - Header:  p_V6MiXw67enUVC9Bga6FzRRz0pn_Drego3Mj5VwmJ.48PJJTa7Qvs8y9t5o
# 2025-04-30 10:41:04,847 - DEBUG - Header:  izvoCbInaYyl7knuW0biOX6V9duVVKIiATtNP.3wzp4Fon8lSV8ZXyuZs_Vb
# 2025-04-30 10:41:04,847 - DEBUG - Header:  Cj.X_z.znWkYfbqs8OABJfV97ofzKLjHSVWedLF9Ft0jnEIpGkyRSGeaQh.R
# 2025-04-30 10:41:04,847 - DEBUG - Header:  dS_KV1lInAg_ujA40fXlBX5KYLPcnRQsM8mYzhVm_7QJZtPid48FrAiuFv_g
# 2025-04-30 10:41:04,847 - DEBUG - Header:  7cW2sij0T_lHDaBoFHuFe.36VAT7b8BBY2Xc7R.QXbWoemCjpe.gNdb1KOU9
# 2025-04-30 10:41:04,847 - DEBUG - Header:  Nfos_Tnscm6SFwY2x.se
# 2025-04-30 10:41:04,847 - DEBUG - Header: List-Unsubscribe: <mailto:unsubscribe@nowthreading.com?body=unsubscribe&subject=unsubscribe-Z5u3ChksaMGBzw6r7hjsi-qAls9NNdnsoNqaM5im8KJmxbv7c7gF9eNGReG6sJgs8Cg507Kx2puD&jvJ7Bu31VGvwbDlEtqB2r3Cx2738HX0xsX1FZtEavs7XPzYmWADWB2Gp2itp5g4bc3865Pf05b1DTQc0tB9Fw3D4ia5hPv6nwZEz>
# 2025-04-30 10:41:04,847 - DEBUG - Header: Thread-Index: AQHgRaj3D8cJlOQ8t61u0VW5uel6Xw==
# 2025-04-30 10:41:04,847 - DEBUG - Header:
# 2025-04-30 10:41:04,871 - DEBUG -
#
# Email 4:
# 2025-04-30 10:41:04,880 - DEBUG - Subject: Cancer Lawsuit Finder: Diagnosed with Cancer after 1999? Billions awarded. Kidney, Testic
# 2025-04-30 10:41:04,888 - DEBUG - From: xdkxtwjsmfro@mattamis.com
# 2025-04-30 10:41:04,888 - DEBUG - Received: 2025-04-30 00:43:52+00:00
# 2025-04-30 10:41:05,156 - DEBUG - No conditions or phishing indicators found
# 2025-04-30 10:41:05,157 - DEBUG - Body:
# 2025-04-30 10:41:05,158 - DEBUG - Body:
# 2025-04-30 10:41:05,158 - DEBUG - Body:
# 2025-04-30 10:41:05,159 - DEBUG - Body:
# 2025-04-30 10:41:05,160 - DEBUG - Body:
# 2025-04-30 10:41:05,161 - DEBUG - Body:
# 2025-04-30 10:41:05,162 - DEBUG - Body:
# 2025-04-30 10:41:05,163 - DEBUG - Body:
# 2025-04-30 10:41:05,164 - DEBUG - Body:  <https://mattamis.com/63gin2mus?3kfflibt=gzB-80rmtTAU6qNy10qm1FkTsmQUHwum7UktTz1t3xRAE2pOj1zM3xUAklANzD1zGFlzHP5EAPBD/fnbds>
# 2025-04-30 10:41:05,164 - DEBUG - Body:  <https://mattamis.com/jo?3xety=gCApxy-Lz0keTPTDo-yEzzkmFzS1kBUWv3ksUzscxmtGwa-124NszkMGwd-VlPM8BmzVEwx4PKDJVyG/o7vpgef>
# 2025-04-30 10:41:05,165 - DEBUG - Header: Received: from 10.226.14.168
# 2025-04-30 10:41:05,166 - DEBUG - Header:  by atlas109.aol.mail.ne1.yahoo.com pod-id NONE with HTTPS; Wed, 30 Apr 2025 04:43:52 +0000
# 2025-04-30 10:41:05,167 - DEBUG - Header: Received: from 64.188.71.44 (EHLO vpntun44.kingofninjutsu.com)
# 2025-04-30 10:41:05,168 - DEBUG - Header:  by 10.226.14.168 with SMTPs
# 2025-04-30 10:41:05,169 - DEBUG - Header:  (version=TLS1_2 cipher=TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256);
# 2025-04-30 10:41:05,170 - DEBUG - Header:  Wed, 30 Apr 2025 04:43:52 +0000
# 2025-04-30 10:41:05,171 - DEBUG - Header: From: =?UTF-8?B?Q/OggIFh86CAgW7zoICBY/OggIFlcvOggIFM86CAgWHzoICBd/OggIFz86CAgQ==?=
# 2025-04-30 10:41:05,172 - DEBUG - Header: 	=?UTF-8?B?dfOggIFp86CAgXRG86CAgWnzoICBbvOggIFk86CAgWXzoICBcvOggIEg86CAgQ==?=
# 2025-04-30 10:41:05,172 - DEBUG - Header: 	=?UTF-8?B?SfOggIFu86CAgWZv86CAgQ==?= <xdkxtwjsmfro@mattamis.com>
# 2025-04-30 10:41:05,174 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:41:05,175 - DEBUG - Header: Subject: =?UTF-8?B?Q/OggIFh86CAgW7zoICBY/OggIFl86CAgXLzoICBIPOggIFM86CAgWHzoICBdw==?=
# 2025-04-30 10:41:05,176 - DEBUG - Header: 	=?UTF-8?B?86CAgXPzoICBdfOggIFp86CAgXTzoICBIPOggIFG86CAgWnzoICBbmTzoICBZQ==?=
# 2025-04-30 10:41:05,177 - DEBUG - Header: 	=?UTF-8?B?86CAgXLzoICBOvOggIEg86CAgUTzoICBafOggIFhZ/OggIFu86CAgW/zoICBcw==?=
# 2025-04-30 10:41:05,177 - DEBUG - Header: 	=?UTF-8?B?86CAgWXzoICBZPOggIEg86CAgXfzoICBafOggIF086CAgWjzoICBIPOggIFD77+9?=
# 2025-04-30 10:41:05,179 - DEBUG - Header: 	=?UTF-8?B?77+9YfOggIFuY/OggIFl86CAgXLzoICBIPOggIFh86CAgWbzoICBdPOggIFl77+9?=
# 2025-04-30 10:41:05,180 - DEBUG - Header: 	=?UTF-8?B?77+9cvOggIEg86CAgTHzoICBOfOggIE586CAgTnzoICBP/OggIEg86CAgULzoICB?=
# 2025-04-30 10:41:05,180 - DEBUG - Header: 	=?UTF-8?B?afOggIFs86CAgWzzoICBafOggIFv86CAgW7zoICBcyDzoICBYfOggIF3Ye+/vQ==?=
# 2025-04-30 10:41:05,182 - DEBUG - Header: 	=?UTF-8?B?77+9cvOggIFk86CAgWXzoICBZPOggIEu86CAgSDzoICBS/OggIFp86CAgWTzoICB?=
# 2025-04-30 10:41:05,182 - DEBUG - Header: 	=?UTF-8?B?bvOggIFl86CAgXnzoICBLPOggIEg86CAgVTzoICBZfOggIFz86CAgXTzoICBaQ==?=
# 2025-04-30 10:41:05,183 - DEBUG - Header: 	=?UTF-8?B?86CAgWPzoICBdfOggIFs86CAgWHzoICBcvOggIEs86CAgSDzoICBVPOggIFo77+9?=
# 2025-04-30 10:41:05,184 - DEBUG - Header: 	=?UTF-8?B?77+9efOggIFy86CAgW/zoICBafOggIFk86CAgSDzoICBbfOggIFhbvOggIF577+9?=
# 2025-04-30 10:41:05,184 - DEBUG - Header: 	=?UTF-8?B?77+9IG3zoICBb/OggIFy86CAgWXzoICBIPOggIFj86CAgWHzoICBbvOggIFj77+9?=
# 2025-04-30 10:41:05,185 - DEBUG - Header: 	=?UTF-8?B?77+9ZfOggIFy86CAgXPzoICBIPOggIFx86CAgXXzoICBYfOggIFs86CAgWnzoICB?=
# 2025-04-30 10:41:05,187 - DEBUG - Header: 	=?UTF-8?B?ZvOggIF586CAgQ==?=
# 2025-04-30 10:41:05,187 - DEBUG - Header: Date: Wed, 30 Apr 2025 00:43:50 -0400
# 2025-04-30 10:41:05,188 - DEBUG - Header: Message-ID: <NZfgPIc5-swHEu4S3Pw-g7ZK1wZt81HF-rO3s-f6M6-Q2Ki-@mattamis.com>
# 2025-04-30 10:41:05,189 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:41:05,190 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:41:05,191 - DEBUG - Header: 	boundary="----=_NextPart_000_0E82_01DBB96B.6477BE90"
# 2025-04-30 10:41:05,192 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:41:05,193 - DEBUG - Header: X-Originating-Ip: [64.188.71.44]
# 2025-04-30 10:41:05,194 - DEBUG - Header: Authentication-Results: atlas109.aol.mail.ne1.yahoo.com;
# 2025-04-30 10:41:05,195 - DEBUG - Header:  dkim=pass header.i=@mattamis.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,196 - DEBUG - Header:  spf=pass smtp.mailfrom=mattamis.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,197 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=mattamis.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,197 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Wed, 30 Apr 2025 04:43:52 +0000
# 2025-04-30 10:41:05,199 - DEBUG - Header: X-YMailISG: 1NjojggWLDtG.I4eiNnpUzhDXqLwpSiRlJh4zMVxjGgWe2mu
# 2025-04-30 10:41:05,200 - DEBUG - Header:  Zu1IS59LGagmEIz9tu4QxsPrLROcZaL1V5iGy0OyA2FUJMOtlVS8pNM5QvLk
# 2025-04-30 10:41:05,201 - DEBUG - Header:  6s4bsCkMvdMA3wwopJ_jxIKNBdFw99RumU2BU93SdzjKMEW4NxbYkxeRIOdL
# 2025-04-30 10:41:05,201 - DEBUG - Header:  O4mnYqc1P5Hxti9YhmSW7Cu55Aeb.NtJ9bDxN0_sshhmbU43pAS5lkEvVVgz
# 2025-04-30 10:41:05,202 - DEBUG - Header:  YOL66wQGsEd_La1LID1Fx7E1k1i3qCEGsY9Rt11NMaFxdIxtHWdnPqeEpj93
# 2025-04-30 10:41:05,203 - DEBUG - Header:  tGqPkjB5CEC2.rUMDpOK4FIUXxzGjlbXaqrLVBSpEGCL6rZpJs.xu.AswGTT
# 2025-04-30 10:41:05,204 - DEBUG - Header:  fM7_8ws4btcYi1_ChtYdWmxvvEQv10neEcu5hkXqw67WiHIMGKb3NTxMaHNb
# 2025-04-30 10:41:05,205 - DEBUG - Header:  A3epukFlbG5ggzmxQJWDhD8Nic0uXP3iBpFTNnZyX_pzv.xLRl3YAmSKfZsT
# 2025-04-30 10:41:05,206 - DEBUG - Header:  k9A3L7PT0J3zT.4xMMhiNyxeinL7fVtdDp1k4xEgbhosrJA6Gw7NcxAXSiIR
# 2025-04-30 10:41:05,207 - DEBUG - Header:  XV6NNK5Amd5xJpBZCY3uzNi_cqVsKQB9HmSIcz.Cqr9xl36Gy0fT4ZbD_vNf
# 2025-04-30 10:41:05,209 - DEBUG - Header:  sqsWbm2O4CVh6.MHfUd6KWjy1XbcZScKn3m1RzEZgZF0rdRlgtQx3OvtPxCE
# 2025-04-30 10:41:05,211 - DEBUG - Header:  ehnGlqD25uQWPyaw4P0fHde26a7T1yq1lFft0Ox2f3wWA1nHJVIs053fJPWB
# 2025-04-30 10:41:05,211 - DEBUG - Header:  Cg8VMdSXnnoRuqUanG8rTZ7D54RsRjfh1ZHhLcq1ebCo9EX51mh9.8EdV2XA
# 2025-04-30 10:41:05,212 - DEBUG - Header:  56l6yfaFdWEJyvVkMg_9xFRQXk0U5mofgawteRJVqpwSaEyWyesqcF_mqVIG
# 2025-04-30 10:41:05,213 - DEBUG - Header:  Ps5PgWp4zMbfyFXk8SWMLm9HVjxc2LnWbCk74h7pUn2uun7NTrrgAW5k55bP
# 2025-04-30 10:41:05,214 - DEBUG - Header:  tQgyaNZ0LMJJuE_0fBkY7Zqqn3vDcdQGe5hwCcqZ3Vpdlg9D4OENw4z762ie
# 2025-04-30 10:41:05,216 - DEBUG - Header:  Cvnz
# 2025-04-30 10:41:05,217 - DEBUG - Header: 	4b5HLU6Ioh5Qbb4_1TR4wRe8dKcGsmGmOPuA23ODST4G1U0MoS8xx932
# 2025-04-30 10:41:05,218 - DEBUG - Header:  tti0bI237RQzy3sg753Mc9s6LSRQa5BofBqmmaH3nSSZn863cI2TmjBlEtoM
# 2025-04-30 10:41:05,218 - DEBUG - Header:  fe_qtI3MsYSOjQqU42WChm2s9VfN8wKRPmKNg9B7MSQM8PNxAx74v8l0qg5x
# 2025-04-30 10:41:05,219 - DEBUG - Header:  pmZAivieq517t1otz.k4uXFf_HdPCUEHkG8Q189USJ9CyxeAa8xD4gShPgf7
# 2025-04-30 10:41:05,220 - DEBUG - Header:  4iBx4C2h06Rk7cX6yZBpkfuIQUvc0GMMfyz7O88Ouw0e7eP3DyjmOmFxDllt
# 2025-04-30 10:41:05,221 - DEBUG - Header:  Yc0_IFstTnqPG7JqvVIIZ9Ut1o4viCzd.KyJr1WC_6bKc7Rw69IotLZLwo_E
# 2025-04-30 10:41:05,223 - DEBUG - Header:  8KQhnOh3USmw47s_1Rf54BSf88PcdhYoM4WVFXwk8PNlAq2JXq81xeYFGDKb
# 2025-04-30 10:41:05,223 - DEBUG - Header:  TMIRh92.o7cNwHFPp8vKVw--
# 2025-04-30 10:41:05,224 - DEBUG - Header: Thread-Index: AQKCnuRYi2PDzte/79eKAShFQUc7wg==
# 2025-04-30 10:41:05,225 - DEBUG - Header:
# 2025-04-30 10:41:05,246 - DEBUG -
#
# Email 5:
# 2025-04-30 10:41:05,248 - DEBUG - Subject: Let's Make Your Rate Work FOR You (Starting Today)
# 2025-04-30 10:41:05,251 - DEBUG - From: aiuyumkkwp@fnxzone.com
# 2025-04-30 10:41:05,253 - DEBUG - Received: 2025-04-29 22:29:54+00:00
# 2025-04-30 10:41:05,524 - DEBUG - No conditions or phishing indicators found
# 2025-04-30 10:41:05,536 - DEBUG - Body:
# 2025-04-30 10:41:05,537 - DEBUG - Body:
# 2025-04-30 10:41:05,537 - DEBUG - Body:
# 2025-04-30 10:41:05,537 - DEBUG - Body:
# 2025-04-30 10:41:05,537 - DEBUG - Body:
# 2025-04-30 10:41:05,537 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:  <https://fnxzone.com/0vogbovu0o535?qng2fal?QMguVTb_MDZzqDsiOTa_U19yc_vEgPe_aE9MDMUdQcCZDSCtTOS8QQEZDVZsjcSi3oUMm_ujwsgD/0ah9ryq>
# 2025-04-30 10:41:05,542 - DEBUG - Body:  <https://fnxzone.com/bsxdt2cftqcuq?h4ta4kpk2l?PjfSJPtsSd87CwysAbhlSc8D0Uxe8eD3Og8JDULFJDcnbEbydZsVLB7nPGWyUwrlZBhGnWJVMBi1dPG/j7q2kcp2>
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body: Let's Make Your Rate Work FOR You (Starting Today)
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Body:
# 2025-04-30 10:41:05,542 - DEBUG - Header: Received: from 10.222.148.11
# 2025-04-30 10:41:05,542 - DEBUG - Header:  by atlas201.aol.mail.ne1.yahoo.com pod-id NONE with HTTPS; Wed, 30 Apr 2025 02:29:54 +0000
# 2025-04-30 10:41:05,558 - DEBUG - Header: Received: from 205.186.97.217 (EHLO iotsecurity.cannaatms.com)
# 2025-04-30 10:41:05,558 - DEBUG - Header:  by 10.222.148.11 with SMTPs
# 2025-04-30 10:41:05,558 - DEBUG - Header:  (version=TLS1_2 cipher=TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256);
# 2025-04-30 10:41:05,561 - DEBUG - Header:  Wed, 30 Apr 2025 02:29:54 +0000
# 2025-04-30 10:41:05,561 - DEBUG - Header: From: =?UTF-8?B?UfOggIF186CAgWnzoICBY/OggIFr86CAgS3zoICBYfOggIF186CAgXTzoICBbw==?=
# 2025-04-30 10:41:05,561 - DEBUG - Header: 	=?UTF-8?B?86CAgS3zoICBY/OggIFvdvOggIFl86CAgXJh86CAgWfzoICBZfOggIEg86CAgQ==?=
# 2025-04-30 10:41:05,561 - DEBUG - Header: 	=?UTF-8?B?QWTzoICB?= <aiuyumkkwp@fnxzone.com>
# 2025-04-30 10:41:05,561 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:41:05,566 - DEBUG - Header: Subject: =?UTF-8?B?TPOggIFl86CAgXTzoICBJ/OggIFz86CAgSBN86CAgWHzoICBa/OggIFl86CAgQ==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	=?UTF-8?B?IPOggIFZ86CAgW/zoICBdfOggIFyIPOggIFS86CAgWHzoICBdPOggIFl86CAgQ==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	=?UTF-8?B?IPOggIFX86CAgW/zoICBcvOggIFr86CAgSDzoICBRvOggIFP86CAgVLzoICBIA==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	=?UTF-8?B?86CAgVnzoICBb/OggIF186CAgSDzoICBKPOggIFT86CAgXTzoICBYfOggIFydA==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	=?UTF-8?B?86CAgWnzoICBbvOggIFn86CAgSDzoICBVPOggIFv86CAgWTzoICBYXnzoICBKQ==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	=?UTF-8?B?86CAgQ==?=
# 2025-04-30 10:41:05,566 - DEBUG - Header: Date: Tue, 29 Apr 2025 22:29:52 -0400
# 2025-04-30 10:41:05,566 - DEBUG - Header: Message-ID: <7L3ciWF3.YF8oqNEOy9NPQu.USu4BA5CK54GU4.95CqGjkt@fnxzone.com>
# 2025-04-30 10:41:05,566 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:41:05,566 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:41:05,566 - DEBUG - Header: 	boundary="----=_NextPart_000_0E7A_01DBB95A.A13F3170"
# 2025-04-30 10:41:05,566 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:41:05,566 - DEBUG - Header: X-Originating-Ip: [205.186.97.217]
# 2025-04-30 10:41:05,566 - DEBUG - Header: Authentication-Results: atlas201.aol.mail.ne1.yahoo.com;
# 2025-04-30 10:41:05,582 - DEBUG - Header:  dkim=pass header.i=@fnxzone.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,582 - DEBUG - Header:  spf=pass smtp.mailfrom=fnxzone.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,582 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=fnxzone.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:41:05,582 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Wed, 30 Apr 2025 02:29:54 +0000
# 2025-04-30 10:41:05,582 - DEBUG - Header: X-YMailISG: XRTcd2oWLDvpE3YCM1EvswpgoJN4TNbcpsJ2nF4uF250FypX
# 2025-04-30 10:41:05,582 - DEBUG - Header:  50qHLGbFEgH2bP43ybCxvyqBiHI4clvki3ueUFRe__Rd2C6pMThP7_SKTH_f
# 2025-04-30 10:41:05,591 - DEBUG - Header:  v3oUtFPdKvgwvlBJxSx54s5EYKIvEp4UWNRDlh5Vt0YrLaPR82tEhKekah7Q
# 2025-04-30 10:41:05,591 - DEBUG - Header:  ZGfJOQGyJ0iBJmKRFJlNHPYzEJUM503p5ARvc6Tgo1BEO1mFoCEpiYc5nmEG
# 2025-04-30 10:41:05,591 - DEBUG - Header:  tHdWyoUtph.vxRBbpbRr9fllamGq6XC1xtg.i4oyqeXWGmp4M6s7YPP2mXaH
# 2025-04-30 10:41:05,591 - DEBUG - Header:  sV13ePPGeEjhOkBJId4oURDdajFP_zL3HPS_WsBT6hKKKirvOzYsK4d6U6Dz
# 2025-04-30 10:41:05,591 - DEBUG - Header:  oJ9o3W2tg5biAZcjyoExHUFj2KnzKS03IJlv6GFyirw1bulwvf8hhVQPQ8Ru
# 2025-04-30 10:41:05,591 - DEBUG - Header:  cmeBXARZG6PenyCaaoeW.iXQi3p.xhao82sAhce5jz61ir8dalpDcaxfJv2B
# 2025-04-30 10:41:05,591 - DEBUG - Header:  Tq_qhFV.lFHzZZEoMSsj3pp.XRcPm8cHdjqK57nVTJAFipJanK7.sC6_Lk4f
# 2025-04-30 10:41:05,591 - DEBUG - Header:  Pjq1YbuQvjCsbyK2x8A42nlqGuFym8r92NN0WFY6zdp1WapoSAb9lCviRsIk
# 2025-04-30 10:41:05,591 - DEBUG - Header:  vmZ2Q2qrybSsPvXJQw25aFrpNRzCZ.e7wn4kwUu4LuGidQRi1jrEkdl4Oeib
# 2025-04-30 10:41:05,591 - DEBUG - Header:  ANUqfdeLHyWKLbyTZHwT4lDZSbVqftc9wVKadMNiiTQLOPRki.eeFKw_MFuw
# 2025-04-30 10:41:05,591 - DEBUG - Header:  .61dTX89T.eU.Zx15wZhI6uhHxcgW2mJU66LX1hjuhE.L4.Is.ync_tAoAym
# 2025-04-30 10:41:05,591 - DEBUG - Header:  vflQwsc.4nQ7pk.P1u0ZkU0lYVptMskYyGs.vTs1Zrhe10X92QzyercayAUv
# 2025-04-30 10:41:05,591 - DEBUG - Header:  SLDuAAefSmynC_gozqdbV7_KpvZ6IwKKWcQpjRxrZxayNoIWZyGiu2ab1py0
# 2025-04-30 10:41:05,591 - DEBUG - Header:  fKVXX2a.xiuRTN5HSquj._kmfwmaQMaFivj7hkmPXoqjOZ4niOuuNSbHftoK
# 2025-04-30 10:41:05,591 - DEBUG - Header:  UNUU
# 2025-04-30 10:41:05,607 - DEBUG - Header: 	hJuYjn_PLeL7bXzeKdEHIZ.F4RwudTDtlM_1YpJvKOIA8vZNZiu.zpnZ
# 2025-04-30 10:41:05,607 - DEBUG - Header:  YKGRXr8xJp7qmICGqUSF75HhypkBfe5PUUz0T_EySRnWsg2nQ48f0_VhRQ1k
# ...
# 2025-04-30 10:42:44,208 - DEBUG - Header: 	=?utf-8?B?77+986CBkyDzoIGTU/OggZNj86CBk/OggZNy86CBk2Vl86CBk27zoIGT77+9?=
# 2025-04-30 10:42:44,210 - DEBUG - Header: 	=?utf-8?B?77+986CBk/OggZNp86CBk/OggZPzoIGT86CBk25n86CBk/OggZMgUPOggZPvv70=?=
# 2025-04-30 10:42:44,211 - DEBUG - Header: 	=?utf-8?B?77+986CBk3Jl86CBk/OggZN286CBk/OggZNl86CBk27zoIGTdPOggZPzoIGTYQ==?=
# 2025-04-30 10:42:44,213 - DEBUG - Header: 	=?utf-8?B?dPOggZNp86CBk/OggZPzoIGTdmXzoIGT86CBk/OggZPzoIGTIPOggZNDYe+/vQ==?=
# 2025-04-30 10:42:44,214 - DEBUG - Header: 	=?utf-8?B?77+9cvOggZNl86CBk/OggZMgQfOggZPzoIGT86CBk/OggZNmZvOggZNp86CBkw==?=
# 2025-04-30 10:42:44,216 - DEBUG - Header: 	=?utf-8?B?bPOggZNp86CBk/OggZNh86CBk/OggZN086CBk/OggZPzoIGT86CBk2XzoIGT?=
# 2025-04-30 10:42:44,217 - DEBUG - Header: 	=?utf-8?B?86CBuw==?= <stirsyoghurt@zeards.com>
# 2025-04-30 10:42:44,218 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:42:44,219 - DEBUG - Header: Subject: =?utf-8?B?86CBk0nzoIGTbnZl86CBk/OggZNz86CBk/OggZN0IPOggZPzoIGTafOggZNuIA==?=
# 2025-04-30 10:42:44,221 - DEBUG - Header: 	=?utf-8?B?86CBk1nzoIGTb/OggZN186CBk/OggZPzoIGTcvOggZMg86CBk/OggZPzoIGT?=
# 2025-04-30 10:42:44,222 - DEBUG - Header: 	=?utf-8?B?SPOggZNl86CBk/OggZNh86CBk2zzoIGTdPOggZPzoIGTaDog86CBk1Nj86CBkw==?=
# 2025-04-30 10:42:44,223 - DEBUG - Header: 	=?utf-8?B?86CBk/OggZNy86CBk/OggZPzoIGT86CBk/OggZPzoIGT86CBk2XzoIGTZW5p?=
# 2025-04-30 10:42:44,224 - DEBUG - Header: 	=?utf-8?B?86CBk27zoIGT86CBk2cgU/OggZNl86CBk/OggZPzoIGT86CBk3LzoIGTdu+/vQ==?=
# 2025-04-30 10:42:44,225 - DEBUG - Header: 	=?utf-8?B?77+9afOggZPzoIGT86CBk2PzoIGT86CBk/OggZNlc/OggZPzoIGTIEHzoIGT?=
# 2025-04-30 10:42:44,227 - DEBUG - Header: 	=?utf-8?B?86CBk3bzoIGT86CBk2HzoIGTaWzzoIGTYfOggZNibPOggZNl86CBk/OggZPzoIGT?=
# 2025-04-30 10:42:44,228 - DEBUG - Header: 	=?utf-8?B?IE7zoIGT86CBk2XzoIGTYfOggZNy86CBk/OggZPzoIGTYnnzoIGTIfOggZM=?=
# 2025-04-30 10:42:44,229 - DEBUG - Header: 	=?utf-8?B?86CBk/OggZPzoIGT86CBu/Oggbs=?=
# 2025-04-30 10:42:44,230 - DEBUG - Header: Date: Sun, 20 Apr 2025 12:28:33 -0400
# 2025-04-30 10:42:44,231 - DEBUG - Header: Message-ID: <117359c7-dc51-472c-b8bd-173c4d9440d6@zeards.com>
# 2025-04-30 10:42:44,232 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:42:44,234 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:42:44,235 - DEBUG - Header: 	boundary="----=_NextPart_000_07D2_01DBB1F0.517C0030"
# 2025-04-30 10:42:44,236 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:42:44,238 - DEBUG - Header: X-Originating-Ip: [139.28.213.31]
# 2025-04-30 10:42:44,239 - DEBUG - Header: Authentication-Results: atlas-production.v2-mail-prod1-bf1.omega.yahoo.com;
# 2025-04-30 10:42:44,240 - DEBUG - Header:  dkim=pass header.i=@zeards.com header.s=default arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:44,241 - DEBUG - Header:  spf=pass smtp.mailfrom=zeards.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:44,242 - DEBUG - Header:  dmarc=pass(p=REJECT) header.from=zeards.com arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:44,244 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Sun, 20 Apr 2025 16:28:42 +0000
# 2025-04-30 10:42:44,245 - DEBUG - Header: X-YMailISG: fEBm4HQWLDssJCT2E3KcM9nLuq6P_7wmu7qmosh9lB._NdPi
# 2025-04-30 10:42:44,245 - DEBUG - Header:  UOvUD7mwDatkGFdzY8p3hLklnC7.tkuRXcWece6TCMyMiGh8ZNm7t_BfeneR
# 2025-04-30 10:42:44,247 - DEBUG - Header:  nqo96iLfmXD_4gd9Wgqla.5tgeMbAVvidH6h2_ny.2aiJFC7NGsQpBFyHk8P
# 2025-04-30 10:42:44,248 - DEBUG - Header:  hZlxGsXSa38ea.MOVKoiwj5jJ1jwY1a_OY83R5QrHRTfgT1G.X0J_5om97kw
# 2025-04-30 10:42:44,249 - DEBUG - Header:  .T35CC.psJ9QrjNs9nYUkHGk9UFN38OZt_A6CjSKzo5y8ogwjU4Ge6C721qn
# 2025-04-30 10:42:44,250 - DEBUG - Header:  5AKey3bos8PB_A0I4ppudAMyrHkEQW8_rdBPED_UitxOSDRZ1J2SjPy7jj7g
# 2025-04-30 10:42:44,251 - DEBUG - Header:  tzrDi7HTjuGWf9UoeI3TB.bRoIz8oSYjtJV9lEFglAMsR9ZAqL2MZmgEeB3H
# 2025-04-30 10:42:44,252 - DEBUG - Header:  GrhtUzi65pOHG4uA3KRjat9xGlHUrAOEXjUcfFsyj3fdb3.Vi9S0u27QaUPO
# 2025-04-30 10:42:44,253 - DEBUG - Header:  JsibWgFho3D8slvk8jluXOPQPnoC4U7ok7aNBYhBpvSJoZ0x3Ce8cOM2SEQl
# 2025-04-30 10:42:44,255 - DEBUG - Header:  mB0zu7qCJhGsKDPl8vWMcyHd4B4Wnn3VFJrO6gX6_dLR43Jm5oDBScOuEY1.
# 2025-04-30 10:42:44,257 - DEBUG - Header:  gdtpS7kqu38RBL9vq6atOL6dNPgD0e_wkLnsLET7Vgm_kpYURXmXX9xZDaYF
# 2025-04-30 10:42:44,257 - DEBUG - Header:  l3H.A8GTct8I6lSn8tidrYv6Cq9Hpb_OuIaH0g20q7Ir4rQd9QEfGeQwFJPp
# 2025-04-30 10:42:44,259 - DEBUG - Header:  hnnxSnmDSP_JnTx6nxTf_gfpD3XhMobTXnc1ADa41JyQRZf1cD2zkPFhJZUA
# 2025-04-30 10:42:44,260 - DEBUG - Header:  hUijoM_8hDlwLn7.peX38XZqiKjQXrRDaAvdEb97R3.gFPqeCayIG9tgRE4q
# 2025-04-30 10:42:44,261 - DEBUG - Header:  h39RM8O9bpi7cbaN1J3lIjfX2WPm.HwEiPdSngY4yA4hsDaOOqw30leihuBM
# 2025-04-30 10:42:44,263 - DEBUG - Header:  6lU6VWsbnXCyhdUNekb9F9YJ.E8cTmKMBHfpn7bWHD9qzaits7JO8TiiQ844
# 2025-04-30 10:42:44,264 - DEBUG - Header:  yFMp
# 2025-04-30 10:42:44,265 - DEBUG - Header: 	Q1IjWZWCh4MNyGg_ABcLWmIv6eulkUxUucKiZm09bqaIHlRStdlthUtR
# 2025-04-30 10:42:44,270 - DEBUG - Header:  6LpXdMU.Bojnk8Q2JarNzIJ83.Hq5Alw5A2449WFHUfDGYDQH5kAKDsm5jBO
# 2025-04-30 10:42:44,273 - DEBUG - Header:  pcjXELsW0ASBlZlJObycE4RQvzQ3Jg8pI._H0cXMkUM_GR_QKsEG0UzkfUez
# 2025-04-30 10:42:44,274 - DEBUG - Header:  3EKKOU8AmCUAPytlt4sRIRgTTk1ojdvsSXxI9xk-
# 2025-04-30 10:42:44,276 - DEBUG - Header: List-Unsubscribe: <https://zeards.com/1687a0/b45d0/qGbIPO15HdTuE9n8IO05PP3t25qeaK45Ve3HdGL8Zg4Ze08otINWKLeT-vTuNeM9aNW43nRQ-9pcaO4H7qjAbQRD/caef93a/31e2?ref=e3484474d9e1be0d0b>
# 2025-04-30 10:42:44,277 - DEBUG - Header: Thread-Index: AQGYaES8hezOqxi/25RqjAYv6NDgBw==
# 2025-04-30 10:42:44,279 - DEBUG - Header:
# 2025-04-30 10:42:44,313 - DEBUG -
#
# Email 167:
# 2025-04-30 10:42:44,318 - DEBUG - Subject: CONFIRMED: kimmeyharold, $50 Free Trial Offer Confirmed. Claim Now!
# 2025-04-30 10:42:44,326 - DEBUG - From: noreply@choiceforindependentlife.jp.net
# 2025-04-30 10:42:44,329 - DEBUG - Received: 2025-04-20 12:07:18+00:00
# 2025-04-30 10:42:45,008 - DEBUG - No conditions or phishing indicators found
# 2025-04-30 10:42:45,015 - DEBUG - Body: <https://bikepremier.com/4hVpCH353320KGxu3464bdlzkuhvfu60241FCPIEUVRLAIJYPK22190KDMN333478U19>
# 2025-04-30 10:42:45,015 - DEBUG - Body:
# 2025-04-30 10:42:45,015 - DEBUG - Body: Please confirm receipt!
# 2025-04-30 10:42:45,015 - DEBUG - Body:
# 2025-04-30 10:42:45,015 - DEBUG - Body: <https://bikepremier.com/4Mbccl353320mCXv3464ykuuaecihb60241KKWBZXGIGWHKVDL22190QMUT333478z19>
# 2025-04-30 10:42:45,015 - DEBUG - Body:
# 2025-04-30 10:42:45,015 - DEBUG - Body:
# 2025-04-30 10:42:45,020 - DEBUG - Body:
# 2025-04-30 10:42:45,020 - DEBUG - Body:
# 2025-04-30 10:42:45,020 - DEBUG - Body: CVS
# 2025-04-30 10:42:45,023 - DEBUG - Body:
# 2025-04-30 10:42:45,023 - DEBUG - Body: EXCLUSIVE OFFER!
# 2025-04-30 10:42:45,023 - DEBUG - Body:
# 2025-04-30 10:42:45,023 - DEBUG - Body: Dear Pharmacy Customer,
# 2025-04-30 10:42:45,028 - DEBUG - Body:
# 2025-04-30 10:42:45,030 - DEBUG - Body:
# 2025-04-30 10:42:45,032 - DEBUG - Body:
# 2025-04-30 10:42:45,032 - DEBUG - Body: Congratulations! You've been selected to receive an EXCLUSIVE OFFER!
# 2025-04-30 10:42:45,034 - DEBUG - Body:
# 2025-04-30 10:42:45,034 - DEBUG - Body:
# 2025-04-30 10:42:45,036 - DEBUG - Body:
# 2025-04-30 10:42:45,038 - DEBUG - Body: Complete this short 30-second survey about your experiences with
# 2025-04-30 10:42:45,039 - DEBUG - Body:
# 2025-04-30 10:42:45,040 - DEBUG - Body: Pharmacy and receive your exclusive reward offer (minimum value of $90) for participating.
# 2025-04-30 10:42:45,041 - DEBUG - Body:
# 2025-04-30 10:42:45,042 - DEBUG - Body:
# 2025-04-30 10:42:45,044 - DEBUG - Body:
# 2025-04-30 10:42:45,046 - DEBUG - Body: Start Now > <https://bikepremier.com/4UStsT353320cLEn3464kubjnytlln60241ZVJNYALHJPLMOKC22190SXMB333478k19>
# 2025-04-30 10:42:45,047 - DEBUG - Body:
# 2025-04-30 10:42:45,048 - DEBUG - Body:
# 2025-04-30 10:42:45,048 - DEBUG - Body:
# 2025-04-30 10:42:45,048 - DEBUG - Body: Copyright  02-20-2025, all rights reserved.
# 2025-04-30 10:42:45,048 - DEBUG - Body:
# 2025-04-30 10:42:45,048 - DEBUG - Body:
# 2025-04-30 10:42:45,048 - DEBUG - Body:
# 2025-04-30 10:42:45,056 - DEBUG - Body:
# 2025-04-30 10:42:45,057 - DEBUG - Body:
# 2025-04-30 10:42:45,057 - DEBUG - Body: This rewards program is not endorsed, sponsored by or affiliated with any merchants listed above.
# 2025-04-30 10:42:45,059 - DEBUG - Body: Registered trademarks are the property of their respective owners.
# 2025-04-30 10:42:45,061 - DEBUG - Body:
# 2025-04-30 10:42:45,063 - DEBUG - Body: This ad is sent by a third-party on behalf of the advertiser. All promotional fulfillment is the sole responsibility
# 2025-04-30 10:42:45,065 - DEBUG - Body: of the owner of the program. Please refer to the program requirements listed on the offers registration page
# 2025-04-30 10:42:45,069 - DEBUG - Body: for further details.
# 2025-04-30 10:42:45,069 - DEBUG - Body:
# 2025-04-30 10:42:45,072 - DEBUG - Body:
# 2025-04-30 10:42:45,074 - DEBUG - Body: If you no longer wish to receive these emails, you may unsubscribe by clicking here <https://bikepremier.com/5OdEdK353320fkWA3464cafwyswbuu60241RNUKFNIKEBHBFNU22190BFAX333478l19>
# 2025-04-30 10:42:45,075 - DEBUG - Body:
# 2025-04-30 10:42:45,075 - DEBUG - Body: To unsubscribe, click here <https://bikepremier.com/6ytLOQ353320mRoI3464nvzjupwrrx60241VDBOAVQGRQKLBUG22190ZZXV333478O19> .
# 2025-04-30 10:42:45,077 - DEBUG - Body:
# 2025-04-30 10:42:45,077 - DEBUG - Body:
# 2025-04-30 10:42:45,080 - DEBUG - Body:  <https://bikepremier.com/track/3ocSia353320MTLK3464ujilhiquyn60241LJLSROVTDDSFJJN22190RMLB333478j19>
# 2025-04-30 10:42:45,083 - DEBUG - Header: Received: from 127.0.0.1
# 2025-04-30 10:42:45,084 - DEBUG - Header:  by atlas-production.v2-mail-prod1-bf1.omega.yahoo.com pod-id atlas--production-bf1-7cd54695cd-g4h2t.bf1.yahoo.com with HTTP; Sun, 20 Apr 2025 16:07:18 +0000
# 2025-04-30 10:42:45,085 - DEBUG - Header: Received: from 85.239.55.49 (EHLO goodreads.jastkolpimunestregeve.com)
# 2025-04-30 10:42:45,087 - DEBUG - Header:  by 10.196.122.43 with SMTP;
# 2025-04-30 10:42:45,088 - DEBUG - Header:  Sun, 20 Apr 2025 16:07:18 +0000
# 2025-04-30 10:42:45,089 - DEBUG - Header: Reply-To: "thank you" <n-info.22190-60241@invkwetvm.com>
# 2025-04-30 10:42:45,091 - DEBUG - Header: From: "CVS" <noreply@choiceforindependentlife.jp.net>
# 2025-04-30 10:42:45,092 - DEBUG - Header: To: <kimmeyharold@aol.com>
# 2025-04-30 10:42:45,094 - DEBUG - Header: Subject: CONFIRMED: kimmeyharold, $50 Free Trial Offer Confirmed. Claim Now!
# 2025-04-30 10:42:45,095 - DEBUG - Header: Date: Sun, 20 Apr 2025 12:07:17 -0400
# 2025-04-30 10:42:45,097 - DEBUG - Header: Message-ID: <031031046.56802195.9054277846807@mail.yahoo.com>
# 2025-04-30 10:42:45,098 - DEBUG - Header: MIME-Version: 1.0
# 2025-04-30 10:42:45,099 - DEBUG - Header: Content-Type: multipart/alternative;
# 2025-04-30 10:42:45,100 - DEBUG - Header: 	boundary="----=_NextPart_000_07F5_01DBB1F0.56788D10"
# 2025-04-30 10:42:45,101 - DEBUG - Header: X-Mailer: Microsoft Outlook 16.0
# 2025-04-30 10:42:45,103 - DEBUG - Header: X-Originating-Ip: [85.239.55.49]
# 2025-04-30 10:42:45,105 - DEBUG - Header: Authentication-Results: atlas-production.v2-mail-prod1-bf1.omega.yahoo.com;
# 2025-04-30 10:42:45,106 - DEBUG - Header:  dkim=perm_fail header.i=@choiceforindependentlife.jp.net header.s=smtp arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:45,108 - DEBUG - Header:  spf=fail smtp.mailfrom=choiceforindependentlife.jp.net arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:45,110 - DEBUG - Header:  dmarc=unknown header.from=choiceforindependentlife.jp.net arc_overridden_status=NOT_OVERRIDDEN;
# 2025-04-30 10:42:45,111 - DEBUG - Header: X-Apparently-To: kimmeyharold@aol.com; Sun, 20 Apr 2025 16:07:18 +0000
# 2025-04-30 10:42:45,112 - DEBUG - Header: X-YMailISG: UJBe9zwWLDsF1NUKYnl84V57552Ynspscmo0IRB7u1rx3EyF
# 2025-04-30 10:42:45,114 - DEBUG - Header:  a77be7iK_.p4TqXMf1ZLZTUj7b083sNxoOF1.C9v.C5wxciW78VNM.uqLBHA
# 2025-04-30 10:42:45,116 - DEBUG - Header:  XllsTJ5r_33wBXMbGvnogvjpBg8tBIpUqnhdGcgE0RN8iddbU0qxZ8s2B86M
# 2025-04-30 10:42:45,117 - DEBUG - Header:  c9xp36228_Q5R_vUq27iOdIjfDu13szrML_ERKlyBLmPj7UDl9uamfAiGNjz
# 2025-04-30 10:42:45,119 - DEBUG - Header:  EbVt93K6TbzgyBkjd2gIM1_ozG2Ys0aJda121ofqfp7.QT943wfjwrbsvTix
# 2025-04-30 10:42:45,120 - DEBUG - Header:  HS4C9zIWbtmnso2dqPo5hJ2Hv9z18v_KeJqCQmIUEhC_y2m6bRHFqT_P5GWu
# 2025-04-30 10:42:45,121 - DEBUG - Header:  puG2pw_7cN4H9O742rG5VU4PmMIrF_5CgjwHXFJdgeFRrIcAFXORGwrjDuTt
# 2025-04-30 10:42:45,123 - DEBUG - Header:  c4m6LKQrSeuhdjtgQtAKWCG4JQqSlXuqbwVzc68DyC2ZYb0DuBzKY4Q3F78.
# 2025-04-30 10:42:45,124 - DEBUG - Header:  bIbGPlDYxXjPKVMemaD.Fvx3iOF0wIcrus8myxvCRbgQ9ehJODb1YJR.hk3Y
# 2025-04-30 10:42:45,127 - DEBUG - Header:  o9wkyb6F_QtfhiwyOmUDrw9b57DqXAYuHdpI8a2ww68uXSexvVsODVFMJn_P
# 2025-04-30 10:42:45,129 - DEBUG - Header:  yuUvnEu2u2WdU.OkpxgjX0gSMz70_2Jg7bFwI9O1hGzm0_WeGybaCwhtFeRg
# 2025-04-30 10:42:45,130 - DEBUG - Header:  NPLcFHlAaMmRY9Z44bgvhmUor6klePArCPV9PndWSPi8N2qIZdqvSeOIlCM8
# 2025-04-30 10:42:45,131 - DEBUG - Header:  3ipJqVl7BySvxF2uNBV.GSZ.5cf6uTHpWWCJ_YqDcuyIOutGVOiLhqSpr4k8
# 2025-04-30 10:42:45,133 - DEBUG - Header:  xrT6F376k7Vo9vqK1jWsX6DsT7h5zPad10mbnXvL_skX6Fu0pUaK8mvantcz
# 2025-04-30 10:42:45,135 - DEBUG - Header:  ZbQc7lrQrgje6eHFv1yqlvxmf80ghxvYCoaaBZ_B2D.5dAS7cCGGfX_Cfu6P
# 2025-04-30 10:42:45,140 - DEBUG - Header:  _iyZx9QOCw1dQ8iinVPQqzd6e5Qg6jZxHa5gVIo04_M0XOfEZiLBYCMxL6xA
# 2025-04-30 10:42:45,142 - DEBUG - Header:  Rnb9
# 2025-04-30 10:42:45,143 - DEBUG - Header: 	Zn3ove1JQs_lAmkMHQTcJAdc_09hvB_O__fKEqHt3bQC2f_FoD8ln0bI
# 2025-04-30 10:42:45,145 - DEBUG - Header:  cToywNq4PTxqfQ.6HAGcL7aTeemGatZGN56KFqN9.cZXXGeUCisbIReAw9Na
# 2025-04-30 10:42:45,146 - DEBUG - Header:  EgkGhWhJ2GMRmIBM68u.Aq8x8w2rTAgJrtZksTX3bPWQ9S6j3PYqZDhxci5s
# 2025-04-30 10:42:45,148 - DEBUG - Header:  WDiAHFxNhU_IGKy8hieZYCxmw2fBvOa2oSRGJvfrHYsCGvIGWq6LbvxW3Q.d
# 2025-04-30 10:42:45,149 - DEBUG - Header:  Tof0of23moYQ2VbYHBNPTOAihRNDgDtB9LpIqVQ2GfA_OnJFtg--
# 2025-04-30 10:42:45,151 - DEBUG - Header: Thread-Index: AQHuX2eDaOdcpy52j8SiwA5LxBulqg==
# 2025-04-30 10:42:45,152 - DEBUG - Header:
# 2025-04-30 10:42:45,186 - DEBUG -
#
# Email 168:
# 2025-04-30 10:42:45,190 - DEBUG - Subject: Unlock Personalized Loan Solutions for Every Dream
# 2025-04-30 10:42:45,195 - DEBUG - From: jmdqhxyoi@imagoid.com
# 2025-04-30 10:42:45,201 - DEBUG - Received: 2025-04-20 09:32:20+00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#       9     rules_json = agent.get_outlook_rules()
#      10     #print(rules_json)
#      11
#      12     # Process last 24 hours of emails
# ---> 13     agent.process_emails(rules_json)
#      15     print("Complete. Check the log file for detailed analysis.\n\n")
#      17 except Exception as e:
#
# Cell In[3], line 584, in OutlookSecurityAgent.process_emails(self, rules_json, days_back)
#     582 # Check body keywords
#     583 if 'body' in conditions:
# --> 584     if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
#     585         match = True
#     586         matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
#
# Cell In[3], line 584, in <genexpr>(.0)
#     582 # Check body keywords
#     583 if 'body' in conditions:
# --> 584     if any(keyword.lower() in email.Body.lower() for keyword in conditions['body']):
#     585         match = True
#     586         matched_keyword = next((keyword for keyword in conditions['body'] if keyword.lower() in email.Body.lower()), None)
#
# File d:\Data\Harold\github\OutlookMailSpamFilter\.venv\Lib\site-packages\win32com\client\dynamic.py:618, in CDispatch.__getattr__(self, attr)
#     614 debug_attr_print(
#     615     "Getting property Id 0x%x from OLE object" % retEntry.dispid
#     616 )
#     617 try:
# --> 618     ret = self._oleobj_.Invoke(retEntry.dispid, 0, invoke_type, 1)
#     619 except pythoncom.com_error as details:
#     620     if details.hresult in ERRORS_BAD_CONTEXT:
#     621         # May be a method.
#
# KeyboardInterrupt:
